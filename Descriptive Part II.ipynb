# %%
import numpy as np
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns
from datetime import datetime #for working with times objects
from datetime import timedelta #for working with times objects
from collections import Counter
import folium #map
import matplotlib.pyplot as plt #color and graph
import matplotlib.cm as cm #color
import math
import random
import glob
import plotly.graph_objects as go

# %%
Phil = pd.read_csv('cleaned_files.csv', low_memory=False)
Phil2 = pd.read_csv('merged_files.csv', low_memory=False) #uncleaned file for stolen bikes

# %%
Weather = pd.read_csv("Weather_data_clean.csv", low_memory=False)

# %%
columns = Phil.columns
print(columns)
#print (Phil["start_coordinates"])
Phil.info()
# Out:
# Index(['trip_id', 'duration', 'start_time', 'end_time', 'start_station',
#        'end_station', 'bike_id', 'plan_duration', 'trip_route_category',
#        'passholder_type', 'bike_type', 'Date_s', 'Weekday_s', 'Hour_s',
#        'Date_e', 'Weekday_e', 'Hour_e', 'start_coordinates',
#        'end_coordinates'],
#       dtype='object')
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1781474 entries, 0 to 1781473
# Data columns (total 19 columns):
#  #   Column               Dtype
# ---  ------               -----
#  0   trip_id              int64
#  1   duration             int64
#  2   start_time           object
#  3   end_time             object
#  4   start_station        int64
#  5   end_station          int64
#  6   bike_id              object
#  7   plan_duration        int64
#  8   trip_route_category  object
#  9   passholder_type      object
#  10  bike_type            object
#  11  Date_s               object
#  12  Weekday_s            int64
#  13  Hour_s               int64
#  14  Date_e               object
#  15  Weekday_e            int64
#  16  Hour_e               int64
#  17  start_coordinates    object
#  18  end_coordinates      object
# dtypes: int64(9), object(10)
# memory usage: 258.2+ MB

# %%
# unique start station coordinations
unique_coordinates = Phil[["start_coordinates", "start_station"]].drop_duplicates().values.tolist()
print (unique_coordinates)
amount = len(unique_coordinates)
print (amount)
# Out:
# [['39.943909,-75.167351', 3125], ['39.95472,-75.183228', 3022], ['39.94561,-75.173477', 3066], ['39.947922,-75.162369', 3045], ['39.947319,-75.156952', 3052], ['39.955231,-75.166199', 3201], ['39.97121,-75.159698', 3039], ['39.953651,-75.14045', 3124], ['39.942181,-75.177467', 3012], ['39.96439,-75.179871', 3057], ['39.947109,-75.166183', 3010], ['39.964371,-75.165817', 3204], ['39.963791,-75.18158', 3212], ['39.93549,-75.167107', 3068], ['39.95425,-75.177612', 3061], ['39.948219,-75.209084', 3024], ['39.980049,-75.15522', 3031], ['39.940609,-75.149582', 3028], ['39.928139,-75.165154', 3164], ['39.953548,-75.171921', 3078], ['39.984921,-75.156677', 3210], ['39.962502,-75.174202', 3054], ['39.955109,-75.209869', 3074], ['39.928841,-75.170212', 3150], ['39.934311,-75.160423', 3098], ['39.942951,-75.159554', 3101], ['39.940769,-75.172272', 3203], ['39.953812,-75.174072', 3156], ['39.96664,-75.192093', 3104], ['39.940182,-75.154419', 3155], ['39.964111,-75.19973', 3067], ['39.96244,-75.161209', 3059], ['39.93935,-75.157158', 3030], ['39.945171,-75.159927', 3007], ['39.953732,-75.218246', 3112], ['39.946331,-75.1698', 3063], ['39.948551,-75.190071', 3020], ['39.950249,-75.160278', 3167], ['39.94595,-75.184753', 3162], ['39.93082,-75.174744', 3043], ['39.937038,-75.150383', 3069], ['39.945271,-75.17971', 3032], ['39.953388,-75.154259', 3050], ['39.925522,-75.169
 3041], ['39.958858,-75.173691', 3014], ['39.952202,-75.20311', 3006], ['39.947922,-75.162369', 3045], ['39.954048,-75.167831', 3205], ['39.96674,-75.207993', 3119], ['39.93401,-75.15094', 3099], ['39.950481,-75.193237', 3208], ['39.95174,-75.170631', 3206], ['39.954239,-75.161377', 3037], ['39.972351,-75.134453', 3166], ['39.960621,-75.139832', 3070], ['39.97414,-75.180222', 3121], ['39.96143,-75.15242', 3073], ['39.951969,-75.179428', 3062], ['39.953548,-75.171921', 3078], ['39.953732,-75.218246', 3112], ['39.954029,-75.149834', 3019], ['39.951118,-75.154572', 3055], ['39.953651,-75.14045', 3124], ['39.951691,-75.158882', 3185], ['39.987171,-75.174767', 3196], ['39.962711,-75.194191', 3035], ['39.948551,-75.190071', 3020], ['39.938869,-75.166634', 3213], ['39.927769,-75.151031', 3100], ['39.928139,-75.165154', 3164], ['39.978882,-75.133392', 3097], ['39.95071,-75.149208', 3047], ['39.9538,-75.194794', 3029], ['39.988369,-75.187012', 3093], ['39.89307,-75.171677', 3186], ['39.977791,-75.213226', 3111], ['39.953781,-75.163742', 3004], ['39.991192,-75.179749', 3096], ['39.89629,-75.17514', 3181], ['39.96207,-75.141113',  ...
# 198

# %%
#coordinates
min_max = (Phil['start_coordinates'].min(), Phil['start_coordinates'].max())
print (min_max)

lat = (Phil2['start_lat'].min() + Phil2['start_lat'].max()) /2
print (lat)
lon = (Phil2['start_lon'].min() + Phil2['start_lon'].max()) / 2
print (lon)
# Out:
# ('39.889938,-75.176788', '40.01112,-75.192871')
# 39.950529
# -75.17551449999999

# %%
start_dict = dict(Phil)

# %%
map = folium.Map(location=[39.9505, -75.1755], zoom_start = 12)
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_3da7e64236fd596b5d7a28041670948b {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_3da7e64236fd596b5d7a28041670948b&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_3da7e64236fd596b5d7a28041670948b = L.map(
#                 &quot;map_3da7e64236fd596b5d7a28041670948b&quot;,
#                 {
#                     center: [39.9505, -75.1755],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_016033eec63cbdb5d95c3d6066553cc7 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_3da7e64236fd596b5d7a28041670948b);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# map with all stations
map = folium.Map(location=[39.95, -75.14], zoom_start = 12)

for start_coordinates, start_station in unique_coordinates:
    
    
    lat, lon = start_coordinates.split(",")
    lat = float(lat)
    lon = float(lon)
    
 
    
    if np.isnan(lat) or np.isnan(lon):
        continue 
        
    folium.Marker(location = [lat, lon],
                  popup= f"{start_station}"
                   ).add_to(map)
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_6807014d63b3f41187a0bc0a5bb7eb55 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_6807014d63b3f41187a0bc0a5bb7eb55&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_6807014d63b3f41187a0bc0a5bb7eb55 = L.map(
#                 &quot;map_6807014d63b3f41187a0bc0a5bb7eb55&quot;,
#                 {
#                     center: [39.95, -75.14],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_224ff2f202c3238ddf73e6cacaf3f8ce = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_6807014d63b3f41187a0bc0a5bb7eb55);
#
#
#             var marker_992fdb187bc5a1690b0780a23ebba79e = L.marker(
#                 [39.943909, -75.167351],
#                 {}
#             ).addTo(map_6807014d63b3f41187a0bc0a5bb7eb55);
#
#
#         var popup_39f854a2ef125439bb92168339bee0df = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_4ff3442e8310d77124fdc87e4f651f58 = $(`&lt;div id=&quot;html_4ff3442e8310d77124fdc87e4f651f58&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;3125&lt;/div&gt;`)[0];
#                 popup_39f854a2ef125439bb92168339bee0df.setContent(html_4ff3442e8310d77124fdc87e4f651f58);
#
#
#
#         marker_992fdb187bc5a1690b0780a23ebba79e.bindPopup(popup_39f854a2ef125439bb92168339bee0df)
#         ;
#
#
#
#
#             var marker_ff8c22839fad8efdb1510e1bc7d83c3e = L.marker(
#                 [39.95472, -75.183228],
#                 {}
#             ).addTo(map_6807014d63b3f41187a0bc0a5bb7eb55);
#
#
#         var popup_d2b484c41cb4d64afa32edd29ccbe8dc = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_564b10ba8ca514465eb717569dbb18a8 = $(`&lt;div id=&quot;html_564b10ba8ca514465eb717569dbb18a8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;3022&lt;/div&gt;`)[0];
#                 popup_d2b484c41cb4d64afa32edd29ccbe8dc.setContent(html_564b10ba8ca514465eb717569dbb18a8);
#
#
#
#         marker_ff8c22839fad8efdb1510e1bc7d83c3e.bindPopup(popup_d2b484c41cb4d64afa32edd29ccbe8dc)
#         ;
#
#
#
#
#             var marker_d3c078df18d5f5252520dfa3b52508b6 = L.marker(
#                 [39.94561, -75.173477],
#                 {}
#             ).addTo(map_6807014d63b3f41187a0bc0a5bb7eb55);
#
#
#         var popup_072a66362307bb398ea76754a492a749 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_a33871ab1958e017c314c0b4152ddfd4 = $(`&lt;div id=&quot;html_a33871ab1958e017c314c0b4152ddfd4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;3066&lt;/div&gt;`)[0];
#                 popup_072a66362307bb398ea76754a492a749.setContent(html_a33871ab1958e017c314c0b4152ddfd4);
#
#
#
#         marker_d3c078df18d5f5252520dfa3b52508b6.bindPopup(popup_072a66362307bb398ea76754a492a749)
#         ;
#
#
#
#
#             var marker_501b18cdf22f6141da34072fb1b3a9c2 = L.marker(
#                 [39.947922, -75.162369],
#                 {}
#             ).addTo(map_6807014d63b3f41187a0bc0a5bb7eb55);
#
#
#         var popup_d742a69bb533fd6ab2c1c75b2633d864 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_f5864e15154d1aab82a0169d9d01edf8 = $(`&lt;div id=&quot;html_f5864e15154d1aab82a0169d9d01edf8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;3045&lt;/div&gt;`)[0];
#                 popup_d742a69bb533fd6ab2c1c75b2633d864.setContent(html_f5864e15154d1aab82a0169d9d01edf8);
#
#
#
#         marker_501b18cdf22f6141da34072fb1b3a9c2.bindPopup(popup_d742a69bb533fd6ab2c1c75b2633d864)
#         ;
#
#
#
#
#             var marker_b69febf9311d35166bc6c37e162e0e44 = L.marker(
#                 [39.947319, -75.156952],
#                 {}
#             ).addTo(map_6807014d63b3f41187a0bc0a5bb7eb55);
#
#
#         var popup_3663fdda648717650761d56ba5d2bcb2 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_fbc1e7c04808c19ffd1d2df1d682e58e = $(`&lt;div id=&quot;html_fbc1e7c04808c19ffd1d2df1d682e58e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;3052&lt;/div&gt;`)[0];
#                 popup_3663fdda648717650761d56ba5d2bcb2.setContent(html_fbc1e7c04808c19ffd1d2df1d682e58e);
#
#
#
#         marker_b69febf9311d35166bc6c37e162e0e44.bindPopup(popup_3663fdda648717650761d56ba5d2bcb2)
#         ;
#
#
#
#
#             var marker_1fc3f2d6b82c1b56563110fd8250c8b2 = L.marker(
#                 [39.955231, -75.166199],
#                 {}
#             ).addTo(map_6807014d63b3f41187a0b

# %%
# counter how many starts at station 
map2 = folium.Map(location=[39.95, -75.14], zoom_start = 12)


start_counter  = Counter(Phil['start_station'])
start_counter_list = list(start_counter.items())
start_counter_list.sort(key=lambda x: x[1], reverse=True)

for station, count in start_counter_list:
    print(f"Station {station}: {count}")

station_dict_start = dict(Phil.start_station.value_counts().sort_index())
#print(station_dict_start)


color_palette = ['darkred', 'red', 'lightred', 'white', 'lightblue', 'blue', 'darkblue']


for start_coordinates, start_station in unique_coordinates:
    
    
    lat, lon = start_coordinates.split(",")
    lat = float(lat)
    lon = float(lon)

        
    if np.isnan(lat) or np.isnan(lon):
        continue 
        
    count = start_counter[start_station]
    popup_message = f"Station: {start_station}<br>Frequency: {count}"
    
    color_index = min(int(count / 4000), len(color_palette) - 1)
    marker_color = color_palette[color_index]

    
    
    folium.Marker(location = [lat, lon],
                  popup= popup_message,
                  icon=folium.Icon(color=marker_color)
                   ).add_to(map2)
    
map2
# Out:
# Station 3010: 31318
# Station 3190: 29064
# Station 3032: 28215
# Station 3202: 27807
# Station 3007: 27155
# Station 3208: 26628
# Station 3168: 26107
# Station 3167: 25500
# Station 3045: 25457
# Station 3052: 25415
# Station 3054: 25316
# Station 3212: 24495
# Station 3101: 22805
# Station 3066: 22598
# Station 3028: 22224
# Station 3046: 21513
# Station 3102: 21251
# Station 3185: 20683
# Station 3022: 20473
# Station 3057: 20268
# Station 3012: 19888
# Station 3154: 19341
# Station 3063: 17961
# Station 3020: 16960
# Station 3207: 16890
# Station 3021: 16889
# Station 3029: 16772
# Station 3009: 16739
# Station 3018: 16329
# Station 3061: 16125
# Station 3203: 15989
# Station 3206: 15964
# Station 3037: 15864
# Station 3078: 15743
# Station 3125: 15647
# Station 3033: 15641
# Station 3163: 15354
# Station 3058: 15276
# Station 3006: 14904
# Station 3114: 14626
# Station 3030: 14620
# Station 3238: 14549
# Station 3100: 14272
# Station 3040: 14150
# Station 3244: 14111
# Station 3182: 13998
# Station 3160: 13943
# Station 3055: 13890
# Station 3034: 13838
# Station 3064: 13774
# Station 3047: 13674
# Station 3050: 13167
# Station 3108: 13153
# Station 3161: 12994
# Station 3059: 12870
# Station 3035: 12855
# Station 3156: 12124
# Station 3051: 12014
# Station 3201: 11953
# Station 3026: 11754
# Station 3155: 11741
# Station 3075: 11719
# Station 3068: 11561
# Station 3043: 11421
# Station 3159: 11374
# Station 3116: 11373
# Station 3049: 11370
# Station 3025: 11170
# Station 3169: 11168
# Station 3069: 10619
# Station 3038: 10369
# Station 3053: 10247
# Station 3158: 10198
# Station 3074: 10150
# Station 3098: 9991
# Station 3255: 9916
# Station 3164: 9774
# Station 3256: 9746
# Station 3204: 9697
# Station 3205: 9644
# Station 3088: 9190
# Station 3162: 9173
# Station 3121: 9078
# Station 3073: 9064
# Station 3056: 9056
# Station 3157: 9030
# Station 3039: 8993
= L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;white&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_2a61ed88f15cc39655ed0fe1c4357ad5.setIcon(icon_b4a4eeef2b5611d77198f0c3ff393753);
#
#
#         var popup_e21499e912d889936be371eba218f0b3 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_863b1b14e4541d6f762396a180521675 = $(`&lt;div id=&quot;html_863b1b14e4541d6f762396a180521675&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Station: 3125&lt;br&gt;Frequency: 15647&lt;/div&gt;`)[0];
#                 popup_e21499e912d889936be371eba218f0b3.setContent(html_863b1b14e4541d6f762396a180521675);
#
#
#
#         marker_2a61ed88f15cc39655ed0fe1c4357ad5.bindPopup(popup_e21499e912d889936be371eba218f0b3)
#         ;
#
#
#
#
#             var marker_d9f1f1dea4056841fda6cc5171c4fd6b = L.marker(
#                 [39.95472, -75.183228],
#                 {}
#             ).addTo(map_74ab8275174d173cbbc7a03cb4d6f3c8);
#
#
#             var icon_7533f06b8f739dd9ca524fb92b126b03 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_d9f1f1dea4056841fda6cc5171c4fd6b.setIcon(icon_7533f06b8f739dd9ca524fb92b126b03);
#
#
#         var popup_89e2f0d8221721d0c1ca052d3fe06896 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_62a8a4c05314e05260bcf9b560a9cd29 = $(`&lt;div id=&quot;html_62a8a4c05314e05260bcf9b560a9cd29&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Station: 3022&lt;br&gt;Frequency: 20473&lt;/div&gt;`)[0];
#                 popup_89e2f0d8221721d0c1ca052d3fe06896.setContent(html_62a8a4c05314e05260bcf9b560a9cd29);
#
#
#
#         marker_d9f1f1dea4056841fda6cc5171c4fd6b.bindPopup(popup_89e2f0d8221721d0c1ca052d3fe06896)
#         ;
#
#
#
#
#             var marker_8476a64bd59e6c547200f9eb62abdb2e = L.marker(
#                 [39.94561, -75.173477],
#                 {}
#             ).addTo(map_74ab8275174d173cbbc7a03cb4d6f3c8);
#
#
#             var icon_5f508bfd41799b71a4c04cf9176fef2e = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_8476a64bd59e6c547200f9eb62abdb2e.setIcon(icon_5f508bfd41799b71a4c04cf9176fef2e);
#
#
#         var popup_ea07ab2cf595e53aad9e24a380eabeb3 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_29b472703338d97b121a5b1f4731a642 = $(`&lt;div id=&quot;html_29b472703338d97b121a5b1f4731a642&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Station: 3066&lt;br&gt;Frequency: 22598&lt;/div&gt;`)[0];
#                 popup_ea07ab2cf595e53aad9e24a380eabeb3.setContent(html_29b472703338d97b121a5b1f4731a642);
#
#
#
#         marker_8476a64bd59e6c547200f9eb62abdb2e.bindPopup(popup_ea07ab2cf595e53aad9e24a380eabeb3)
#         ;
#
#
#
#
#             var marker_3195114456226ba015c42aa707bfa5b0 = L.marker(
#                 [39.947922, -75.162369],
#                 {}
#             ).addTo(map_74ab8275174d173cbbc7a03cb4d6f3c8);
#
#
#             var icon_7793a9191476eb8acf3616398381ff44 = L.AwesomeMarkers.icon(
#                 {&qu

# %% [raw]
# It is only possible to use fixed colors with folium.
# So we build a color scale from dark red to dark blue
#
# dark red lowest value to dark blue highest value
# dark red: 0 - 1999
# red 2000 - 5999
# light red 6000 - 9999
# white 10000 - 13999
# lightblue 14000 - 17999
# blue 18000 - 21999
# darkblue 22000+

# %%
# counter how many ends at station - scale dark red to dark blue 
map3 = folium.Map(location=[39.95, -75.14], zoom_start = 12)


end_counter  = Counter(Phil['end_station'])
end_counter_list = list(end_counter.items())
end_counter_list.sort(key=lambda x: x[1], reverse=True)

#for station, count in end_counter_list:
#    print(f"Station {station}: {count}")

station_dict_end = dict(Phil.end_station.value_counts().sort_index())
#print(station_dict_end)


color_palette = ['darkred', 'red', 'lightred', 'white', 'lightblue', 'blue', 'darkblue']


for end_coordinates, end_station in unique_coordinates_end:
    
    
    lat, lon = end_coordinates.split(",")
    lat = float(lat)
    lon = float(lon)

        
    if np.isnan(lat) or np.isnan(lon):
        continue 
        
    count = end_counter[end_station]
    popup_message = f"Station: {end_station}<br>Frequency: {count}"
    
    color_index = min(int(count / 4000), len(color_palette) - 1)
    marker_color = color_palette[color_index]

    
    
    folium.Marker(location = [lat, lon],
                  popup= popup_message,
                  icon=folium.Icon(color=marker_color)
                   ).add_to(map3)
    

map3
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_37e5e6bc00f9755519e36aed06229e1c {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_37e5e6bc00f9755519e36aed06229e1c&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_37e5e6bc00f9755519e36aed06229e1c = L.map(
#                 &quot;map_37e5e6bc00f9755519e36aed06229e1c&quot;,
#                 {
#                     center: [39.95, -75.14],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_b960fa785ab955730c2e60a19bebdb10 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_37e5e6bc00f9755519e36aed06229e1c);
#
#
#             var marker_b958970165cf01f9628a7ffd8401709a = L.marker(
#                 [39.925449, -75.159538],
#                 {}
#             ).addTo(map_37e5e6bc00f9755519e36aed06229e1c);
#
#
#             var icon_504d4c12a33b9765f9bf35648b785138 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;lightred&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_b958970165cf01f9628a7ffd8401709a.setIcon(icon_504d4c12a33b9765f9bf35648b785138);
#
#
#         var popup_1abb13d06e48b179aef678768cb45d57 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_aac04ac1839840247e7176dc90442491 = $(`&lt;div id=&quot;html_aac04ac1839840247e7176dc90442491&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Station: 3157&lt;br&gt;Frequency: 9627&lt;/div&gt;`)[0];
#                 popup_1abb13d06e48b179aef678768cb45d57.setContent(html_aac04ac1839840247e7176dc90442491);
#
#
#
#         marker_b958970165cf01f9628a7ffd8401709a.bindPopup(popup_1abb13d06e48b179aef678768cb45d57)
#         ;
#
#
#
#
#             var marker_8c712c4d3cbd1f7419ba6991ab1f334c = L.marker(
#                 [39.947109, -75.166183],
#                 {}
#             ).addTo(map_37e5e6bc00f9755519e36aed06229e1c);
#
#
#             var icon_db83c0e534a664fc1eaaec591778d7e0 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;darkblue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_8c712c4d3cbd1f7419ba6991ab1f334c.setIcon(icon_db83c0e534a664fc1eaaec591778d7e0);
#
#
#         var popup_6d85a61bdcd13370c773c5e8a3199e2d = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_b4b7cd1de373cc4dbb8a2c9b18bdf01d = $(`&lt;div id=&quot;html_b4b7cd1de373cc4dbb8a2c9b18bdf01d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Station: 3010&lt;br&gt;Frequency: 31034&lt;/div&gt;`)[0];
#                 popup_6d85a61bdcd13370c773c5e8a3199e2d.setContent(html_b4b7cd1de373cc4dbb8a2c9b18bdf01d);
#
#
#
#         marker_8c712c4d3cbd1f7419ba6991ab1f334c.bindPopup(popup_6d85a61bdcd13370c773c5e8a3199e2d)
#         ;
#
#
#
#
#             var marker_502afea09060ac2450d91daffce49ee9 = L.marker(
#                 [39.955231, -75.166199],
#                 {}
#             ).addTo(map_37e5e6bc00f9755519e36aed06229e1c);
#
#
#             var icon_18c86575b7dbeecff08490e1fe5e01c6 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;white&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_502afea09060ac2450d91daffce49ee9.setIcon(icon_18c86575b7dbeecff08490e1fe5e01c6);
#
#
#         var popup_b51965f938339727bb257e66db541228 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_ad0187df0bc3456cf90beee3375025cc = $(`&lt;div id=&quot;html_ad0187df0bc3456cf90beee3375025cc&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Station: 3201&lt;br&gt;Frequency: 12385&lt;/div&gt;`)[0];
#                 popup_b51965f938339727bb257e66db541228.setContent(html_ad0187df0bc3456cf90beee3375025cc);
#
#
#
#         marker_502afea09060ac2450d91daffce49ee9.bindPopup(popup_b51965f938339727bb257e66db541228)
#         ;
#
#
#
#
#             var marker_9cc4805f6461c0f8ff08712f2304a99c = L.marker(
#                 [39.933151, -75.162483],
#                 {}
#             ).addTo(map_37e5e6bc00f9755519e36aed06229e1c);
#
#
#             var icon_243b82a11ab1e267ba1727680162926b = L.AwesomeMarkers.icon(

# %%
# # bikes
unique_bikes = Phil["bike_id"].drop_duplicates().values.tolist()

amount_bikes = len(unique_bikes)
print (amount_bikes)

bike_counter  = Counter(Phil["bike_id"])
bike_counter_list = list(bike_counter.items())
bike_counter_list.sort(key=lambda x: x[1], reverse=False)


# shows how often each bike was rented 

print(bike_counter_list[1186])



for bike_id, count in bike_counter_list:
    print(f"bike_id: {bike_id} : {count}")
# Out:
# 2373
# ('3289', 719)
# bike_id: 19621 : 1
# bike_id: 3309 : 1
# bike_id: WAND_ERIN_47 : 1
# bike_id: WAND_LILRUSS_43 : 1
# bike_id: WAND_PHIL_61 : 1
# bike_id: WAND_CARA_45 : 1
# bike_id: WAND_RUSSEL_46 : 1
# bike_id: 22275 : 1
# bike_id: WAND_DENISE : 1
# bike_id: WAND_CARNIESHA : 1
# bike_id: Cara45 : 2
# bike_id: 23242 : 2
# bike_id: 5407 : 3
# bike_id: 27876 : 3
# bike_id: 26124 : 3
# bike_id: 25356 : 3
# bike_id: 2574 : 4
# bike_id: 27341 : 4
# bike_id: 26484 : 4
# bike_id: 23769 : 5
# bike_id: 25654 : 5
# bike_id: 24941 : 5
# bike_id: 25193 : 5
# bike_id: 27904 : 6
# bike_id: 25971 : 6
# bike_id: 17391 : 7
# bike_id: 23153 : 8
# bike_id: 22964 : 8
# bike_id: 27322 : 8
# bike_id: 26504 : 8
# bike_id: 26388 : 8
# bike_id: 24952 : 9
# bike_id: 25286 : 9
# bike_id: 27386 : 9
# bike_id: 17794 : 10
# bike_id: 26527 : 10
# bike_id: 25758 : 10
# bike_id: 18446 : 11
# bike_id: 25354 : 11
# bike_id: 22882 : 12
# bike_id: 25179 : 12
# bike_id: 5355 : 13
# bike_id: 25313 : 13
# bike_id: 23650 : 14
# bike_id: 25692 : 14
# bike_id: 27088 : 14
# bike_id: 27653 : 14
# bike_id: 27566 : 14
# bike_id: 25960 : 14
# bike_id: 26761 : 14
# bike_id: 25516 : 15
# bike_id: 27849 : 15
# bike_id: 25230 : 17
# bike_id: 14476 : 1616
# bike_id: 14519 : 1617
# bike_id: 17178 : 1618
# bike_id: 14540 : 1620
# bike_id: 14541 : 1620
# bike_id: 18562 : 1621
# bike_id: 5314 : 1627
# bike_id: 11815 : 1627
# bike_id: 14611 : 1629
# bike_id: 21893 : 1629
# bike_id: 14695 : 1630
# bike_id: 14507 : 1630
# bike_id: 11016 : 1630
# bike_id: 11833 : 1634
# bike_id: 14618 : 1636
# bike_id: 14696 : 1637
# bike_id: 5145 : 1638
# bike_id: 14597 : 1639
# bike_id: 11887 : 1641
# bike_id: 11920 : 1641
# bike_id: 18082 : 1642
# bike_id: 14482 : 1643
# bike_id: 14715 : 1644
# bike_id: 14492 : 1647
# bike_id: 16312 : 1648
# bike_id: 14664 : 1649
# bike_id: 18794 : 1649
# bike_id: 14535 : 1650
# bike_id: 14674 : 1651
# bike_id: 14643 : 1654
# bike_id: 14477 : 1659
# bike_id: 14690 : 1664
# bike_id: 18450 : 1667
# bike_id: 16719 : 1673
# bike_id: 11918 : 1677
# bike_id: 14524 : 1677
# bike_id: 11905 : 1678
# bike_id: 19971 : 1678
# bike_id: 14510 : 1682
# bike_id: 14517 : 1683
# bike_id: 14676 : 1688
# bike_id: 14650 : 1694
# bike_id: 17586 : 1699
# bike_id: 18807 : 1700
# bike_id: 11950 : 1703
# bike_id: 19640 : 1704
# bike_id: 17699 : 1711
# bike_id: 11731 : 1713
# bike_id: 18721 : 1714
# bike_id: 14513 : 1715
# bike_id: 5256 : 1718
# bike_id: 5232 : 1721
# bike_id: 19600 : 1725
# bike_id: 19878 : 1733
# bike_id: 18775 : 1742
# bike_id: 16650 : 1744
# bike_id: 14585 : 1747
# bike_id: 16663 : 1755
# bike_id: 14680 : 1756
# bike_id: 18262 : 1757
# bike_id: 19716 : 1774
# bike_id: 19503 : 1779
# bike_id: 14596 : 1786
# bike_id: 19126 : 1788
# bike_id: 14595 : 1790
# bike_id: 16570 : 1802
# bike_id: 21880 : 1842
# bike_id: 19327 : 1846
# bike_id: 16772 : 1857
# bike_id: 19757 : 1863
# bike_id: 19771 : 1864
# bike_id: 17081 : 1874
# bike_id: 19530 : 1876
# bike_id: 16625 : 1935

# %%
# Top 10 trips
popular_trips_group = Phil.groupby(["start_station", "end_station"]).size()
popular_trips = pd.DataFrame(popular_trips_group[popular_trips_group > 1000], columns=["count"])
popular_trips.reset_index(inplace=True)
popular_trips_sorted = popular_trips.sort_values(by= "count", ascending=False)
popular_trips_sorted.reset_index(drop=True, inplace=True)
popular_trips_sorted.head(20)
# Out:
#     start_station  end_station  count
# 0            3212         3212   7275
# 1            3202         3202   5116
# 2            3057         3057   3242
# 3            3208         3032   2409
# 4            3035         3009   2308
# 5            3020         3032   2079
# 6            3057         3212   1927
# 7            3009         3035   1856
# 8            3186         3186   1650
# 9            3054         3102   1622
# 10           3102         3102   1608
# 11           3049         3049   1596
# 12           3163         3163   1582
# 13           3035         3249   1542
# 14           3032         3208   1512
# 15           3154         3167   1447
# 16           3102         3054   1420
# 17           3006         3208   1328
# 18           3249         3035   1279
# 19           3163         3212   1269

# %%
#duration = 1440 uncleaned data
count_true = (Phil2["duration"] == 1440).sum()
print(count_true)
# Out:
# 801

# %%
#duration = 1440 clean data
count_true = (Phil["duration"] == 1440).sum()
print(count_true)
# Out:
# 320

# %%
# merged_data bikes with 1440 duration
Phil_1440minutes = Phil2[Phil2["duration"] == 1440 ]
selected_columns = ['start_station','start_lat', 'start_lon', "bike_type"]


start_station_count = Phil_1440minutes["start_station"].value_counts()

#print("duration of 1440 minutes for column 'start_station':")
#print(start_station_count.to_string())

# %%
# cleaned data bikes with 1440 duration
Phil_1440minutes = Phil[Phil["duration"] == 1440 ]
selected_columns = ['start_station', "bike_type"]


start_station_count = Phil_1440minutes["start_station"].value_counts()

#print("duration of 1440 minutes for column 'start_station':")
#print(start_station_count.to_string())

# %%
# map for duration == 1440 on uncleaned dataset
map4 = folium.Map(location=[39.9505, -75.1755], zoom_start = 12)

for start_coordinates, start_station in unique_coordinates:
    
    
    lat, lon = start_coordinates.split(",")
    lat = float(lat)
    lon = float(lon)
    
    if np.isnan(lat) or np.isnan(lon):
        continue 
        
    stations_more_10_stolen = [3057, 3097, 3185, 3202, 3046, 3056, 3049, 3210, 3110, 3212, 3190, 3004, 3108, 3037, 3158, 3018, 3160, 3124]
   
    
    if start_station in stations_more_10_stolen:
        folium.Marker(location = [lat, lon],
                  popup= f"{start_station}",
                  icon=folium.Icon(color="red")
                   ).add_to(map4)
    
    else:
        folium.Marker(location = [lat, lon],
                  popup= f"{start_station}",
                  icon=folium.Icon(color="green")
                   ).add_to(map4)

    
map4
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_254af563abcf3cb847e4bf00f468a530 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_254af563abcf3cb847e4bf00f468a530&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_254af563abcf3cb847e4bf00f468a530 = L.map(
#                 &quot;map_254af563abcf3cb847e4bf00f468a530&quot;,
#                 {
#                     center: [39.9505, -75.1755],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_8b2c145d4f5fce5dfcc97aca33509479 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_254af563abcf3cb847e4bf00f468a530);
#
#
#             var marker_98d396353696fa1ee518ce4ba4617baa = L.marker(
#                 [39.943909, -75.167351],
#                 {}
#             ).addTo(map_254af563abcf3cb847e4bf00f468a530);
#
#
#             var icon_e2b6ece37a1dd5445d6fd299062bfe46 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_98d396353696fa1ee518ce4ba4617baa.setIcon(icon_e2b6ece37a1dd5445d6fd299062bfe46);
#
#
#         var popup_3724ec877923d867bbdac2a4dede0144 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_2f51c5669838b7d3f569eba59e4720a4 = $(`&lt;div id=&quot;html_2f51c5669838b7d3f569eba59e4720a4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;3125&lt;/div&gt;`)[0];
#                 popup_3724ec877923d867bbdac2a4dede0144.setContent(html_2f51c5669838b7d3f569eba59e4720a4);
#
#
#
#         marker_98d396353696fa1ee518ce4ba4617baa.bindPopup(popup_3724ec877923d867bbdac2a4dede0144)
#         ;
#
#
#
#
#             var marker_16115b8c4fa583a6918b91166257325a = L.marker(
#                 [39.95472, -75.183228],
#                 {}
#             ).addTo(map_254af563abcf3cb847e4bf00f468a530);
#
#
#             var icon_795c14fc2f7ecb8d509239164885148f = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_16115b8c4fa583a6918b91166257325a.setIcon(icon_795c14fc2f7ecb8d509239164885148f);
#
#
#         var popup_971e932fc86f17f25fa824dbdc7dbc3c = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_09e381179c99e83d8c88090825baf4d9 = $(`&lt;div id=&quot;html_09e381179c99e83d8c88090825baf4d9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;3022&lt;/div&gt;`)[0];
#                 popup_971e932fc86f17f25fa824dbdc7dbc3c.setContent(html_09e381179c99e83d8c88090825baf4d9);
#
#
#
#         marker_16115b8c4fa583a6918b91166257325a.bindPopup(popup_971e932fc86f17f25fa824dbdc7dbc3c)
#         ;
#
#
#
#
#             var marker_a90a947a5a2af4801510a8d5a00ee4e3 = L.marker(
#                 [39.94561, -75.173477],
#                 {}
#             ).addTo(map_254af563abcf3cb847e4bf00f468a530);
#
#
#             var icon_fb12b707416d51af3373a222e191541c = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_a90a947a5a2af4801510a8d5a00ee4e3.setIcon(icon_fb12b707416d51af3373a222e191541c);
#
#
#         var popup_866a94e10c40a596b1fbae1c2418961c = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_ad95f9a2083c7aeb4d91d4ff62231372 = $(`&lt;div id=&quot;html_ad95f9a2083c7aeb4d91d4ff62231372&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;3066&lt;/div&gt;`)[0];
#                 popup_866a94e10c40a596b1fbae1c2418961c.setContent(html_ad95f9a2083c7aeb4d91d4ff62231372);
#
#
#
#         marker_a90a947a5a2af4801510a8d5a00ee4e3.bindPopup(popup_866a94e10c40a596b1fbae1c2418961c)
#         ;
#
#
#
#
#             var marker_fcbeace6068672e677f902853e25bda5 = L.marker(
#                 [39.947922, -75.162369],
#                 {}
#             ).addTo(map_254af563abcf3cb847e4bf00f468a530);
#
#
#             var icon_a43499ddf2822a1f1c4d9232d2831f44 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;icon

# %%
# average duration from start station
Phil_avg_duration = Phil.groupby(["start_station"])["duration"].mean()

print(Phil_avg_duration)
# Out:
# start_station
# 3004    24.112788
# 3005    21.169108
# 3006    19.815217
# 3007    14.590131
# 3008    16.751515
# 3009    16.723341
# 3010    15.937320
# 3011    17.099308
# 3012    13.093976
# 3013    16.748751
# 3014    17.625294
# 3015    18.881664
# 3016    17.475516
# 3017    21.478941
# 3018    21.416253
# 3019    20.304702
# 3020    12.611675
# 3021    15.271242
# 3022    16.934353
# 3024    24.264880
# 3025    13.889436
# 3026    18.746129
# 3028    17.384089
# 3029    16.987956
# 3030    13.776881
# 3031    21.104337
# 3032    13.638845
# 3033    15.068985
# 3034    14.300766
# 3035    13.728510
# 3037    18.607728
# 3038    14.232616
# 3039    18.313466
# 3040    14.626007
# 3041    22.433333
# 3043    15.619473
# 3045    17.073339
# 3046    19.339237
# 3047    22.555872
# 3049    27.628320
# 3050    18.812410
# 3051    18.418761
# 3052    14.348338
# 3053    17.716600
# 3054    16.297954
# 3055    20.924838
# 3056    20.944457
# 3057    36.364367
# 3058    15.725910
# 3059    17.012354
# 3060    19.293828
# 3061    15.636403
# 3062    17.337345
# 3063    13.160626
# 3064    14.266807
# 3065    19.089969
# 3066    12.462563
# 3067    19.318748
# 3068    15.890321
# 3069    15.455128
# 3070    20.270327
# 3071    18.532936
# 3072    20.055508
         Phil.at[index, "season"] = "summer"
    elif 9 <= month <= 11:
         Phil.at[index, "season"] = "autumn"
    else:
         Phil.at[index, "season"] = "winter"
    
# because of long computing time build new dataframe for each season
for season in Phil["season"].unique():
    season_Phil = Phil[Phil["season"] == season]
    season_Phil.to_csv(f"{season}.csv", index=False)

# %%
#read season csv
Phil_winter = pd.read_csv('winter.csv', low_memory=False)
Phil_spring = pd.read_csv('spring.csv', low_memory=False)
Phil_summer = pd.read_csv('summer.csv', low_memory=False)
Phil_autumn = pd.read_csv('autumn.csv', low_memory=False)

# %%
#unique data winter
Phil_winter.nunique()
# Out:
# trip_id                207215
# duration                  613
# start_time             114828
# end_time               114604
# start_station             198
# end_station               198
# bike_id                  2200
# plan_duration               5
# trip_route_category         2
# passholder_type             4
# bike_type                   2
# Date_s                    180
# Weekday_s                   7
# Hour_s                     24
# Date_e                    184
# Weekday_e                   7
# Hour_e                     24
# start_coordinates         196
# end_coordinates           196
# season                      1
# dtype: int64

# %%
#unique data spring
Phil_spring.nunique()
# Out:
# trip_id                392691
# duration                  906
# start_time             159129
# end_time               158430
# start_station             181
# end_station               181
# bike_id                  1700
# plan_duration               4
# trip_route_category         2
# passholder_type             4
# bike_type                   2
# Date_s                    184
# Weekday_s                   7
# Hour_s                     24
# Date_e                    187
# Weekday_e                   7
# Hour_e                     24
# start_coordinates         181
# end_coordinates           181
# season                      1
# dtype: int64

# %%
#unique data summer
Phil_summer.nunique()
# Out:
# trip_id                551450
# duration                  987
# start_time             189348
# end_time               188675
# start_station             187
# end_station               187
# bike_id                  1963
# plan_duration               4
# trip_route_category         2
# passholder_type             4
# bike_type                   2
# Date_s                    184
# Weekday_s                   7
# Hour_s                     24
# Date_e                    186
# Weekday_e                   7
# Hour_e                     24
# start_coordinates         187
# end_coordinates           187
# season                      1
# dtype: int64

# %%
#unique data autumn
Phil_autumn.nunique()
# Out:
# trip_id                527794
# duration                  870
# start_time             179129
# end_time               178921
# start_station             194
# end_station               193
# bike_id                  2120
# plan_duration               4
# trip_route_category         2
# passholder_type             3
# bike_type                   2
# Date_s                    182
# Weekday_s                   7
# Hour_s                     24
# Date_e                    184
# Weekday_e                   7
# Hour_e                     24
# start_coordinates         192
# end_coordinates           191
# season                      1
# dtype: int64

# %%
#trips on each season
trips_winter = Phil_winter["trip_id"].nunique()
trips_spring = Phil_spring["trip_id"].nunique()
trips_summer = Phil_summer["trip_id"].nunique()
trips_autumn = Phil_autumn["trip_id"].nunique()

print(f"Winter: {trips_winter}\nSpring: {trips_spring}\nSummer: {trips_summer}\nAutumn: {trips_autumn}")
# Out:
# Winter: 207215
# Spring: 392691
# Summer: 551450
# Autumn: 527794

# %%
# Usage per hour winter
hour = Phil_winter.groupby(['Hour_s'])['trip_id'].nunique()
fig, ax = plt.subplots(figsize=(16, 9), dpi=110)
ax.bar(hour.index, hour)
plt.title("No. of bike trips per hour in winter")
plt.xlabel("Hour")
plt.ylabel("Number of trips")

fig.savefig("bike_trips_per_hour_winter.jpg")
plt.show()

# %%
# Usage per hour spring
hour = Phil_spring.groupby(['Hour_s'])['trip_id'].nunique()
fig, ax = plt.subplots(figsize=(16, 9), dpi=110)
ax.bar(hour.index, hour)
plt.title("No. of bike trips per hour in spring")
plt.xlabel("Hour")
plt.ylabel("Number of trips")

fig.savefig("bike_trips_per_hour_spring.jpg")
plt.show()

# %%
# Usage per hour summer
hour = Phil_summer.groupby(['Hour_s'])['trip_id'].nunique()
fig, ax = plt.subplots(figsize=(16, 9), dpi=110)
ax.bar(hour.index, hour)
plt.title("No. of bike trips per hour in summer")
plt.xlabel("Hour")
plt.ylabel("Number of trips")

fig.savefig("bike_trips_per_hour_summer.jpg")
plt.show()

# %%
# Usage per hour autumn
hour = Phil_autumn.groupby(['Hour_s'])['trip_id'].nunique()
fig, ax = plt.subplots(figsize=(16, 9), dpi=110)
ax.bar(hour.index, hour)
plt.title("No. of bike trips per hour in autumn")
plt.xlabel("Hour")
plt.ylabel("Number of trips")

fig.savefig("bike_trips_per_hour_autumn.jpg")
plt.show()

# %% [markdown]
# As we can see each season is uniformly distributed.
# In this case we should schedule maintenance to seasons winter and spring.

# %%
#boxplot of accumulated usage of bikes in winter
Phil_winter_bp = Phil_winter.groupby("Weekday_s")["trip_id"].cumsum()

plt.figure(figsize=(8, 6))
sns.boxplot(x=Phil_winter["Weekday_s"], y=Phil_winter_bp)
plt.xlabel("Weekday")
plt.ylabel("Accumulated count of trip_id")
plt.title("Usage winter")
plt.xticks(ticks=range(7), labels=["monday", "tuesday", "wednesday", "thursday", "friday", "saturday", "sunday"])

plt.savefig("accumulated_usage_winter_boxplot.jpg")
plt.show()

# %%
Phil_spring_bp = Phil_spring.groupby("Weekday_s")["trip_id"].cumsum()

plt.figure(figsize=(8, 6))
sns.boxplot(x=Phil_spring["Weekday_s"], y=Phil_spring_bp)
plt.xlabel("Weekday")
plt.ylabel("Accumulated count of trip_id")
plt.title("Usage spring")
plt.xticks(ticks=range(7), labels=["monday", "tuesday", "wednesday", "thursday", "friday", "saturday", "sunday"])

plt.savefig("accumulated_usage_spring_boxplot.jpg")
plt.show()

# %%
Phil_summer_bp = Phil_summer.groupby("Weekday_s")["trip_id"].cumsum()

plt.figure(figsize=(8, 6))
sns.boxplot(x=Phil_summer["Weekday_s"], y=Phil_summer_bp)
plt.xlabel("Weekday")
plt.ylabel("Accumulated count of trip_id")
plt.title("Usage summer")
plt.xticks(ticks=range(7), labels=["monday", "tuesday", "wednesday", "thursday", "friday", "saturday", "sunday"])

plt.savefig("accumulated_usage_summer_boxplot.jpg")
plt.show()

# %%
Phil_autumn_bp = Phil_autumn.groupby("Weekday_s")["trip_id"].cumsum()

plt.figure(figsize=(8, 6))
sns.boxplot(x=Phil_autumn["Weekday_s"], y=Phil_autumn_bp)
plt.xlabel("Weekday")
plt.ylabel("Accumulated count of trip_id")
plt.title("Usage autumn")
plt.xticks(ticks=range(7), labels=["monday", "tuesday", "wednesday", "thursday", "friday", "saturday", "sunday"])

plt.savefig("accumulated_usage_autumn_boxplot.jpg")
plt.show()

# %%
#first date for each start station
first_start_station_date = Phil.groupby('start_station')['Date_e'].first().reset_index()
first_start_station_list = first_start_station_date.values.tolist()
first_start_station_date = first_start_station_date.sort_values('Date_e')
first_start_station_date.reset_index(drop=True, inplace=True)

#pd.set_option('display.max_rows', len(first_start_station_date)) #show all rows

first_start_station_date.head() # len(first_start_station_date)
# Out:
#    start_station      Date_e
# 0           3004  2021-01-01
# 1           3153  2021-01-01
# 2           3213  2021-01-01
# 3           3150  2021-01-01
# 4           3125  2021-01-01

# %%
#days of usage for each station
end_date = pd.to_datetime("2022-12-31")
first_start_station_date["days_of_usage"] = (end_date - pd.to_datetime(first_start_station_date['Date_e'])).dt.days

print(first_start_station_date)
# Out:
#      start_station      Date_e  days_of_usage
# 0             3004  2021-01-01            729
# 1             3153  2021-01-01            729
# 2             3213  2021-01-01            729
# 3             3150  2021-01-01            729
# 4             3125  2021-01-01            729
# 5             3124  2021-01-01            729
# 6             3121  2021-01-01            729
# 7             3120  2021-01-01            729
# 8             3119  2021-01-01            729
# 9             3118  2021-01-01            729
# 10            3117  2021-01-01            729
# 11            3116  2021-01-01            729
# 12            3115  2021-01-01            729
# 13            3114  2021-01-01            729
# 14            3112  2021-01-01            729
# 15            3108  2021-01-01            729
# 16            3107  2021-01-01            729
# 17            3106  2021-01-01            729
# 18            3104  2021-01-01            729
# 19            3102  2021-01-01            729
# 20            3101  2021-01-01            729
# 21            3099  2021-01-01            729
# 22            3098  2021-01-01            729
# 23            3086  2021-01-01            729
# 24            3078  2021-01-01            729
# 25            3077  2021-01-01            729
# 26            3075  2021-01-01            729
# 27            3074  2021-01-01            729
# 28            3154  2021-01-01            729
# 29            3072  2021-01-01            729
# 30            3155  2021-01-01            729
# 31            3157  2021-01-01            729
# 32            3208  2021-01-01            729
# 33            3207  2021-01-01            729
# 34            3206  2021-01-01            729
# 35            3205  2021-01-01            729
# 36            3204  2021-01-01            729
# 37            3203  2021-01-01            729
# 38            3202  2021-01-01            729
# 39            3201  2021-01-01            729
# 40            3200  2021-01-01            729
# 41            3197  2021-01-01            729
# 42            3196  2021-01-01            729
# 43            3190  2021-01-01            729
# 44            3187  2021-01-01            729
# 45            3211  2021-01-01            729
# 46            3183  2021-01-01            729
# 47            3182  2021-01-01            729
# 48            3168  2021-01-01            729
# 49            3167  2021-01-01            729
# 50            3166  2021-01-01            729
# 51            3165  2021-01-01            729
# 52            3164  2021-01-01            729
# 53            3163  2021-01-01            729
# 54            3162  2021-01-01            729
# 55            3161  2021-01-01            729
# 56            3160  2021-01-01            729
# 57            3212  2021-01-01            729
# 58            3158  2021-01-01            729
# 59            3156  2021-01-01            729
# 60            3071  2021-01-01            729
# 61            3088  2021-01-01            729
# 62            3069  2021-01-01            729
# 63            3041  2021-01-01            729
# 64            3040  2021-01-01            729
# 65            3039  2021-01-01            729
# 66            3070  2021-01-01            729
# 67            3037  2021-01-01            729
# 68            3035  2021-01-01            729
# 69            3034  2021-01-01            729
# 70            3033  2021-01-01            729
# 167           3257  2021-10-19            438
# 168           3258  2021-10-23            434
# 169           3259  2021-11-05            421
# 170           3261  2021-12-02            394
# 171           3266  2022-02-15            319
# 172           3267  2022-02-17            317
# 173           3263  2022-02-23            311
# 174           3271  2022-03-03            303
# 175           3272  2022-03-11            295
# 176           3265  2022-03-31            275
# 177           3275  2022-04-22            253
# 178           3276  2022-04-22            253
# 179           3273  2022-05-08            237
# 180           3264  2022-05-19            226
# 181           3277  2022-06-25            189
# 182           3278  2022-06-29            185
# 183           3279  2022-07-06            178
# 184           3280  2022-07-13            171
# 185           3282  2022-07-21            163
# 186           3281  2022-07-28            156
# 187           3287  2022-09-07            115
# 188           3286  2022-10-06             86
# 189           3296  2022-10-11             81
# 190           3284  2022-10-25             67
# 191           3291  2022-11-03             58
# 192           3295  2022-11-03             58
# 193           3294  2022-11-09             52
# 194           3298  2022-11-16             45
# 195           3285  2022-11-29             32
# 196           3300  2022-12-07             24
# 197           3299  2022-12-08             23

# %%
# average usage per day for each station to the number of usage days

average_usage_per_day = {}
for start_station, count in start_counter.items():
    days_of_usage = first_start_station_date[first_start_station_date['start_station'] == start_station]['days_of_usage'].values[0]
    average_usage_per_day[start_station] = count / days_of_usage
    
sorted_average_usage_per_day = sorted(average_usage_per_day.items(), key=lambda x: x[1])

for start_station, average_usage in sorted_average_usage_per_day:
    print(f"start_station {start_station}: average daily usage {average_usage}")
# Out:
# start_station 3284: average daily usage 0.835820895522388
# start_station 3282: average daily usage 0.8711656441717791
# start_station 3298: average daily usage 0.9777777777777777
# start_station 3096: average daily usage 1.151098901098901
# start_station 3280: average daily usage 1.2339181286549707
# start_station 3214: average daily usage 1.3813443072702332
# start_station 3240: average daily usage 1.3953068592057762
# start_station 3278: average daily usage 1.4702702702702704
# start_station 3281: average daily usage 1.4871794871794872
# start_station 3291: average daily usage 1.5172413793103448
# start_station 3196: average daily usage 1.5349794238683128
# start_station 3243: average daily usage 1.7190388170055453
# start_station 3277: average daily usage 1.9047619047619047
# start_station 3247: average daily usage 1.9220532319391634
# start_station 3093: average daily usage 1.940934065934066
# start_station 3181: average daily usage 1.967032967032967
# start_station 3300: average daily usage 2.0
# start_station 3183: average daily usage 2.1248285322359397
# start_station 3272: average daily usage 2.183050847457627
# start_station 3113: average daily usage 2.2376373626373627
# start_station 3117: average daily usage 2.246913580246914
# start_station 3271: average daily usage 2.2904290429042904
# start_station 3226: average daily usage 2.351313969571231
# start_station 3285: average daily usage 2.40625
# start_station 3186: average daily usage 2.8035714285714284
# start_station 3251: average daily usage 2.978
# start_station 3213: average daily usage 3.054869684499314
# start_station 3106: average daily usage 3.1042524005486967
# start_station 3287: average daily usage 3.234782608695652
# start_station 3258: average daily usage 3.47926267281106
# start_station 3119: average daily usage 3.5089163237311385
# start_station 3016: average daily usage 3.590659340659341
# start_station 3111: average daily usage 3.614010989010989
# start_station 3253: average daily usage 4.069815195071868
# start_station 3067: average daily usage 4.075445816186557
# start_station 3107: average daily usage 4.126200274348422
# start_station 3267: average daily usage 4.151419558359621
# start_station 3123: average daily usage 4.153846153846154
# start_station 3263: average daily usage 4.372990353697749
# start_station 3192: average daily usage 4.707417582417582
# start_station 3257: average daily usage 4.938356164383562
# start_station 3200: average daily usage 4.968449931412894
# start_station 3241: average daily usage 5.1063829787234045
# start_station 3237: average daily usage 5.130952380952381
# start_station 3184: average daily usage 5.156808803301238
# start_station 3104: average daily usage 5.297668038408779
# start_station 3153: average daily usage 5.403292181069959
# start_station 3279: average daily usage 5.455056179775281
# start_station 3254: average daily usage 5.49247311827957
# start_station 3188: average daily usage 5.550824175824176
# start_station 3250: average daily usage 5.618736383442266
# start_station 3065: average daily usage 5.702331961591221
# start_station 3276: average daily usage 5.798418972332016
# start_station 3246: average daily usage 5.8869731800766285
# start_station 3115: average daily usage 5.968449931412894
# start_station 3275: average daily usage 6.150197628458498
# start_station 3152: average daily usage 6.481430536451169
# start_station 3070: average daily usage 6.545953360768175
# start_station 3008: average daily usage 6.572802197802198
# start_station 3017: average daily usage 6.587912087912088
# start_station 3019: average daily usage 6.739368998628258
# start_station 3118: average daily usage 6.890260631001372
# start_station 3266: average daily usage 6.905956112852665
# start_station 3299: average daily usage 6.913043478260869
# start_station 3011: average daily usage 6.934156378600823
# start_station 3112: average daily usage 6.969821673525377
# start_station 3252: average daily usage 7.228282828282828
# start_station 3259: average daily usage 7.3610451306413305
# start_station 3014: average daily usage 7.58161865569273
# start_station 3097: average daily usage 7.695054945054945
# start_station 3211: average daily usage 7.7407407407407405
# start_station 3233: average daily usage 8.025167785234899
# start_station 3286: average daily usage 8.279069767441861
# start_station 3077: average daily usage 8.39917695473251
# start_station 3013: average daily usage 8.511659807956104
# start_station 3110: average daily usage 8.630494505494505
# start_station 3265: average daily usage 8.909090909090908
# start_station 3166: average daily usage 8.95747599451303
# start_station 3150: average daily usage 8.989026063100138
# start_station 3197: average daily usage 9.0
# start_station 3024: average daily usage 9.05761316872428
# start_station 3209: average daily usage 9.094780219780219
# start_station 3060: average daily usage 9.178326474622772
# start_station 3099: average daily usage 9.246913580246913
# start_station 3210: average daily usage 9.262002743484224
# start_station 3005: average daily usage 9.657967032967033
# start_station 3072: average daily usage 9.662551440329219
# start_station 3187: average daily usage 10.058984910836763
# start_station 3071: average daily usage 10.12071330589849
# start_station 3120: average daily usage 10.554183813443073
# start_station 3062: average daily usage 10.729395604395604
# start_station 3273: average daily usage 11.0
# start_station 3086: average daily usage 11.034293552812072
# start_station 3236: average daily usage 11.046712802768166
# start_station 3031: average daily usage 11.069958847736626
# start_station 3165: average daily usage 11.293552812071331
# start_station 3248: average daily usage 11.385658914728682
# start_station 3004: average daily usage 11.541838134430726
# start_station 3124: average daily usage 11.55281207133059
# start_station 3041: average daily usage 11.563786008230453
# start_station 3015: average daily usage 11.619505494505495
# start_station 3235: average daily usage 11.981387478849408
# start_station 3170: average daily usage 12.317307692307692
# start_station 3039: average daily usage 12.336076817558299
# start_station 3157: average daily usage 12.386831275720164
# start_station 3056: average daily usage 12.422496570644718
# start_station 3073: average daily usage 12.45054945054945
# start_station 3121: average daily usage 12.452674897119342
# start_station 3261: average daily usage 12.48223350253807
# start_station 3162: average daily usage 12.582990397805213
# start_station 3088: average daily usage 12.60631001371742
# start_station 3234: average daily usage 12.609348914858098
# start_station 3249: average daily usage 12.723107569721115
# start_station 3245: average daily usage 13.139925373134329
# start_station 3205: average daily usage 13.229080932784637
# start_station 3204: average daily usage 13.301783264746227
# start_station 3164: average daily usage 13.407407407407407
# start_station 3294: average daily usage 13.653846153846153
# start_station 3098: average daily usage 13.705075445816187
# start_station 3074: average daily usage 13.92318244170096
# start_station 3158: average daily usage 13.989026063100138
# start_station 3053: average daily usage 14.056241426611797
# start_station 3038: average daily usage 14.223593964334706
# start_station 3069: average daily usage 14.566529492455418
# start_station 3025: average daily usage 15.32235939643347
# start_station 3169: average daily usage 15.340659340659341
# start_station 3049: average daily usage 15.59670781893004
# start_station 3116: average daily usage 15.60082304526749
# start_station 3159: average daily usage 15.645116918844566
# start_station 3043: average daily usage 15.666666666666666
# start_station 3068: average daily usage 15.858710562414267
# start_station 3075: average daily usage 16.07544581618656
# start_station 3155: average daily usage 16.10562414266118
# start_station 3201: average daily usage 16.396433470507546
# start_station 3051: average daily usage 16.480109739369
# start_station 3156: average daily usage 16.631001371742112
# start_station 3035: average daily usage 17.633744855967077
# start_station 3059: average daily usage 17.65432098765432
# start_station 3161: average daily usage 17.824417009602193
# start_station 3108: average daily usage 18.042524005486968
# start_station 3050: average daily usage 18.061728395061728
# start_station 3047: average daily usage 18.782967032967033
# start_station 3064: average daily usage 18.89437585733882
# start_station 3034: average daily usage 18.982167352537722
# start_station 3055: average daily usage 19.05349794238683
# start_station 3160: average daily usage 19.126200274348424
# start_station 3182: average daily usage 19.20164609053498
# start_station 3040: average daily usage 19.410150891632373
# start_station 3264: average daily usage 19.548672566371682
# start_station 3100: average daily usage 19.604395604395606
# start_station 3030: average daily usage 20.054869684499312
# start_station 3114: average daily usage 20.06310013717421
# start_station 3006: average daily usage 20.444444444444443
# start_station 3255: average daily usage 20.445360824742266
# start_station 3256: average daily usage 20.914163090128756
# start_station 3058: average daily usage 20.954732510288064
# start_station 3163: average daily usage 21.061728395061728
# start_station 3026: average daily usage 21.140287769784173
# start_station 3033: average daily usage 21.45541838134431
# start_station 3125: average daily usage 21.463648834019203
# start_station 3078: average daily usage 21.59533607681756
# start_station 3037: average daily usage 21.761316872427983
# start_station 3206: average daily usage 21.89849108367627
# start_station 3203: average daily usage 21.93278463648834
# start_station 3061: average daily usage 22.11934156378601
# start_station 3018: average daily usage 22.39917695473251
# start_station 3009: average daily usage 22.99313186813187
# start_station 3029: average daily usage 23.006858710562415
# start_station 3021: average daily usage 23.16735253772291
# start_station 3207: average daily usage 23.16872427983539
# start_station 3020: average daily usage 23.26474622770919
# start_station 3063: average daily usage 24.637860082304528
# start_station 3238: average daily usage 25.17128027681661
# start_station 3244: average daily usage 26.425093632958802
# start_station 3154: average daily usage 26.530864197530864
# start_station 3012: average daily usage 27.281207133058984
# start_station 3057: average daily usage 27.80246913580247
# start_station 3022: average daily usage 28.083676268861453
# start_station 3185: average daily usage 28.410714285714285
# start_station 3295: average daily usage 28.603448275862068
# start_station 3102: average daily usage 29.150891632373114
# start_station 3046: average daily usage 29.550824175824175
# start_station 3028: average daily usage 30.48559670781893
# start_station 3066: average daily usage 30.998628257887518
# start_station 3101: average daily usage 31.282578875171467
# start_station 3296: average daily usage 31.382716049382715
# start_station 3212: average daily usage 33.60082304526749
# start_station 3054: average daily usage 34.72702331961591
# start_station 3052: average daily usage 34.862825788751714
# start_station 3045: average daily usage 34.920438957475994
# start_station 3167: average daily usage 34.97942386831276
# start_station 3168: average daily usage 35.81207133058985
# start_station 3208: average daily usage 36.52674897119341
# start_station 3007: average daily usage 37.249657064471876
# start_station 3202: average daily usage 38.1440329218107
# start_station 3032: average daily usage 38.7037037037037
# start_station 3190: average daily usage 39.86831275720164
# start_station 3010: average daily usage 42.960219478738

# %%
# map with average daily usage

average_usage_df = pd.DataFrame.from_dict(average_usage_per_day, orient="index", columns=["Average_daily_usage"])
average_usage_df.reset_index(inplace=True)
average_usage_df.rename(columns={"index": "start_station"}, inplace=True)

map5 = folium.Map(location=[39.95, -75.14], zoom_start=12)

color_palette = ['darkred', 'red', 'lightred', 'white', 'lightblue', 'blue', 'darkblue']

for start_coordinates, start_station in unique_coordinates:
    lat, lon = start_coordinates.split(",")
    lat = float(lat)
    lon = float(lon)
    
    average_usage = average_usage_df.loc[average_usage_df["start_station"] == start_station, "Average_daily_usage"].values[0]
    
    color_index = min(int(average_usage / 5), len(color_palette) - 1)
    marker_color = color_palette[color_index]
    
    popup_message = f"Station: {start_station}<br>Average Daily Usage: {average_usage}"
    
    folium.Marker(location=[lat, lon],
                  popup=popup_message,
                  icon=folium.Icon(color=marker_color)
                 ).add_to(map5)
map5
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_f0596aacbe3baeeab5dc1310a82ec72f {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_f0596aacbe3baeeab5dc1310a82ec72f&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_f0596aacbe3baeeab5dc1310a82ec72f = L.map(
#                 &quot;map_f0596aacbe3baeeab5dc1310a82ec72f&quot;,
#                 {
#                     center: [39.95, -75.14],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_138d79c26ff304245df9c2b9cfc34504 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_f0596aacbe3baeeab5dc1310a82ec72f);
#
#
#             var marker_241ba925923a497b1d06776c55999907 = L.marker(
#                 [39.943909, -75.167351],
#                 {}
#             ).addTo(map_f0596aacbe3baeeab5dc1310a82ec72f);
#
#
#             var icon_ea4433bd19e89e47da5cd81d8ed8ec5a = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;lightblue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_241ba925923a497b1d06776c55999907.setIcon(icon_ea4433bd19e89e47da5cd81d8ed8ec5a);
#
#
#         var popup_40b1c86ee088c2d66f9286ae13e09c46 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_a87737d82198a9308744a59cb15cf851 = $(`&lt;div id=&quot;html_a87737d82198a9308744a59cb15cf851&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Station: 3125&lt;br&gt;Average Daily Usage: 21.463648834019203&lt;/div&gt;`)[0];
#                 popup_40b1c86ee088c2d66f9286ae13e09c46.setContent(html_a87737d82198a9308744a59cb15cf851);
#
#
#
#         marker_241ba925923a497b1d06776c55999907.bindPopup(popup_40b1c86ee088c2d66f9286ae13e09c46)
#         ;
#
#
#
#
#             var marker_81e2d6cb320b306207cc3ce167e103bb = L.marker(
#                 [39.95472, -75.183228],
#                 {}
#             ).addTo(map_f0596aacbe3baeeab5dc1310a82ec72f);
#
#
#             var icon_db54e84ba5481f48f5e944235b636175 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_81e2d6cb320b306207cc3ce167e103bb.setIcon(icon_db54e84ba5481f48f5e944235b636175);
#
#
#         var popup_7c8939aee66f82c46fa909b486d88461 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_7848610bf6af7a8170b3f8912b1e3106 = $(`&lt;div id=&quot;html_7848610bf6af7a8170b3f8912b1e3106&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Station: 3022&lt;br&gt;Average Daily Usage: 28.083676268861453&lt;/div&gt;`)[0];
#                 popup_7c8939aee66f82c46fa909b486d88461.setContent(html_7848610bf6af7a8170b3f8912b1e3106);
#
#
#
#         marker_81e2d6cb320b306207cc3ce167e103bb.bindPopup(popup_7c8939aee66f82c46fa909b486d88461)
#         ;
#
#
#
#
#             var marker_4dc6ee01887e0e12e3c12b0fb6c03da5 = L.marker(
#                 [39.94561, -75.173477],
#                 {}
#             ).addTo(map_f0596aacbe3baeeab5dc1310a82ec72f);
#
#
#             var icon_87be65b9cfb80099ed0d0fcf76ed0d7b = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;darkblue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_4dc6ee01887e0e12e3c12b0fb6c03da5.setIcon(icon_87be65b9cfb80099ed0d0fcf76ed0d7b);
#
#
#         var popup_fd344b876252877c40023979364f7f57 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_7ea2515f9e8949b06f01f891574f659f = $(`&lt;div id=&quot;html_7ea2515f9e8949b06f01f891574f659f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Station: 3066&lt;br&gt;Average Daily Usage: 30.998628257887518&lt;/div&gt;`)[0];
#                 popup_fd344b876252877c40023979364f7f57.setContent(html_7ea2515f9e8949b06f01f891574f659f);
#
#
#
#         marker_4dc6ee01887e0e12e3c12b0fb6c03da5.bindPopup(popup_fd344b876252877c40023979364f7f57)
#         ;
#
#
#
#
#             var marker_5c97d3ce2fbaa01ba935a7fc4a39782b = L.marker(
#                 [39.947922, -75.162369],
#                 {}
#             ).addTo(map_f0596aacbe3baeeab5dc1310a82ec72f);
#
#
#             var icon_0

# %%
start_counter = Counter(Phil['start_station'])
start_counter_list = list(start_counter.items())
start_counter_list.sort(key=lambda x: x[1], reverse=True)

start_stations = [item[0] for item in start_counter_list]
start_counts = [item[1] for item in start_counter_list]

end_counter = Counter(Phil['end_station'])
end_counter_list = list(end_counter.items())
end_counter_list.sort(key=lambda x: x[1], reverse=True)

end_stations = [item[0] for item in end_counter_list]
end_counts = [item[1] for item in end_counter_list] 

fig, ax = plt.subplots(figsize=(16, 28))
bar_width = 0.6

start_bar = ax.barh(range(len(start_stations)), start_counts, bar_width, align='center', color='blue', label='start station')
end_bar = ax.barh(range(len(end_stations)), end_counts, bar_width/3, align='center', color='orange', label='end station')

ax.set_yticks(range(len(start_stations)))
ax.set_yticklabels(start_stations[::-1])  # Reverse the order of start stations for better readability

ax.axvline(x=0, color='black', linewidth=0.5)  # Add a vertical line at x=0

ax.set_xlabel('amount')
ax.set_title('Count start and end station')

ax.legend()

plt.tight_layout()
plt.show()

# %% [markdown]
# Support vector regression

# %%
X = dataset.iloc[:, 1:2].values
y = dataset.iloc[:, 2].values
