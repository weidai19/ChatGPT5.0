# %%
import numpy as np
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns
from datetime import datetime #for working with times objects
from datetime import timedelta #for working with times objects
from collections import Counter
import folium #map
import matplotlib.pyplot as plt #color and graph
import matplotlib.cm as cm #color
import math
import random
import glob
import plotly.graph_objects as go

# %%
Phil = pd.read_csv('cleaned_files.csv', low_memory=False)
Phil2 = pd.read_csv('merged_files.csv', low_memory=False) #uncleaned file for stolen bikes

# %%
Weather = pd.read_csv("Weather_data_clean.csv", low_memory=False)

# %%
columns = Phil.columns
print(columns)
#print (Phil["start_coordinates"])
Phil.info()
# Out:
# Index(['trip_id', 'duration', 'start_time', 'end_time', 'start_station',
#        'end_station', 'bike_id', 'plan_duration', 'trip_route_category',
#        'passholder_type', 'bike_type', 'Date_s', 'Weekday_s', 'Hour_s',
#        'Date_e', 'Weekday_e', 'Hour_e', 'start_coordinates',
#        'end_coordinates'],
#       dtype='object')
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1781474 entries, 0 to 1781473
# Data columns (total 19 columns):
#  #   Column               Dtype
# ---  ------               -----
#  0   trip_id              int64
#  1   duration             int64
#  2   start_time           object
#  3   end_time             object
#  4   start_station        int64
#  5   end_station          int64
#  6   bike_id              object
#  7   plan_duration        int64
#  8   trip_route_category  object
#  9   passholder_type      object
#  10  bike_type            object
#  11  Date_s               object
#  12  Weekday_s            int64
#  13  Hour_s               int64
#  14  Date_e               object
#  15  Weekday_e            int64
#  16  Hour_e               int64
#  17  start_coordinates    object
#  18  end_coordinates      object
# dtypes: int64(9), object(10)
# memory usage: 258.2+ MB

# %%
# unique start station coordinations
unique_coordinates = Phil[["start_coordinates", "start_station"]].drop_duplicates().values.tolist()
print (unique_coordinates)
amount = len(unique_coordinates)
print (amount)
# Out:
# [['39.943909,-75.167351', 3125], ['39.95472,-75.183228', 3022], ['39.94561,-75.173477', 3066], ['39.947922,-75.162369', 3045], ['39.947319,-75.156952', 3052], ['39.955231,-75.166199', 3201], ['39.97121,-75.159698', 3039], ['39.953651,-75.14045', 3124], ['39.942181,-75.177467', 3012], ['39.96439,-75.179871', 3057], ['39.947109,-75.166183', 3010], ['39.964371,-75.165817', 3204], ['39.963791,-75.18158', 3212], ['39.93549,-75.167107', 3068], ['39.95425,-75.177612', 3061], ['39.948219,-75.209084', 3024], ['39.980049,-75.15522', 3031], ['39.940609,-75.149582', 3028], ['39.928139,-75.165154', 3164], ['39.953548,-75.171921', 3078], ['39.984921,-75.156677', 3210], ['39.962502,-75.174202', 3054], ['39.955109,-75.209869', 3074], ['39.928841,-75.170212', 3150], ['39.934311,-75.160423', 3098], ['39.942951,-75.159554', 3101], ['39.940769,-75.172272', 3203], ['39.953812,-75.174072', 3156], ['39.96664,-75.192093', 3104], ['39.940182,-75.154419', 3155], ['39.964111,-75.19973', 3067], ['39.96244,-75.161209', 3059], ['39.93935,-75.157158', 3030], ['39.945171,-75.159927', 3007], ['39.953732,-75.218246', 3112], ['39.946331,-75.1698', 3063], ['39.948551,-75.190071', 3020], ['39.950249,-75.160278', 3167], ['39.94595,-75.184753', 3162], ['39.93082,-75.174744', 3043], ['39.937038,-75.150383', 3069], ['39.945271,-75.17971', 3032], ['39.953388,-75.154259', 3050], ['39.925522,-75.169037', 3158], ['39.97263,-75.167572', 3115], ['39.97414,-75.180222', 3121], ['39.933151,-75.162483', 3034], ['39.937752,-75.180122', 3114], ['39.953781,-75.163742', 3004], ['39.949741,-75.180969', 3163], ['39.948921,-75.169907', 3190], ['39.970699,-75.151711', 3065], ['39.9384,-75.173271', 3064], ['39.971722,-75.170601', 3211], ['39.972351,-75.134453', 3166], ['39.934448,-75.145409', 3072], ['39.889938,-75.176788', 3183], ['39.967442,-75.175072', 3051], ['39.972069,-75.163513', 3077], ['39.95866,-75.213226', 3118], ['39.953899,-75.169022', 3021], ['39.963169,-75.147919', 3013], ['39.97583,-75.168457', 3200], ['39.96006,-75.171982', 3116], ['39.940189,-75.166908', 3086], ['39.932308,-75.181541', 3053], ['39.961731,-75.187881', 3071], ['39.957249,-75.172318', 3187], ['39.954239,-75.161377', 3037], ['39.92083,-75.170326', 3197], ['39.959229,-75.170357', 3060], ['39.97216,-75.129936', 3153], ['39.976688,-75.158127', 3056], ['39.956619,-75.198624', 3160], ['39.962711,-75.194191', 3035], ['39.97522,-75.186691', 3120], ['39.953159,-75.165512', 3108], ['39.954411,-75.192001', 3207], ['39.951118,-75.154572', 3055], ['39.925449,-75.159538', 3157], ['39.962891,-75.166061', 3040], ['39.938869,-75.166634', 3213], ['39.95134,-75.173943', 3168], ['39.958858,-75.173691', 3014], ['39.978909,-75.157799', 3214], ['39.952728,-75.15979', 3018], ['39.952202,-75.20311', 3006], ['39.987171,-75.174767', 3196], ['39.96674,-75.207993', 3119], ['39.945091,-75.142502', 3049], ['39.982029,-75.18866', 3107], ['39.954048,-75.167831', 3205], ['39.93401,-75.15094', 3099], ['39.991791,-75.186371', 3106], ['39.950809,-75.169533', 3182], ['39.95174,-75.170631', 3206], ['39.950481,-75.193237', 3208], ['39.95005,-75.156723', 3033], ['39.96759,-75.17952', 3102], ['39.947811,-75.194092', 3038], ['39.954029,-75.149834', 3019], ['39.958191,-75.1782', 3165], ['39.95924,-75.158211', 3154], ['39.959671,-75.196487', 3011], ['39.95134,-75.16758', 3202], ['39.937241,-75.161201', 3025], ['39.954861,-75.180908', 3161], ['39.9538,-75.194794', 3029], ['39.967159,-75.170013', 3058], ['39.978409,-75.223991', 3117], ['39.960621,-75.139832', 3070], ['39.968491,-75.13546', 3041], ['39.969841,-75.1418', 3088], ['39.967178,-75.161247', 3075], ['39.953819,-75.142632', 3169], ['39.955761,-75.189819', 3009], ['39.89629,-75.17514', 3181], ['39.978882,-75.133392', 3097], ['39.950119,-75.144722', 3046], ['39.95071,-75.149208', 3047], ['39.94735,-75.148857', 3015], ['39.89307,-75.171677', 3186], ['39.927769,-75.151031', 3100], ['39.951969,-75.179428', 3062], ['39.96207,-75.141113', 3192], ['39.94426,-75.181343', 3170], ['39.949001,-75.212784' ...
# 198

# %%
#unique end station coordinations
unique_coordinates_end = Phil[['end_coordinates', "end_station"]].drop_duplicates().values.tolist()
print (unique_coordinates_end)
int2 = len(unique_coordinates_end)
print (int2)
# Out:
# [['39.925449,-75.159538', 3157], ['39.947109,-75.166183', 3010], ['39.955231,-75.166199', 3201], ['39.933151,-75.162483', 3034], ['39.962891,-75.166061', 3040], ['39.97121,-75.159698', 3039], ['39.940609,-75.149582', 3028], ['39.967442,-75.175072', 3051], ['39.934448,-75.145409', 3072], ['39.928841,-75.170212', 3150], ['39.955761,-75.189819', 3009], ['39.961731,-75.187881', 3071], ['39.980049,-75.15522', 3031], ['39.984921,-75.156677', 3210], ['39.92083,-75.170326', 3197], ['39.940189,-75.166908', 3086], ['39.955109,-75.209869', 3074], ['39.98003,-75.143707', 3017], ['39.937038,-75.150383', 3069], ['39.96759,-75.17952', 3102], ['39.93082,-75.174744', 3043], ['39.940182,-75.154419', 3155], ['39.953819,-75.142632', 3169], ['39.954861,-75.180908', 3161], ['39.94735,-75.148857', 3015], ['39.964371,-75.165817', 3204], ['39.95134,-75.173943', 3168], ['39.93549,-75.167107', 3068], ['39.963169,-75.147919', 3013], ['39.943909,-75.167351', 3125], ['39.937752,-75.180122', 3114], ['39.967178,-75.161247', 3075], ['39.947811,-75.194092', 3038], ['39.956619,-75.198624', 3160], ['39.950249,-75.160278', 3167], ['39.964111,-75.19973', 3067], ['39.947319,-75.156952', 3052], ['39.95005,-75.156723', 3033], ['39.934311,-75.160423', 3098], ['39.962502,-75.174202', 3054], ['39.94426,-75.181343', 3170], ['39.945171,-75.159927', 3007], ['39.94595,-75.184753', 3162], ['39.950119,-75.144722', 3046], ['39.940769,-75.172272', 3203], ['39.945271,-75.17971', 3032], ['39.95134,-75.16758', 3202], ['39.949741,-75.180969', 3163], ['39.95425,-75.177612', 3061], ['39.95924,-75.158211', 3154], ['39.952728,-75.15979', 3018], ['39.970699,-75.151711', 3065], ['39.93935,-75.157158', 3030], ['39.937241,-75.161201', 3025], ['39.948921,-75.169907', 3190], ['39.942951,-75.159554', 3101], ['39.963791,-75.18158', 3212], ['39.9384,-75.173271', 3064], ['39.950809,-75.169533', 3182], ['39.946331,-75.1698', 3063], ['39.949001,-75.212784', 3209], ['39.945091,-75.142502', 3049], ['39.94561,-75.173477', 3066], ['39.971722,-75.170601', 3211], ['39.957249,-75.172318', 3187], ['39.889938,-75.176788', 3183], ['39.953899,-75.169022', 3021], ['39.96439,-75.179871', 3057], ['39.969841,-75.1418', 3088], ['39.97522,-75.186691', 3120], ['39.96244,-75.161209', 3059], ['39.967159,-75.170013', 3058], ['39.976688,-75.158127', 3056], ['39.942181,-75.177467', 3012], ['39.95472,-75.183228', 3022], ['39.959229,-75.170357', 3060], ['39.925522,-75.169037', 3158], ['39.97216,-75.129936', 3153], ['39.97583,-75.168457', 3200], ['39.954411,-75.192001', 3207], ['39.96664,-75.192093', 3104], ['39.953388,-75.154259', 3050], ['39.982029,-75.18866', 3107], ['39.95866,-75.213226', 3118], ['39.959671,-75.196487', 3011], ['39.932308,-75.181541', 3053], ['39.958191,-75.1782', 3165], ['39.96006,-75.171982', 3116], ['39.953159,-75.165512', 3108], ['39.953812,-75.174072', 3156], ['39.968491,-75.13546', 3041], ['39.958858,-75.173691', 3014], ['39.952202,-75.20311', 3006], ['39.947922,-75.162369', 3045], ['39.954048,-75.167831', 3205], ['39.96674,-75.207993', 3119], ['39.93401,-75.15094', 3099], ['39.950481,-75.193237', 3208], ['39.95174,-75.170631', 3206], ['39.954239,-75.161377', 3037], ['39.972351,-75.134453', 3166], ['39.960621,-75.139832', 3070], ['39.97414,-75.180222', 3121], ['39.96143,-75.15242', 3073], ['39.951969,-75.179428', 3062], ['39.953548,-75.171921', 3078], ['39.953732,-75.218246', 3112], ['39.954029,-75.149834', 3019], ['39.951118,-75.154572', 3055], ['39.953651,-75.14045', 3124], ['39.951691,-75.158882', 3185], ['39.987171,-75.174767', 3196], ['39.962711,-75.194191', 3035], ['39.948551,-75.190071', 3020], ['39.938869,-75.166634', 3213], ['39.927769,-75.151031', 3100], ['39.928139,-75.165154', 3164], ['39.978882,-75.133392', 3097], ['39.95071,-75.149208', 3047], ['39.9538,-75.194794', 3029], ['39.988369,-75.187012', 3093], ['39.89307,-75.171677', 3186], ['39.977791,-75.213226', 3111], ['39.953781,-75.163742', 3004], ['39.991192,-75.179749', 3096], ['39.89629,-75.17514', 3181], ['39.96207,-75.141113',  ...
# 198

# %%
#coordinates
min_max = (Phil['start_coordinates'].min(), Phil['start_coordinates'].max())
print (min_max)

lat = (Phil2['start_lat'].min() + Phil2['start_lat'].max()) /2
print (lat)
lon = (Phil2['start_lon'].min() + Phil2['start_lon'].max()) / 2
print (lon)
# Out:
# ('39.889938,-75.176788', '40.01112,-75.192871')
# 39.950529
# -75.17551449999999

# %%
start_dict = dict(Phil)

# %%
map = folium.Map(location=[39.9505, -75.1755], zoom_start = 12)
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_815b1e1abed2d6a153694fdab809a17e {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_815b1e1abed2d6a153694fdab809a17e&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_815b1e1abed2d6a153694fdab809a17e = L.map(
#                 &quot;map_815b1e1abed2d6a153694fdab809a17e&quot;,
#                 {
#                     center: [39.9505, -75.1755],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_7d6b214c61b058bedbbb05350ed1502e = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_815b1e1abed2d6a153694fdab809a17e);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# map with all stations
map = folium.Map(location=[39.95, -75.14], zoom_start = 12)

for start_coordinates, start_station in unique_coordinates:
    
    
    lat, lon = start_coordinates.split(",")
    lat = float(lat)
    lon = float(lon)
    
 
    
    if np.isnan(lat) or np.isnan(lon):
        continue 
        
    folium.Marker(location = [lat, lon],
                  popup= f"{start_station}"
                   ).add_to(map)
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_a77682e0dd73bbd54625daee89800e21 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_a77682e0dd73bbd54625daee89800e21&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_a77682e0dd73bbd54625daee89800e21 = L.map(
#                 &quot;map_a77682e0dd73bbd54625daee89800e21&quot;,
#                 {
#                     center: [39.95, -75.14],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_5cdd074c61184f00b6cdeefaede0d93f = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_a77682e0dd73bbd54625daee89800e21);
#
#
#             var marker_66ac42a5baf32858901e8fa06fc5f772 = L.marker(
#                 [39.943909, -75.167351],
#                 {}
#             ).addTo(map_a77682e0dd73bbd54625daee89800e21);
#
#
#         var popup_1474a20179d8317222bcb2808f3a9563 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_212747b7d486843a9b7f75616e0ac171 = $(`&lt;div id=&quot;html_212747b7d486843a9b7f75616e0ac171&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;3125&lt;/div&gt;`)[0];
#                 popup_1474a20179d8317222bcb2808f3a9563.setContent(html_212747b7d486843a9b7f75616e0ac171);
#
#
#
#         marker_66ac42a5baf32858901e8fa06fc5f772.bindPopup(popup_1474a20179d8317222bcb2808f3a9563)
#         ;
#
#
#
#
#             var marker_d7f17e3c1915817cefd2cb7a01a1d10f = L.marker(
#                 [39.95472, -75.183228],
#                 {}
#             ).addTo(map_a77682e0dd73bbd54625daee89800e21);
#
#
#         var popup_41eff1e369c4a0078777cf4a58df189c = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_83fcc9d56920ef9c9d58125584259856 = $(`&lt;div id=&quot;html_83fcc9d56920ef9c9d58125584259856&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;3022&lt;/div&gt;`)[0];
#                 popup_41eff1e369c4a0078777cf4a58df189c.setContent(html_83fcc9d56920ef9c9d58125584259856);
#
#
#
#         marker_d7f17e3c1915817cefd2cb7a01a1d10f.bindPopup(popup_41eff1e369c4a0078777cf4a58df189c)
#         ;
#
#
#
#
#             var marker_2233ef928010af53817a561bd6495da3 = L.marker(
#                 [39.94561, -75.173477],
#                 {}
#             ).addTo(map_a77682e0dd73bbd54625daee89800e21);
#
#
#         var popup_4c98dacdb7ba7f8ab50611ef8082dec5 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_c7761882ba59107e483e33b54cdbcba8 = $(`&lt;div id=&quot;html_c7761882ba59107e483e33b54cdbcba8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;3066&lt;/div&gt;`)[0];
#                 popup_4c98dacdb7ba7f8ab50611ef8082dec5.setContent(html_c7761882ba59107e483e33b54cdbcba8);
#
#
#
#         marker_2233ef928010af53817a561bd6495da3.bindPopup(popup_4c98dacdb7ba7f8ab50611ef8082dec5)
#         ;
#
#
#
#
#             var marker_05618fa61f6ce924472d24bb32449e71 = L.marker(
#                 [39.947922, -75.162369],
#                 {}
#             ).addTo(map_a77682e0dd73bbd54625daee89800e21);
#
#
#         var popup_4d884ab6dadb442e5c27e03c2f106afa = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_caedbdd34a3041190f7d6948525fe267 = $(`&lt;div id=&quot;html_caedbdd34a3041190f7d6948525fe267&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;3045&lt;/div&gt;`)[0];
#                 popup_4d884ab6dadb442e5c27e03c2f106afa.setContent(html_caedbdd34a3041190f7d6948525fe267);
#
#
#
#         marker_05618fa61f6ce924472d24bb32449e71.bindPopup(popup_4d884ab6dadb442e5c27e03c2f106afa)
#         ;
#
#
#
#
#             var marker_72679751d68c0f101be886035c473b19 = L.marker(
#                 [39.947319, -75.156952],
#                 {}
#             ).addTo(map_a77682e0dd73bbd54625daee89800e21);
#
#
#         var popup_a5ae0f35475916acd32a0edc026b0c9f = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_2147123b1a7beb55ef51dec8fda07c29 = $(`&lt;div id=&quot;html_2147123b1a7beb55ef51dec8fda07c29&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;3052&lt;/div&gt;`)[0];
#                 popup_a5ae0f35475916acd32a0edc026b0c9f.setContent(html_2147123b1a7beb55ef51dec8fda07c29);
#
#
#
#         marker_72679751d68c0f101be886035c473b19.bindPopup(popup_a5ae0f35475916acd32a0edc026b0c9f)
#         ;
#
#
#
#
#             var marker_7e8b27d3602ac7bf4dd7001649ee217f = L.marker(
#                 [39.955231, -75.166199],
#                 {}
#             ).addTo(map_a77682e0dd73bbd54625d

# %%
# counter how many starts at station 
map2 = folium.Map(location=[39.95, -75.14], zoom_start = 12)


start_counter  = Counter(Phil['start_station'])
start_counter_list = list(start_counter.items())
start_counter_list.sort(key=lambda x: x[1], reverse=True)

for station, count in start_counter_list:
    print(f"Station {station}: {count}")

station_dict_start = dict(Phil.start_station.value_counts().sort_index())
#print(station_dict_start)


color_palette = ['darkred', 'red', 'lightred', 'white', 'lightblue', 'blue', 'darkblue']


for start_coordinates, start_station in unique_coordinates:
    
    
    lat, lon = start_coordinates.split(",")
    lat = float(lat)
    lon = float(lon)

        
    if np.isnan(lat) or np.isnan(lon):
        continue 
        
    count = start_counter[start_station]
    popup_message = f"Station: {start_station}<br>Frequency: {count}"
    
    color_index = min(int(count / 4000), len(color_palette) - 1)
    marker_color = color_palette[color_index]

    
    
    folium.Marker(location = [lat, lon],
                  popup= popup_message,
                  icon=folium.Icon(color=marker_color)
                   ).add_to(map2)
    

map2
# Out:
# Station 3010: 31318
# Station 3190: 29064
# Station 3032: 28215
# Station 3202: 27807
# Station 3007: 27155
# Station 3208: 26628
# Station 3168: 26107
# Station 3167: 25500
# Station 3045: 25457
# Station 3052: 25415
# Station 3054: 25316
# Station 3212: 24495
# Station 3101: 22805
# Station 3066: 22598
# Station 3028: 22224
# Station 3046: 21513
# Station 3102: 21251
# Station 3185: 20683
# Station 3022: 20473
# Station 3057: 20268
# Station 3012: 19888
# Station 3154: 19341
# Station 3063: 17961
# Station 3020: 16960
# Station 3207: 16890
# Station 3021: 16889
# Station 3029: 16772
# Station 3009: 16739
# Station 3018: 16329
# Station 3061: 16125
# Station 3203: 15989
# Station 3206: 15964
# Station 3037: 15864
# Station 3078: 15743
# Station 3125: 15647
# Station 3033: 15641
# Station 3163: 15354
# Station 3058: 15276
# Station 3006: 14904
# Station 3114: 14626
# Station 3030: 14620
# Station 3238: 14549
# Station 3100: 14272
# Station 3040: 14150
# Station 3244: 14111
# Station 3182: 13998
# Station 3160: 13943
# Station 3055: 13890
# Station 3034: 13838
# Station 3064: 13774
# Station 3047: 13674
# Station 3050: 13167
# Station 3108: 13153
# Station 3161: 12994
# Station 3059: 12870
# Station 3035: 12855
# Station 3156: 12124
# Station 3051: 12014
# Station 3201: 11953
# Station 3026: 11754
# Station 3155: 11741
# Station 3075: 11719
# Station 3068: 11561
# Station 3043: 11421
# Station 3159: 11374
# Station 3116: 11373
# Station 3049: 11370
# Station 3025: 11170
# Station 3169: 11168
# Station 3069: 10619
# Station 3038: 10369
# Station 3053: 10247
# Station 3158: 10198
# Station 3074: 10150
# Station 3098: 9991
# Station 3255: 9916
# Station 3164: 9774
# Station 3256: 9746
# Station 3204: 9697
# Station 3205: 9644
# Station 3088: 9190
# Station 3162: 9173
# Station 3121: 9078
# Station 3073: 9064
# Station 3056: 9056
# Station 3157: 9030
# Station 3039: 8993
# Station 3170: 8967
# Station 3015: 8459
# Station 3041: 8430
# Station 3124: 8422
# Station 3004: 8414
# Station 3165: 8233
# Station 3031: 8070
# Station 3086: 8044
# Station 3062: 7811
# Station 3120: 7694
# Station 3234: 7553
# Station 3071: 7378
# Station 3187: 7333
# Station 3235: 7081
# Station 3072: 7044
# Station 3245: 7043
# Station 3005: 7031
# Station 3210: 6752
# Station 3099: 6741
# Station 3060: 6691
# Station 3209: 6621
# Station 3024: 6603
# Station 3197: 6561
# Station 3150: 6553
# Station 3166: 6530
# Station 3249: 6387
# Station 3236: 6385
# Station 3110: 6283
# Station 3013: 6205
# Station 3077: 6123
# Station 3248: 5875
# Station 3211: 5643
# Station 3097: 5602
# Station 3014: 5527
# Station 3112: 5081
# Station 3011: 5055
# Station 3118: 5023
# Station 3261: 4918
# Station 3019: 4913
# Station 3017: 4796
# Station 3008: 4785
# Station 3233: 4783
# Station 3070: 4772
# Station 3152: 4712
# Station 3264: 4418
# Station 3115: 4351
# Station 3065: 4157
# Station 3188: 4041
# Station 3153: 3939
# Station 3104: 3862
# Station 3184: 3749
# Station 3200: 3622
# Station 3252: 3578
# Station 3192: 3427
# Station 3259: 3099
# Station 3246: 3073
# Station 3123: 3024
# Station 3237: 3017
# Station 3107: 3008
# Station 3067: 2971
# Station 3241: 2880
# Station 3111: 2631
# Station 3016: 2614
# Station 3273: 2607
# Station 3250: 2579
# Station 3119: 2558
# Station 3254: 2554
# Station 3296: 2542
# Station 3265: 2450
# Station 3106: 2263
# Station 3213: 2227
# Station 3266: 2203
# Station 3257: 2163
# Station 3186: 2041
# Station 3253: 1982
# Station 3226: 1700
# Station 3295: 1659
# Station 3117: 1638
# Station 3113: 1629
# Station 3275: 1556
# Station 3183: 1549
# Station 3258: 1510
# Station 3251: 1489
# Station 3276: 1467
# Station 3181: 1432
# Station 3093: 1413
# Station 3263: 1360
# Station 3267: 1316
# Station 3196: 1119
# Station 3247: 1011
# Station 3214: 1007
# Station 3279: 971
# Station 3243: 930
# Station 3096: 838
# Station 3240: 773
# Station 3286: 712
# Station 3294: 710
# Station 3271: 694
# Station 3272: 644
# Station 3287: 372
# Station 3277: 360
# Station 3278: 272
# Station 3281: 232
# Station 3280: 211
# Station 3299: 159
# Station 3282: 142
# Station 3291: 88
# Station 3285: 77
# Station 3284: 56
# Station 3300: 48
# Station 3298: 44
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_3f8133a85eabf28d271d4d52ac29b0a5 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_3f8133a85eabf28d271d4d52ac29b0a5&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_3f8133a85eabf28d271d4d52ac29b0a5 = L.map(
#                 &quot;map_3f8133a85eabf28d271d4d52ac29b0a5&quot;,
#                 {
#                     center: [39.95, -75.14],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_06a9abe54c63370e6416b05012a5b245 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_3f8133a85eabf28d271d4d52ac29b0a5);
#
#
#             var marker_f2a77363e89ccdc1ae9ed49d08f98886 = L.marker(
#                 [39.943909, -75.167351],
#                 {}
#             ).addTo(map_3f8133a85eabf28d271d4d52ac29b0a5);
#
#
#             var icon_4ae0cea855d6ea2b831e13ca4c74f1f6 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;white&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_f2a77363e89ccdc1ae9ed49d08f98886.setIcon(icon_4ae0cea855d6ea2b831e13ca4c74f1f6);
#
#
#         var popup_185e948cf9b462d683afe08c6479f42f = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_60867be222ca1af612af8992d8840afd = $(`&lt;div id=&quot;html_60867be222ca1af612af8992d8840afd&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Station: 3125&lt;br&gt;Frequency: 15647&lt;/div&gt;`)[0];
#                 popup_185e948cf9b462d683afe08c6479f42f.setContent(html_60867be222ca1af612af8992d8840afd);
#
#
#
#         marker_f2a77363e89ccdc1ae9ed49d08f98886.bindPopup(popup_185e948cf9b462d683afe08c6479f42f)
#         ;
#
#
#
#
#             var marker_34a00e42dec22dd31486bd398a987042 = L.marker(
#                 [39.95472, -75.183228],
#                 {}
#             ).addTo(map_3f8133a85eabf28d271d4d52ac29b0a5);
#
#
#             var icon_5b10e919236d5a8a958b43a7b7d8d939 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_34a00e42dec22dd31486bd398a987042.setIcon(icon_5b10e919236d5a8a958b43a7b7d8d939);
#
#
#         var popup_b304d4602620db85bf67229e2663a2ab = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_85969fd4c13574ef02fcaaae3172e028 = $(`&lt;div id=&quot;html_85969fd4c13574ef02fcaaae3172e028&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Station: 3022&lt;br&gt;Frequency: 20473&lt;/div&gt;`)[0];
#                 popup_b304d4602620db85bf67229e2663a2ab.setContent(html_85969fd4c13574ef02fcaaae3172e028);
#
#
#
#         marker_34a00e42dec22dd31486bd398a987042.bindPopup(popup_b304d4602620db85bf67229e2663a2ab)
#         ;
#
#
#
#
#             var marker_3bb2ab6c9db2b50f99f45d1908400db5 = L.marker(
#                 [39.94561, -75.173477],
#                 {}
#             ).addTo(map_3f8133a85eabf28d271d4d52ac29b0a5);
#
#
#             var icon_9e26cc89045d6403a2e774819ee8531f = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_3bb2ab6c9db2b50f99f45d1908400db5.setIcon(icon_9e26cc89045d6403a2e774819ee8531f);
#
#
#         var popup_e29a36a4efa79cb4ffcf0fbc55c62c9f = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_9ba422f226eaced43d88471e762ec6bc = $(`&lt;div id=&quot;html_9ba422f226eaced43d88471e762ec6bc&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Station: 3066&lt;br&gt;Frequency: 22598&lt;/div&gt;`)[0];
#                 popup_e29a36a4efa79cb4ffcf0fbc55c62c9f.setContent(html_9ba422f226eaced43d88471e762ec6bc);
#
#
#
#         marker_3bb2ab6c9db2b50f99f45d1908400db5.bindPopup(popup_e29a36a4efa79cb4ffcf0fbc55c62c9f)
#         ;
#
#
#
#
#             var marker_0cb999ba4964166d05778197f783d1b4 = L.marker(
#                 [39.947922, -75.162369],
#                 {}
#             ).addTo(map_3f8133a85eabf28d271d4d52ac29b0a5);
#
#
#             var icon_efc9e1d956744bde2234cef49f6e2636 = L.AwesomeMarkers.icon(
#                 {&qu

# %% [raw]
# It is only possible to use fixed colors with folium.
# So we build a color scale from dark red to dark blue
#
# dark red lowest value to dark blue highest value
# dark red: 0 - 1999
# red 2000 - 5999
# light red 6000 - 9999
# white 10000 - 13999
# lightblue 14000 - 17999
# blue 18000 - 21999
# darkblue 22000+

# %%
# counter how many ends at station - scale dark red to dark blue 
map3 = folium.Map(location=[39.95, -75.14], zoom_start = 12)


end_counter  = Counter(Phil['end_station'])
end_counter_list = list(end_counter.items())
end_counter_list.sort(key=lambda x: x[1], reverse=True)

#for station, count in end_counter_list:
#    print(f"Station {station}: {count}")

station_dict_end = dict(Phil.end_station.value_counts().sort_index())
#print(station_dict_end)


color_palette = ['darkred', 'red', 'lightred', 'white', 'lightblue', 'blue', 'darkblue']


for end_coordinates, end_station in unique_coordinates_end:
    
    
    lat, lon = end_coordinates.split(",")
    lat = float(lat)
    lon = float(lon)

        
    if np.isnan(lat) or np.isnan(lon):
        continue 
        
    count = end_counter[end_station]
    popup_message = f"Station: {end_station}<br>Frequency: {count}"
    
    color_index = min(int(count / 4000), len(color_palette) - 1)
    marker_color = color_palette[color_index]

    
    
    folium.Marker(location = [lat, lon],
                  popup= popup_message,
                  icon=folium.Icon(color=marker_color)
                   ).add_to(map3)
    

map3
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_37e5e6bc00f9755519e36aed06229e1c {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_37e5e6bc00f9755519e36aed06229e1c&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_37e5e6bc00f9755519e36aed06229e1c = L.map(
#                 &quot;map_37e5e6bc00f9755519e36aed06229e1c&quot;,
#                 {
#                     center: [39.95, -75.14],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_b960fa785ab955730c2e60a19bebdb10 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_37e5e6bc00f9755519e36aed06229e1c);
#
#
#             var marker_b958970165cf01f9628a7ffd8401709a = L.marker(
#                 [39.925449, -75.159538],
#                 {}
#             ).addTo(map_37e5e6bc00f9755519e36aed06229e1c);
#
#
#             var icon_504d4c12a33b9765f9bf35648b785138 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;lightred&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_b958970165cf01f9628a7ffd8401709a.setIcon(icon_504d4c12a33b9765f9bf35648b785138);
#
#
#         var popup_1abb13d06e48b179aef678768cb45d57 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_aac04ac1839840247e7176dc90442491 = $(`&lt;div id=&quot;html_aac04ac1839840247e7176dc90442491&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Station: 3157&lt;br&gt;Frequency: 9627&lt;/div&gt;`)[0];
#                 popup_1abb13d06e48b179aef678768cb45d57.setContent(html_aac04ac1839840247e7176dc90442491);
#
#
#
#         marker_b958970165cf01f9628a7ffd8401709a.bindPopup(popup_1abb13d06e48b179aef678768cb45d57)
#         ;
#
#
#
#
#             var marker_8c712c4d3cbd1f7419ba6991ab1f334c = L.marker(
#                 [39.947109, -75.166183],
#                 {}
#             ).addTo(map_37e5e6bc00f9755519e36aed06229e1c);
#
#
#             var icon_db83c0e534a664fc1eaaec591778d7e0 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;darkblue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_8c712c4d3cbd1f7419ba6991ab1f334c.setIcon(icon_db83c0e534a664fc1eaaec591778d7e0);
#
#
#         var popup_6d85a61bdcd13370c773c5e8a3199e2d = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_b4b7cd1de373cc4dbb8a2c9b18bdf01d = $(`&lt;div id=&quot;html_b4b7cd1de373cc4dbb8a2c9b18bdf01d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Station: 3010&lt;br&gt;Frequency: 31034&lt;/div&gt;`)[0];
#                 popup_6d85a61bdcd13370c773c5e8a3199e2d.setContent(html_b4b7cd1de373cc4dbb8a2c9b18bdf01d);
#
#
#
#         marker_8c712c4d3cbd1f7419ba6991ab1f334c.bindPopup(popup_6d85a61bdcd13370c773c5e8a3199e2d)
#         ;
#
#
#
#
#             var marker_502afea09060ac2450d91daffce49ee9 = L.marker(
#                 [39.955231, -75.166199],
#                 {}
#             ).addTo(map_37e5e6bc00f9755519e36aed06229e1c);
#
#
#             var icon_18c86575b7dbeecff08490e1fe5e01c6 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;white&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_502afea09060ac2450d91daffce49ee9.setIcon(icon_18c86575b7dbeecff08490e1fe5e01c6);
#
#
#         var popup_b51965f938339727bb257e66db541228 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_ad0187df0bc3456cf90beee3375025cc = $(`&lt;div id=&quot;html_ad0187df0bc3456cf90beee3375025cc&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Station: 3201&lt;br&gt;Frequency: 12385&lt;/div&gt;`)[0];
#                 popup_b51965f938339727bb257e66db541228.setContent(html_ad0187df0bc3456cf90beee3375025cc);
#
#
#
#         marker_502afea09060ac2450d91daffce49ee9.bindPopup(popup_b51965f938339727bb257e66db541228)
#         ;
#
#
#
#
#             var marker_9cc4805f6461c0f8ff08712f2304a99c = L.marker(
#                 [39.933151, -75.162483],
#                 {}
#             ).addTo(map_37e5e6bc00f9755519e36aed06229e1c);
#
#
#             var icon_243b82a11ab1e267ba1727680162926b = L.AwesomeMarkers.icon(

# %%
# # bikes
unique_bikes = Phil["bike_id"].drop_duplicates().values.tolist()

amount_bikes = len(unique_bikes)
print (amount_bikes)

bike_counter  = Counter(Phil["bike_id"])
bike_counter_list = list(bike_counter.items())
bike_counter_list.sort(key=lambda x: x[1], reverse=False)


# shows how often each bike was rented 

#for bike_id, count in bike_counter_list:
#    print(f"bike_id: {bike_id} : {count}")
# Out:
# 2373

# %%
# Top 10 trips
popular_trips_group = Phil.groupby(["start_station", "end_station"]).size()
popular_trips = pd.DataFrame(popular_trips_group[popular_trips_group > 1000], columns=["count"])
popular_trips.reset_index(inplace=True)
popular_trips_sorted = popular_trips.sort_values(by= "count", ascending=False)
popular_trips_sorted.reset_index(drop=True, inplace=True)
popular_trips_sorted.head(20)
# Out:
#     start_station  end_station  count
# 0            3212         3212   7275
# 1            3202         3202   5116
# 2            3057         3057   3242
# 3            3208         3032   2409
# 4            3035         3009   2308
# 5            3020         3032   2079
# 6            3057         3212   1927
# 7            3009         3035   1856
# 8            3186         3186   1650
# 9            3054         3102   1622
# 10           3102         3102   1608
# 11           3049         3049   1596
# 12           3163         3163   1582
# 13           3035         3249   1542
# 14           3032         3208   1512
# 15           3154         3167   1447
# 16           3102         3054   1420
# 17           3006         3208   1328
# 18           3249         3035   1279
# 19           3163         3212   1269

# %%
#duration = 1440 uncleaned data
count_true = (Phil2["duration"] == 1440).sum()
print(count_true)
# Out:
# 801

# %%
#duration = 1440 clean data
count_true = (Phil["duration"] == 1440).sum()
print(count_true)
# Out:
# 320

# %%
# merged_data bikes with 1440 duration
Phil_1440minutes = Phil2[Phil2["duration"] == 1440 ]
selected_columns = ['start_station','start_lat', 'start_lon', "bike_type"]


start_station_count = Phil_1440minutes["start_station"].value_counts()

#print("duration of 1440 minutes for column 'start_station':")
#print(start_station_count.to_string())

# %%
# cleaned data bikes with 1440 duration
Phil_1440minutes = Phil[Phil["duration"] == 1440 ]
selected_columns = ['start_station', "bike_type"]


start_station_count = Phil_1440minutes["start_station"].value_counts()

#print("duration of 1440 minutes for column 'start_station':")
#print(start_station_count.to_string())

# %%
# map for duration == 1440 on uncleaned dataset
map4 = folium.Map(location=[39.9505, -75.1755], zoom_start = 12)

for start_coordinates, start_station in unique_coordinates:
    
    
    lat, lon = start_coordinates.split(",")
    lat = float(lat)
    lon = float(lon)
    
    if np.isnan(lat) or np.isnan(lon):
        continue 
        
    stations_more_10_stolen = [3057, 3097, 3185, 3202, 3046, 3056, 3049, 3210, 3110, 3212, 3190, 3004, 3108, 3037, 3158, 3018, 3160, 3124]
   
    
    if start_station in stations_more_10_stolen:
        folium.Marker(location = [lat, lon],
                  popup= f"{start_station}",
                  icon=folium.Icon(color="red")
                   ).add_to(map4)
    
    else:
        folium.Marker(location = [lat, lon],
                  popup= f"{start_station}",
                  icon=folium.Icon(color="green")
                   ).add_to(map4)

    
map4
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_254af563abcf3cb847e4bf00f468a530 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_254af563abcf3cb847e4bf00f468a530&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_254af563abcf3cb847e4bf00f468a530 = L.map(
#                 &quot;map_254af563abcf3cb847e4bf00f468a530&quot;,
#                 {
#                     center: [39.9505, -75.1755],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_8b2c145d4f5fce5dfcc97aca33509479 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_254af563abcf3cb847e4bf00f468a530);
#
#
#             var marker_98d396353696fa1ee518ce4ba4617baa = L.marker(
#                 [39.943909, -75.167351],
#                 {}
#             ).addTo(map_254af563abcf3cb847e4bf00f468a530);
#
#
#             var icon_e2b6ece37a1dd5445d6fd299062bfe46 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_98d396353696fa1ee518ce4ba4617baa.setIcon(icon_e2b6ece37a1dd5445d6fd299062bfe46);
#
#
#         var popup_3724ec877923d867bbdac2a4dede0144 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_2f51c5669838b7d3f569eba59e4720a4 = $(`&lt;div id=&quot;html_2f51c5669838b7d3f569eba59e4720a4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;3125&lt;/div&gt;`)[0];
#                 popup_3724ec877923d867bbdac2a4dede0144.setContent(html_2f51c5669838b7d3f569eba59e4720a4);
#
#
#
#         marker_98d396353696fa1ee518ce4ba4617baa.bindPopup(popup_3724ec877923d867bbdac2a4dede0144)
#         ;
#
#
#
#
#             var marker_16115b8c4fa583a6918b91166257325a = L.marker(
#                 [39.95472, -75.183228],
#                 {}
#             ).addTo(map_254af563abcf3cb847e4bf00f468a530);
#
#
#             var icon_795c14fc2f7ecb8d509239164885148f = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_16115b8c4fa583a6918b91166257325a.setIcon(icon_795c14fc2f7ecb8d509239164885148f);
#
#
#         var popup_971e932fc86f17f25fa824dbdc7dbc3c = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_09e381179c99e83d8c88090825baf4d9 = $(`&lt;div id=&quot;html_09e381179c99e83d8c88090825baf4d9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;3022&lt;/div&gt;`)[0];
#                 popup_971e932fc86f17f25fa824dbdc7dbc3c.setContent(html_09e381179c99e83d8c88090825baf4d9);
#
#
#
#         marker_16115b8c4fa583a6918b91166257325a.bindPopup(popup_971e932fc86f17f25fa824dbdc7dbc3c)
#         ;
#
#
#
#
#             var marker_a90a947a5a2af4801510a8d5a00ee4e3 = L.marker(
#                 [39.94561, -75.173477],
#                 {}
#             ).addTo(map_254af563abcf3cb847e4bf00f468a530);
#
#
#             var icon_fb12b707416d51af3373a222e191541c = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_a90a947a5a2af4801510a8d5a00ee4e3.setIcon(icon_fb12b707416d51af3373a222e191541c);
#
#
#         var popup_866a94e10c40a596b1fbae1c2418961c = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_ad95f9a2083c7aeb4d91d4ff62231372 = $(`&lt;div id=&quot;html_ad95f9a2083c7aeb4d91d4ff62231372&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;3066&lt;/div&gt;`)[0];
#                 popup_866a94e10c40a596b1fbae1c2418961c.setContent(html_ad95f9a2083c7aeb4d91d4ff62231372);
#
#
#
#         marker_a90a947a5a2af4801510a8d5a00ee4e3.bindPopup(popup_866a94e10c40a596b1fbae1c2418961c)
#         ;
#
#
#
#
#             var marker_fcbeace6068672e677f902853e25bda5 = L.marker(
#                 [39.947922, -75.162369],
#                 {}
#             ).addTo(map_254af563abcf3cb847e4bf00f468a530);
#
#
#             var icon_a43499ddf2822a1f1c4d9232d2831f44 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;icon

# %%
# average duration from start station
Phil_avg_duration = Phil.groupby(["start_station"])["duration"].mean()

print(Phil_avg_duration)
# Out:
# start_station
# 3004    24.112788
# 3005    21.169108
# 3006    19.815217
# 3007    14.590131
# 3008    16.751515
# 3009    16.723341
# 3010    15.937320
# 3011    17.099308
# 3012    13.093976
# 3013    16.748751
# 3014    17.625294
# 3015    18.881664
# 3016    17.475516
# 3017    21.478941
# 3018    21.416253
# 3019    20.304702
# 3020    12.611675
# 3021    15.271242
# 3022    16.934353
# 3024    24.264880
# 3025    13.889436
# 3026    18.746129
# 3028    17.384089
# 3029    16.987956
# 3030    13.776881
# 3031    21.104337
# 3032    13.638845
# 3033    15.068985
# 3034    14.300766
# 3035    13.728510
# 3037    18.607728
# 3038    14.232616
# 3039    18.313466
# 3040    14.626007
# 3041    22.433333
# 3043    15.619473
# 3045    17.073339
# 3046    19.339237
# 3047    22.555872
# 3049    27.628320
# 3050    18.812410
# 3051    18.418761
# 3052    14.348338
# 3053    17.716600
# 3054    16.297954
# 3055    20.924838
# 3056    20.944457
# 3057    36.364367
# 3058    15.725910
# 3059    17.012354
# 3060    19.293828
# 3061    15.636403
# 3062    17.337345
# 3063    13.160626
# 3064    14.266807
# 3065    19.089969
# 3066    12.462563
# 3067    19.318748
# 3068    15.890321
# 3069    15.455128
# 3070    20.270327
# 3071    18.532936
# 3072    20.055508
# 3073    16.694175
# 3074    18.718128
# 3075    14.835140
# 3077    16.474277
# 3078    16.883186
# 3086    14.106663
# 3088    21.526115
# 3093    46.585987
# 3096    42.896181
# 3097    24.581400
# 3098    19.713242
# 3099    17.790536
# 3100    19.174047
# 3101    16.115194
# 3102    20.322197
# 3104    20.005697
# 3106    39.858595
# 3107    31.191822
# 3108    22.503307
# 3110    24.205316
# 3111    40.969593
# 3112    21.958473
# 3113    30.877839
# 3114    13.842814
# 3115    15.657320
# 3116    20.707993
# 3117    38.827839
# 3118    21.897273
# 3119    22.170837
# 3120    22.770470
# 3121    17.772527
# 3123    23.248677
# 3124    25.089052
# 3125    15.046590
# 3150    17.330078
# 3152    20.046689
# 3153    24.043666
# 3154    15.242387
# 3155    15.307895
# 3156    16.830007
# 3157    19.892027
# 3158    21.273877
# 3159    15.949798
# 3160    17.520978
# 3161    16.961675
# 3162    16.775428
# 3163    22.469194
# 3164    17.221301
# 3165    20.996478
# 3166    21.557734
# 3167    18.222980
# 3168    16.463516
# 3169    18.692067
# 3170    14.050184
# 3181    32.290503
# 3182    18.241535
# 3183    29.603615
# 3184    13.967991
# 3185    20.244742
# 3186    25.118079
# 3187    18.102277
# 3188    29.517694
# 3190    16.639038
# 3192    19.375547
# 3196    38.273458
# 3197    21.463192
# 3200    18.809221
# 3201    17.898436
# 3202    22.523250
# 3203    12.185878
# 3204    13.119522
# 3205    17.040336
# 3206    18.855988
# 3207    16.248076
# 3208    13.860635
# 3209    20.591451
# 3210    28.129147
# 3211    16.888534
# 3212    35.254991
# 3213    17.305344
# 3214    26.898709
# 3226    19.695294
# 3233    19.007109
# 3234    13.903217
# 3235    15.138963
# 3236    21.209084
# 3237    26.959231
# 3238    14.998213
# 3240    21.420440
# 3241    30.396528
# 3243    26.852688
# 3244    14.389625
# 3245    18.681386
# 3246    22.970713
# 3247    26.341246
# 3248    14.049021
# 3249    15.330045
# 3250    17.507173
# 3251    25.168570
# 3252    17.307993
# 3253    25.082240
# 3254    18.620595
# 3255    20.304357
# 3256    14.797250
# 3257    24.060564
# 3258    27.096689
# 3259    16.610842
# 3261    16.746238
# 3263    15.448529
# 3264    12.948393
# 3265    15.592245
# 3266    23.280527
# 3267    27.248480
# 3271    31.213256
# 3272    27.507764
# 3273    44.548140
# 3275    29.285347
# 3276    16.871847
# 3277    28.144444
# 3278    44.900735
# 3279    15.336766
# 3280    28.924171
# 3281    39.487069
# 3282    42.211268
# 3284    47.321429
# 3285    11.922078
# 3286    13.186798
# 3287    14.825269
# 3291    41.590909
# 3294    18.283099
# 3295    16.827607
# 3296    20.898112
# 3298    20.613636
# 3299    17.289308
# 3300    15.479167
# Name: duration, dtype: float64

# %%
count_true = (Phil["duration"] < 4).sum()
print(count_true)
# Out:
# 82649

# %%
# data saved as new .csv for each season 

Phil["season"] = ""

for index, row in Phil.iterrows():
    
    date = row["Date_s"]
    month = int (date.split("-")[1])
    
    if 3 <= month <= 5:
        Phil.at[index, "season"] = "spring"
    elif 6 <= month <= 8:
         Phil.at[index, "season"] = "summer"
    elif 9 <= month <= 11:
         Phil.at[index, "season"] = "autumn"
    else:
         Phil.at[index, "season"] = "winter"
    
# because of long computing time build new dataframe for each season
for season in Phil["season"].unique():
    season_Phil = Phil[Phil["season"] == season]
    season_Phil.to_csv(f"{season}.csv", index=False)

# %%
#read season csv
Phil_winter = pd.read_csv('winter.csv', low_memory=False)
Phil_spring = pd.read_csv('spring.csv', low_memory=False)
Phil_summer = pd.read_csv('summer.csv', low_memory=False)
Phil_autumn = pd.read_csv('autumn.csv', low_memory=False)

# %%
#unique data winter
Phil_winter.nunique()
# Out:
# trip_id                207215
# duration                  613
# start_time             114828
# end_time               114604
# start_station             198
# end_station               198
# bike_id                  2200
# plan_duration               5
# trip_route_category         2
# passholder_type             4
# bike_type                   2
# Date_s                    180
# Weekday_s                   7
# Hour_s                     24
# Date_e                    184
# Weekday_e                   7
# Hour_e                     24
# start_coordinates         196
# end_coordinates           196
# season                      1
# dtype: int64

# %%
#unique data spring
Phil_spring.nunique()
# Out:
# trip_id                392691
# duration                  906
# start_time             159129
# end_time               158430
# start_station             181
# end_station               181
# bike_id                  1700
# plan_duration               4
# trip_route_category         2
# passholder_type             4
# bike_type                   2
# Date_s                    184
# Weekday_s                   7
# Hour_s                     24
# Date_e                    187
# Weekday_e                   7
# Hour_e                     24
# start_coordinates         181
# end_coordinates           181
# season                      1
# dtype: int64

# %%
#unique data summer
Phil_summer.nunique()
# Out:
# trip_id                551450
# duration                  987
# start_time             189348
# end_time               188675
# start_station             187
# end_station               187
# bike_id                  1963
# plan_duration               4
# trip_route_category         2
# passholder_type             4
# bike_type                   2
# Date_s                    184
# Weekday_s                   7
# Hour_s                     24
# Date_e                    186
# Weekday_e                   7
# Hour_e                     24
# start_coordinates         187
# end_coordinates           187
# season                      1
# dtype: int64

# %%
#unique data autumn
Phil_autumn.nunique()
# Out:
# trip_id                527794
# duration                  870
# start_time             179129
# end_time               178921
# start_station             194
# end_station               193
# bike_id                  2120
# plan_duration               4
# trip_route_category         2
# passholder_type             3
# bike_type                   2
# Date_s                    182
# Weekday_s                   7
# Hour_s                     24
# Date_e                    184
# Weekday_e                   7
# Hour_e                     24
# start_coordinates         192
# end_coordinates           191
# season                      1
# dtype: int64

# %%
#trips on each season
trips_winter = Phil_winter["trip_id"].nunique()
trips_spring = Phil_spring["trip_id"].nunique()
trips_summer = Phil_summer["trip_id"].nunique()
trips_autumn = Phil_autumn["trip_id"].nunique()

print(f"Winter: {trips_winter}\nSpring: {trips_spring}\nSummer: {trips_summer}\nAutumn: {trips_autumn}")
# Out:
# Winter: 207215
# Spring: 392691
# Summer: 551450
# Autumn: 527794

# %%
# Usage per hour winter
hour = Phil_winter.groupby(['Hour_s'])['trip_id'].nunique()
fig, ax = plt.subplots(figsize=(16, 9), dpi=110)
ax.bar(hour.index, hour)
plt.title("No. of bike trips per hour in winter")
plt.xlabel("Hour")
plt.ylabel("Number of trips")


plt.show()

# %%
# Usage per hour spring
hour = Phil_spring.groupby(['Hour_s'])['trip_id'].nunique()
fig, ax = plt.subplots(figsize=(16, 9), dpi=110)
ax.bar(hour.index, hour)
plt.title("No. of bike trips per hour in spring")
plt.xlabel("Hour")
plt.ylabel("Number of trips")


plt.show()

# %%
# Usage per hour summer
hour = Phil_summer.groupby(['Hour_s'])['trip_id'].nunique()
fig, ax = plt.subplots(figsize=(16, 9), dpi=110)
ax.bar(hour.index, hour)
plt.title("No. of bike trips per hour in summer")
plt.xlabel("Hour")
plt.ylabel("Number of trips")


plt.show()

# %%
# Usage per hour autumn
hour = Phil_autumn.groupby(['Hour_s'])['trip_id'].nunique()
fig, ax = plt.subplots(figsize=(16, 9), dpi=110)
ax.bar(hour.index, hour)
plt.title("No. of bike trips per hour in autumn")
plt.xlabel("Hour")
plt.ylabel("Number of trips")


plt.show()

# %% [markdown]
# As we can see each season is uniformly distributed.
# In this case we should schedule maintenance to seasons winter and spring.

# %%
#boxplot of accumulated usage of bikes in winter
Phil_winter_bp = Phil_winter.groupby("Weekday_s")["trip_id"].cumsum()

plt.figure(figsize=(8, 6))
sns.boxplot(x=Phil_winter["Weekday_s"], y=Phil_winter_bp)
plt.xlabel("Weekday")
plt.ylabel("Accumulated count of trip_id")
plt.title("Usage winter")
plt.xticks(ticks=range(7), labels=["monday", "tuesday", "wednesday", "thursday", "friday", "saturday", "sunday"])
plt.show()

# %%
Phil_spring_bp = Phil_spring.groupby("Weekday_s")["trip_id"].cumsum()

plt.figure(figsize=(8, 6))
sns.boxplot(x=Phil_spring["Weekday_s"], y=Phil_spring_bp)
plt.xlabel("Weekday")
plt.ylabel("Accumulated count of trip_id")
plt.title("Usage spring")
plt.xticks(ticks=range(7), labels=["monday", "tuesday", "wednesday", "thursday", "friday", "saturday", "sunday"])
plt.show()

# %%
#first date for each start station
first_start_station_date = Phil.groupby('start_station')['Date_e'].first().reset_index()
first_start_station_list = first_start_station_date.values.tolist()
first_start_station_date = first_start_station_date.sort_values('Date_e')
first_start_station_date.reset_index(drop=True, inplace=True)

#pd.set_option('display.max_rows', len(first_start_station_date)) #show all rows

first_start_station_date.head() # len(first_start_station_date)
# Out:
#    start_station      Date_e
# 0           3004  2021-01-01
# 1           3153  2021-01-01
# 2           3213  2021-01-01
# 3           3150  2021-01-01
# 4           3125  2021-01-01

# %%
#days of usage for each station
end_date = pd.to_datetime("2022-12-31")
first_start_station_date["days_of_usage"] = (end_date - pd.to_datetime(first_start_station_date['Date_e'])).dt.days

print(first_start_station_date)
# Out:
#      start_station      Date_e  days_of_usage
# 0             3004  2021-01-01            729
# 1             3153  2021-01-01            729
# 2             3213  2021-01-01            729
# 3             3150  2021-01-01            729
# 4             3125  2021-01-01            729
# 5             3124  2021-01-01            729
# 6             3121  2021-01-01            729
# 7             3120  2021-01-01            729
# 8             3119  2021-01-01            729
# 9             3118  2021-01-01            729
# 10            3117  2021-01-01            729
# 11            3116  2021-01-01            729
# 12            3115  2021-01-01            729
# 13            3114  2021-01-01            729
# 14            3112  2021-01-01            729
# 15            3108  2021-01-01            729
# 16            3107  2021-01-01            729
# 17            3106  2021-01-01            729
# 18            3104  2021-01-01            729
# 19            3102  2021-01-01            729
# 20            3101  2021-01-01            729
# 21            3099  2021-01-01            729
# 22            3098  2021-01-01            729
# 23            3086  2021-01-01            729
# 24            3078  2021-01-01            729
# 25            3077  2021-01-01            729
# 26            3075  2021-01-01            729
# 27            3074  2021-01-01            729
# 28            3154  2021-01-01            729
# 29            3072  2021-01-01            729
# 30            3155  2021-01-01            729
# 31            3157  2021-01-01            729
# 32            3208  2021-01-01            729
# 33            3207  2021-01-01            729
# 34            3206  2021-01-01            729
# 35            3205  2021-01-01            729
# 36            3204  2021-01-01            729
# 37            3203  2021-01-01            729
# 38            3202  2021-01-01            729
# 39            3201  2021-01-01            729
# 40            3200  2021-01-01            729
# 41            3197  2021-01-01            729
# 42            3196  2021-01-01            729
# 43            3190  2021-01-01            729
# 44            3187  2021-01-01            729
# 45            3211  2021-01-01            729
# 46            3183  2021-01-01            729
# 47            3182  2021-01-01            729
# 48            3168  2021-01-01            729
# 49            3167  2021-01-01            729
# 50            3166  2021-01-01            729
# 51            3165  2021-01-01            729
# 52            3164  2021-01-01            729
# 53            3163  2021-01-01            729
# 54            3162  2021-01-01            729
# 55            3161  2021-01-01            729
# 56            3160  2021-01-01            729
# 57            3212  2021-01-01            729
# 58            3158  2021-01-01            729
# 59            3156  2021-01-01            729
# 60            3071  2021-01-01            729
# 61            3088  2021-01-01            729
# 62            3069  2021-01-01            729
# 63            3041  2021-01-01            729
# 64            3040  2021-01-01            729
# 65            3039  2021-01-01            729
# 66            3070  2021-01-01            729
# 67            3037  2021-01-01            729
# 68            3035  2021-01-01            729
# 69            3034  2021-01-01            729
# 70            3033  2021-01-01            729
# 71            3032  2021-01-01            729
# 72            3031  2021-01-01            729
# 73            3030  2021-01-01            729
# 74            3029  2021-01-01            729
# 75            3028  2021-01-01            729
# 76            3043  2021-01-01            729
# 77            3214  2021-01-01            729
# 78            3024  2021-01-01            729
# 79            3022  2021-01-01            729
# 80            3021  2021-01-01            729
# 81            3020  2021-01-01            729
# 82            3019  2021-01-01            729
# 83            3018  2021-01-01            729
# 84            3014  2021-01-01            729
# 85            3013  2021-01-01            729
# 86            3012  2021-01-01            729
# 87            3011  2021-01-01            729
# 88            3010  2021-01-01            729
# 89            3007  2021-01-01            729
# 90            3006  2021-01-01            729
# 91            3025  2021-01-01            729
# 92            3045  2021-01-01            729
# 93            3038  2021-01-01            729
# 94            3210  2021-01-01            729
# 95            3064  2021-01-01            729
# 96            3065  2021-01-01            729
# 97            3066  2021-01-01            729
# 98            3063  2021-01-01            729
# 99            3067  2021-01-01            729
# 100           3061  2021-01-01            729
# 101           3060  2021-01-01            729
# 102           3059  2021-01-01            729
# 103           3057  2021-01-01            729
# 104           3056  2021-01-01            729
# 105           3058  2021-01-01            729
# 106           3068  2021-01-01            729
# 107           3049  2021-01-01            729
# 108           3050  2021-01-01            729
# 109           3052  2021-01-01            729
# 110           3053  2021-01-01            729
# 111           3051  2021-01-01            729
# 112           3055  2021-01-01            729
# 113           3054  2021-01-01            729
# 114           3009  2021-01-02            728
# 115           3073  2021-01-02            728
# 116           3008  2021-01-02            728
# 117           3016  2021-01-02            728
# 118           3005  2021-01-02            728
# 119           3209  2021-01-02            728
# 120           3015  2021-01-02            728
# 121           3192  2021-01-02            728
# 122           3188  2021-01-02            728
# 123           3123  2021-01-02            728
# 124           3186  2021-01-02            728
# 125           3185  2021-01-02            728
# 126           3093  2021-01-02            728
# 127           3096  2021-01-02            728
# 128           3097  2021-01-02            728
# 129           3181  2021-01-02            728
# 130           3046  2021-01-02            728
# 131           3169  2021-01-02            728
# 132           3062  2021-01-02            728
# 133           3100  2021-01-02            728
# 134           3110  2021-01-02            728
# 135           3111  2021-01-02            728
# 136           3113  2021-01-02            728
# 137           3047  2021-01-02            728
# 138           3017  2021-01-02            728
# 139           3170  2021-01-02            728
# 140           3152  2021-01-03            727
# 141           3159  2021-01-03            727
# 142           3184  2021-01-03            727
# 143           3226  2021-01-07            723
# 144           3234  2021-05-11            599
# 145           3233  2021-05-14            596
# 146           3235  2021-05-19            591
# 147           3237  2021-05-22            588
# 148           3236  2021-06-01            578
# 149           3238  2021-06-01            578
# 150           3241  2021-06-15            564
# 151           3026  2021-06-23            556
# 152           3240  2021-06-25            554
# 153           3243  2021-07-08            541
# 154           3245  2021-07-13            536
# 155           3244  2021-07-15            534
# 156           3247  2021-07-23            526
# 157           3246  2021-07-27            522
# 158           3248  2021-08-02            516
# 159           3249  2021-08-16            502
# 160           3251  2021-08-18            500
# 161           3252  2021-08-23            495
# 162           3253  2021-08-31            487
# 163           3255  2021-09-02            485
# 164           3256  2021-09-21            466
# 165           3254  2021-09-22            465
# 166           3250  2021-09-28            459
# 167           3257  2021-10-19            438
# 168           3258  2021-10-23            434
# 169           3259  2021-11-05            421
# 170           3261  2021-12-02            394
# 171           3266  2022-02-15            319
# 172           3267  2022-02-17            317
# 173           3263  2022-02-23            311
# 174           3271  2022-03-03            303
# 175           3272  2022-03-11            295
# 176           3265  2022-03-31            275
# 177           3275  2022-04-22            253
# 178           3276  2022-04-22            253
# 179           3273  2022-05-08            237
# 180           3264  2022-05-19            226
# 181           3277  2022-06-25            189
# 182           3278  2022-06-29            185
# 183           3279  2022-07-06            178
# 184           3280  2022-07-13            171
# 185           3282  2022-07-21            163
# 186           3281  2022-07-28            156
# 187           3287  2022-09-07            115
# 188           3286  2022-10-06             86
# 189           3296  2022-10-11             81
# 190           3284  2022-10-25             67
# 191           3291  2022-11-03             58
# 192           3295  2022-11-03             58
# 193           3294  2022-11-09             52
# 194           3298  2022-11-16             45
# 195           3285  2022-11-29             32
# 196           3300  2022-12-07             24
# 197           3299  2022-12-08             23

# %%
# average usage per day for each station to the number of usage days

average_usage_per_day = {}
for start_station, count in start_counter.items():
    days_of_usage = first_start_station_date[first_start_station_date['start_station'] == start_station]['days_of_usage'].values[0]
    average_usage_per_day[start_station] = count / days_of_usage
    
sorted_average_usage_per_day = sorted(average_usage_per_day.items(), key=lambda x: x[1])

for start_station, average_usage in sorted_average_usage_per_day:
    print(f"start_station {start_station}: average daily usage {average_usage}")
# Out:
# start_station 3284: average daily usage 0.835820895522388
# start_station 3282: average daily usage 0.8711656441717791
# start_station 3298: average daily usage 0.9777777777777777
# start_station 3096: average daily usage 1.151098901098901
# start_station 3280: average daily usage 1.2339181286549707
# start_station 3214: average daily usage 1.3813443072702332
# start_station 3240: average daily usage 1.3953068592057762
# start_station 3278: average daily usage 1.4702702702702704
# start_station 3281: average daily usage 1.4871794871794872
# start_station 3291: average daily usage 1.5172413793103448
# start_station 3196: average daily usage 1.5349794238683128
# start_station 3243: average daily usage 1.7190388170055453
# start_station 3277: average daily usage 1.9047619047619047
# start_station 3247: average daily usage 1.9220532319391634
# start_station 3093: average daily usage 1.940934065934066
# start_station 3181: average daily usage 1.967032967032967
# start_station 3300: average daily usage 2.0
# start_station 3183: average daily usage 2.1248285322359397
# start_station 3272: average daily usage 2.183050847457627
# start_station 3113: average daily usage 2.2376373626373627
# start_station 3117: average daily usage 2.246913580246914
# start_station 3271: average daily usage 2.2904290429042904
# start_station 3226: average daily usage 2.351313969571231
# start_station 3285: average daily usage 2.40625
# start_station 3186: average daily usage 2.8035714285714284
# start_station 3251: average daily usage 2.978
# start_station 3213: average daily usage 3.054869684499314
# start_station 3106: average daily usage 3.1042524005486967
# start_station 3287: average daily usage 3.234782608695652
# start_station 3258: average daily usage 3.47926267281106
# start_station 3119: average daily usage 3.5089163237311385
# start_station 3016: average daily usage 3.590659340659341
# start_station 3111: average daily usage 3.614010989010989
# start_station 3253: average daily usage 4.069815195071868
# start_station 3067: average daily usage 4.075445816186557
# start_station 3107: average daily usage 4.126200274348422
# start_station 3267: average daily usage 4.151419558359621
# start_station 3123: average daily usage 4.153846153846154
# start_station 3263: average daily usage 4.372990353697749
# start_station 3192: average daily usage 4.707417582417582
# start_station 3257: average daily usage 4.938356164383562
# start_station 3200: average daily usage 4.968449931412894
# start_station 3241: average daily usage 5.1063829787234045
# start_station 3237: average daily usage 5.130952380952381
# start_station 3184: average daily usage 5.156808803301238
# start_station 3104: average daily usage 5.297668038408779
# start_station 3153: average daily usage 5.403292181069959
# start_station 3279: average daily usage 5.455056179775281
# start_station 3254: average daily usage 5.49247311827957
# start_station 3188: average daily usage 5.550824175824176
# start_station 3250: average daily usage 5.618736383442266
# start_station 3065: average daily usage 5.702331961591221
# start_station 3276: average daily usage 5.798418972332016
# start_station 3246: average daily usage 5.8869731800766285
# start_station 3115: average daily usage 5.968449931412894
# start_station 3275: average daily usage 6.150197628458498
# start_station 3152: average daily usage 6.481430536451169
# start_station 3070: average daily usage 6.545953360768175
# start_station 3008: average daily usage 6.572802197802198
# start_station 3017: average daily usage 6.587912087912088
# start_station 3019: average daily usage 6.739368998628258
# start_station 3118: average daily usage 6.890260631001372
# start_station 3266: average daily usage 6.905956112852665
# start_station 3299: average daily usage 6.913043478260869
# start_station 3011: average daily usage 6.934156378600823
# start_station 3112: average daily usage 6.969821673525377
# start_station 3252: average daily usage 7.228282828282828
# start_station 3259: average daily usage 7.3610451306413305
# start_station 3014: average daily usage 7.58161865569273
# start_station 3097: average daily usage 7.695054945054945
# start_station 3211: average daily usage 7.7407407407407405
# start_station 3233: average daily usage 8.025167785234899
# start_station 3286: average daily usage 8.279069767441861
# start_station 3077: average daily usage 8.39917695473251
# start_station 3013: average daily usage 8.511659807956104
# start_station 3110: average daily usage 8.630494505494505
# start_station 3265: average daily usage 8.909090909090908
# start_station 3166: average daily usage 8.95747599451303
# start_station 3150: average daily usage 8.989026063100138
# start_station 3197: average daily usage 9.0
# start_station 3024: average daily usage 9.05761316872428
# start_station 3209: average daily usage 9.094780219780219
# start_station 3060: average daily usage 9.178326474622772
# start_station 3099: average daily usage 9.246913580246913
# start_station 3210: average daily usage 9.262002743484224
# start_station 3005: average daily usage 9.657967032967033
# start_station 3072: average daily usage 9.662551440329219
# start_station 3187: average daily usage 10.058984910836763
# start_station 3071: average daily usage 10.12071330589849
# start_station 3120: average daily usage 10.554183813443073
# start_station 3062: average daily usage 10.729395604395604
# start_station 3273: average daily usage 11.0
# start_station 3086: average daily usage 11.034293552812072
# start_station 3236: average daily usage 11.046712802768166
# start_station 3031: average daily usage 11.069958847736626
# start_station 3165: average daily usage 11.293552812071331
# start_station 3248: average daily usage 11.385658914728682
# start_station 3004: average daily usage 11.541838134430726
# start_station 3124: average daily usage 11.55281207133059
# start_station 3041: average daily usage 11.563786008230453
# start_station 3015: average daily usage 11.619505494505495
# start_station 3235: average daily usage 11.981387478849408
# start_station 3170: average daily usage 12.317307692307692
# start_station 3039: average daily usage 12.336076817558299
# start_station 3157: average daily usage 12.386831275720164
# start_station 3056: average daily usage 12.422496570644718
# start_station 3073: average daily usage 12.45054945054945
# start_station 3121: average daily usage 12.452674897119342
# start_station 3261: average daily usage 12.48223350253807
# start_station 3162: average daily usage 12.582990397805213
# start_station 3088: average daily usage 12.60631001371742
# start_station 3234: average daily usage 12.609348914858098
# start_station 3249: average daily usage 12.723107569721115
# start_station 3245: average daily usage 13.139925373134329
# start_station 3205: average daily usage 13.229080932784637
# start_station 3204: average daily usage 13.301783264746227
# start_station 3164: average daily usage 13.407407407407407
# start_station 3294: average daily usage 13.653846153846153
# start_station 3098: average daily usage 13.705075445816187
# start_station 3074: average daily usage 13.92318244170096
# start_station 3158: average daily usage 13.989026063100138
# start_station 3053: average daily usage 14.056241426611797
# start_station 3038: average daily usage 14.223593964334706
# start_station 3069: average daily usage 14.566529492455418
# start_station 3025: average daily usage 15.32235939643347
# start_station 3169: average daily usage 15.340659340659341
# start_station 3049: average daily usage 15.59670781893004
# start_station 3116: average daily usage 15.60082304526749
# start_station 3159: average daily usage 15.645116918844566
# start_station 3043: average daily usage 15.666666666666666
# start_station 3068: average daily usage 15.858710562414267
# start_station 3075: average daily usage 16.07544581618656
# start_station 3155: average daily usage 16.10562414266118
# start_station 3201: average daily usage 16.396433470507546
# start_station 3051: average daily usage 16.480109739369
# start_station 3156: average daily usage 16.631001371742112
# start_station 3035: average daily usage 17.633744855967077
# start_station 3059: average daily usage 17.65432098765432
# start_station 3161: average daily usage 17.824417009602193
# start_station 3108: average daily usage 18.042524005486968
# start_station 3050: average daily usage 18.061728395061728
# start_station 3047: average daily usage 18.782967032967033
# start_station 3064: average daily usage 18.89437585733882
# start_station 3034: average daily usage 18.982167352537722
# start_station 3055: average daily usage 19.05349794238683
# start_station 3160: average daily usage 19.126200274348424
# start_station 3182: average daily usage 19.20164609053498
# start_station 3040: average daily usage 19.410150891632373
# start_station 3264: average daily usage 19.548672566371682
# start_station 3100: average daily usage 19.604395604395606
# start_station 3030: average daily usage 20.054869684499312
# start_station 3114: average daily usage 20.06310013717421
# start_station 3006: average daily usage 20.444444444444443
# start_station 3255: average daily usage 20.445360824742266
# start_station 3256: average daily usage 20.914163090128756
# start_station 3058: average daily usage 20.954732510288064
# start_station 3163: average daily usage 21.061728395061728
# start_station 3026: average daily usage 21.140287769784173
# start_station 3033: average daily usage 21.45541838134431
# start_station 3125: average daily usage 21.463648834019203
# start_station 3078: average daily usage 21.59533607681756
# start_station 3037: average daily usage 21.761316872427983
# start_station 3206: average daily usage 21.89849108367627
# start_station 3203: average daily usage 21.93278463648834
# start_station 3061: average daily usage 22.11934156378601
# start_station 3018: average daily usage 22.39917695473251
# start_station 3009: average daily usage 22.99313186813187
# start_station 3029: average daily usage 23.006858710562415
# start_station 3021: average daily usage 23.16735253772291
# start_station 3207: average daily usage 23.16872427983539
# start_station 3020: average daily usage 23.26474622770919
# start_station 3063: average daily usage 24.637860082304528
# start_station 3238: average daily usage 25.17128027681661
# start_station 3244: average daily usage 26.425093632958802
# start_station 3154: average daily usage 26.530864197530864
# start_station 3012: average daily usage 27.281207133058984
# start_station 3057: average daily usage 27.80246913580247
# start_station 3022: average daily usage 28.083676268861453
# start_station 3185: average daily usage 28.410714285714285
# start_station 3295: average daily usage 28.603448275862068
# start_station 3102: average daily usage 29.150891632373114
# start_station 3046: average daily usage 29.550824175824175
# start_station 3028: average daily usage 30.48559670781893
# start_station 3066: average daily usage 30.998628257887518
# start_station 3101: average daily usage 31.282578875171467
# start_station 3296: average daily usage 31.382716049382715
# start_station 3212: average daily usage 33.60082304526749
# start_station 3054: average daily usage 34.72702331961591
# start_station 3052: average daily usage 34.862825788751714
# start_station 3045: average daily usage 34.920438957475994
# start_station 3167: average daily usage 34.97942386831276
# start_station 3168: average daily usage 35.81207133058985
# start_station 3208: average daily usage 36.52674897119341
# start_station 3007: average daily usage 37.249657064471876
# start_station 3202: average daily usage 38.1440329218107
# start_station 3032: average daily usage 38.7037037037037
# start_station 3190: average daily usage 39.86831275720164
# start_station 3010: average daily usage 42.960219478738

# %%
# map with average daily usage

average_usage_df = pd.DataFrame.from_dict(average_usage_per_day, orient="index", columns=["Average_daily_usage"])
average_usage_df.reset_index(inplace=True)
average_usage_df.rename(columns={"index": "start_station"}, inplace=True)

map5 = folium.Map(location=[39.95, -75.14], zoom_start=12)

color_palette = ['darkred', 'red', 'lightred', 'white', 'lightblue', 'blue', 'darkblue']

for start_coordinates, start_station in unique_coordinates:
    lat, lon = start_coordinates.split(",")
    lat = float(lat)
    lon = float(lon)
    
    average_usage = average_usage_df.loc[average_usage_df["start_station"] == start_station, "Average_daily_usage"].values[0]
    
    color_index = min(int(average_usage / 5), len(color_palette) - 1)
    marker_color = color_palette[color_index]
    
    popup_message = f"Station: {start_station}<br>Average Daily Usage: {average_usage}"
    
    folium.Marker(location=[lat, lon],
                  popup=popup_message,
                  icon=folium.Icon(color=marker_color)
                 ).add_to(map5)
map5
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_f0596aacbe3baeeab5dc1310a82ec72f {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_f0596aacbe3baeeab5dc1310a82ec72f&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_f0596aacbe3baeeab5dc1310a82ec72f = L.map(
#                 &quot;map_f0596aacbe3baeeab5dc1310a82ec72f&quot;,
#                 {
#                     center: [39.95, -75.14],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_138d79c26ff304245df9c2b9cfc34504 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_f0596aacbe3baeeab5dc1310a82ec72f);
#
#
#             var marker_241ba925923a497b1d06776c55999907 = L.marker(
#                 [39.943909, -75.167351],
#                 {}
#             ).addTo(map_f0596aacbe3baeeab5dc1310a82ec72f);
#
#
#             var icon_ea4433bd19e89e47da5cd81d8ed8ec5a = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;lightblue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_241ba925923a497b1d06776c55999907.setIcon(icon_ea4433bd19e89e47da5cd81d8ed8ec5a);
#
#
#         var popup_40b1c86ee088c2d66f9286ae13e09c46 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_a87737d82198a9308744a59cb15cf851 = $(`&lt;div id=&quot;html_a87737d82198a9308744a59cb15cf851&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Station: 3125&lt;br&gt;Average Daily Usage: 21.463648834019203&lt;/div&gt;`)[0];
#                 popup_40b1c86ee088c2d66f9286ae13e09c46.setContent(html_a87737d82198a9308744a59cb15cf851);
#
#
#
#         marker_241ba925923a497b1d06776c55999907.bindPopup(popup_40b1c86ee088c2d66f9286ae13e09c46)
#         ;
#
#
#
#
#             var marker_81e2d6cb320b306207cc3ce167e103bb = L.marker(
#                 [39.95472, -75.183228],
#                 {}
#             ).addTo(map_f0596aacbe3baeeab5dc1310a82ec72f);
#
#
#             var icon_db54e84ba5481f48f5e944235b636175 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_81e2d6cb320b306207cc3ce167e103bb.setIcon(icon_db54e84ba5481f48f5e944235b636175);
#
#
#         var popup_7c8939aee66f82c46fa909b486d88461 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_7848610bf6af7a8170b3f8912b1e3106 = $(`&lt;div id=&quot;html_7848610bf6af7a8170b3f8912b1e3106&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Station: 3022&lt;br&gt;Average Daily Usage: 28.083676268861453&lt;/div&gt;`)[0];
#                 popup_7c8939aee66f82c46fa909b486d88461.setContent(html_7848610bf6af7a8170b3f8912b1e3106);
#
#
#
#         marker_81e2d6cb320b306207cc3ce167e103bb.bindPopup(popup_7c8939aee66f82c46fa909b486d88461)
#         ;
#
#
#
#
#             var marker_4dc6ee01887e0e12e3c12b0fb6c03da5 = L.marker(
#                 [39.94561, -75.173477],
#                 {}
#             ).addTo(map_f0596aacbe3baeeab5dc1310a82ec72f);
#
#
#             var icon_87be65b9cfb80099ed0d0fcf76ed0d7b = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;darkblue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_4dc6ee01887e0e12e3c12b0fb6c03da5.setIcon(icon_87be65b9cfb80099ed0d0fcf76ed0d7b);
#
#
#         var popup_fd344b876252877c40023979364f7f57 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_7ea2515f9e8949b06f01f891574f659f = $(`&lt;div id=&quot;html_7ea2515f9e8949b06f01f891574f659f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Station: 3066&lt;br&gt;Average Daily Usage: 30.998628257887518&lt;/div&gt;`)[0];
#                 popup_fd344b876252877c40023979364f7f57.setContent(html_7ea2515f9e8949b06f01f891574f659f);
#
#
#
#         marker_4dc6ee01887e0e12e3c12b0fb6c03da5.bindPopup(popup_fd344b876252877c40023979364f7f57)
#         ;
#
#
#
#
#             var marker_5c97d3ce2fbaa01ba935a7fc4a39782b = L.marker(
#                 [39.947922, -75.162369],
#                 {}
#             ).addTo(map_f0596aacbe3baeeab5dc1310a82ec72f);
#
#
#             var icon_0

# %%
import matplotlib.pyplot as plt

start_counter = Counter(Phil['start_station'])
start_counter_list = list(start_counter.items())
start_counter_list.sort(key=lambda x: x[1], reverse=True)

start_stations = [item[0] for item in start_counter_list]
start_counts = [item[1] for item in start_counter_list]

end_counter = Counter(Phil['end_station'])
end_counter_list = list(end_counter.items())
end_counter_list.sort(key=lambda x: x[1], reverse=True)

end_stations = [item[0] for item in end_counter_list]
end_counts = [item[1] for item in end_counter_list]  # Multiply by -1 to make the bars go from right to left

fig, ax = plt.subplots(figsize=(16, 28))
bar_width = 0.6

start_bar = ax.barh(range(len(start_stations)), start_counts, bar_width, align='center', color='blue', label='start station')
end_bar = ax.barh(range(len(end_stations)), end_counts, bar_width/3, align='center', color='orange', label='end station')

ax.set_yticks(range(len(start_stations)))
ax.set_yticklabels(start_stations[::-1])  # Reverse the order of start stations for better readability

ax.axvline(x=0, color='black', linewidth=0.5)  # Add a vertical line at x=0

ax.set_xlabel('amount')
ax.set_title('Count start and end station')

ax.legend()

plt.tight_layout()
plt.show()

# %%
idle time = duration bike was dropped of at station until another bike is booked (in avg for every station) each season?

# %% [markdown]
# # bis hier hin danach nur komische Dinge zu idle_time

# %%
Phil.sort_values("start_time", inplace=True)

Phil["idle_time"] = Phil.groupby(["start_station", "bike_id"])["start_time"].shift(-1) - Phil["end_time"]

Phil["idle_time"] = Phil["idle_time"].dt.total_seconds() / 60

print(Phil[["start_station", "bike_id", "end_time", "start_time", "idle_time"]].head())
# Out:
#    start_station bike_id            end_time          start_time  idle_time
# 0           3125   14542 2021-01-01 00:20:00 2021-01-01 00:05:00    37275.0
# 1           3022    5294 2021-01-01 00:20:00 2021-01-01 00:06:00     9365.0
# 2           3066   14586 2021-01-01 00:40:00 2021-01-01 00:07:00   239542.0
# 3           3045   14683 2021-01-01 00:22:00 2021-01-01 00:13:00   205571.0
# 4           3052    3330 2021-01-01 00:50:00 2021-01-01 00:37:00    51401.0

# %%
Phil.sort_values("start_time", inplace=True)

Phil["idle_time"] = Phil.groupby(["start_station", "bike_id"])["end_time"].shift(-1) - Phil["start_time"]

Phil["idle_time"] = Phil["idle_time"].dt.total_seconds() / 60

print(Phil[["start_station", "bike_id", "end_time", "start_time", "idle_time"]].head())
# Out:
#    start_station bike_id            end_time          start_time  idle_time
# 0           3125   14542 2021-01-01 00:20:00 2021-01-01 00:05:00    37336.0
# 1           3022    5294 2021-01-01 00:20:00 2021-01-01 00:06:00     9386.0
# 2           3066   14586 2021-01-01 00:40:00 2021-01-01 00:07:00   239581.0
# 3           3045   14683 2021-01-01 00:22:00 2021-01-01 00:13:00   205623.0
# 4           3052    3330 2021-01-01 00:50:00 2021-01-01 00:37:00    51428.0

# %%
idle_time_df = Phil.groupby(["trip_id",'start_station']).apply(lambda x: x['start_time'].shift(-1) - x['end_time']).reset_index()
print(idle_time_df)
idle_time_df.columns = ['start_station', 'index', 'idle_time']

# Berechnung des Durchschnitts der idle_time für jede Station
average_idle_time = idle_time_df.groupby('start_station')['idle_time'].mean().reset_index()

# Ausgabe der Ergebnisse
print(average_idle_time)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[174], line 1
# ----> 1 idle_time_df = Phil.groupby(["trip_id",'start_station']).apply(lambda x: x['start_time'].shift(-1) - x['end_time']).reset_index()
#       2 print(idle_time_df)
#       3 idle_time_df.columns = ['start_station', 'index', 'idle_time']
#
# File ~\anaconda3\lib\site-packages\pandas\core\groupby\groupby.py:1567, in GroupBy.apply(self, func, *args, **kwargs)
#    1559     new_msg = (
#    1560         f"The operation {orig_func} failed on a column. If any error is "
#    1561         f"raised, this will raise an exception in a future version "
#    1562         f"of pandas. Drop these columns to avoid this warning."
#    1563     )
#    1564     with rewrite_warning(
#    1565         old_msg, FutureWarning, new_msg
#    1566     ) if is_np_func else nullcontext():
# -> 1567         result = self._python_apply_general(f, self._selected_obj)
#    1568 except TypeError:
#    1569     # gh-20949
#    1570     # try again, with .apply acting as a filtering
#    (...)
#    1574     # fails on *some* columns, e.g. a numeric operation
#    1575     # on a string grouper column
#    1577     with self._group_selection_context():
#    1578         # GH#50538
#
# File ~\anaconda3\lib\site-packages\pandas\core\groupby\groupby.py:1658, in GroupBy._python_apply_general(self, f, data, not_indexed_same, is_transform, is_agg)
#    1651     # We want to behave as if `self.group_keys=False` when reconstructing
#    1652     # the object. However, we don't want to mutate the stateful GroupBy
#    1653     # object, so we just override it.
#    1654     # When this deprecation is enforced then override_group_keys
#    1655     # may be removed.
#    1656     override_group_keys = True
# -> 1658 return self._wrap_applied_output(
#    1659     data,
#    1660     values,
#    1661     not_indexed_same,
#    1662     override_group_keys=is_transform or override_group_keys,
#    1663 )
#
# File ~\anaconda3\lib\site-packages\pandas\core\groupby\generic.py:1066, in DataFrameGroupBy._wrap_applied_output(self, data, values, not_indexed_same, override_group_keys)
#    1063         return result
#    1064 else:
#    1065     # values are Series
# -> 1066     return self._wrap_applied_output_series(
#    1067         values,
#    1068         not_indexed_same,
#    1069         first_not_none,
#    1070         key_index,
#    1071         override_group_keys,
#    1072     )
#
# File ~\anaconda3\lib\site-packages\pandas\core\groupby\generic.py:1119, in DataFrameGroupBy._wrap_applied_output_series(self, values, not_indexed_same, first_not_none, key_index, override_group_keys)
#    1115         return concat(values)
#    1117 if not all_indexed_same:
#    1118     # GH 8467
# -> 1119     return self._concat_objects(
#    1120         values,
#    1121         not_indexed_same=True,
#    1122         override_group_keys=override_group_keys,
#    1123     )
#    1125 # Combine values
#    1126 # vstack+constructor is faster than concat and handles MI-columns
#    1127 stacked_values = np.vstack([np.asarray(v) for v in values])
#
# File ~\anaconda3\lib\site-packages\pandas\core\groupby\groupby.py:1149, in GroupBy._concat_objects(self, values, not_indexed_same, override_group_keys)
#    1146     group_levels = self.grouper.levels
#    1147     group_names = self.grouper.names
# -> 1149     result = concat(
#    1150         values,
#    1151         axis=self.axis,
#    1152         keys=group_keys,
#    1153         levels=group_levels,
#    1154         names=group_names,
#    1155         sort=False,
#    1156     )
#    1157 else:
#    1158
#    1159     # GH5610, returns a MI, with the first level being a
#    1160     # range index
#    1161     keys = list(range(len(values)))
#
# File ~\anaconda3\lib\site-packages\pandas\util\_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# File ~\anaconda3\lib\site-packages\pandas\core\reshape\concat.py:368, in concat(objs, axis, join, ignore_index, keys, levels, names, verify_integrity, sort, copy)
#     146 @deprecate_nonkeyword_arguments(version=None, allowed_args=["objs"])
#     147 def concat(
#     148     objs: Iterable[NDFrame] | Mapping[HashableT, NDFrame],
#    (...)
#     157     copy: bool = True,
#     158 ) -> DataFrame | Series:
#     159     """
#     160     Concatenate pandas objects along a particular axis.
#     161
#    (...)
#     366     1   3   4
#     367     """
# --> 368     op = _Concatenator(
#     369         objs,
#     370         axis=axis,
#     371         ignore_index=ignore_index,
#     372         join=join,
#     373         keys=keys,
#     374         levels=levels,
#     375         names=names,
#     376         verify_integrity=verify_integrity,
#     377         copy=copy,
#     378         sort=sort,
#     379     )
#     381     return op.get_result()
#
# File ~\anaconda3\lib\site-packages\pandas\core\reshape\concat.py:563, in _Concatenator.__init__(self, objs, axis, join, keys, levels, names, ignore_index, verify_integrity, copy, sort)
#     560 self.verify_integrity = verify_integrity
#     561 self.copy = copy
# --> 563 self.new_axes = self._get_new_axes()
#
# File ~\anaconda3\lib\site-packages\pandas\core\reshape\concat.py:633, in _Concatenator._get_new_axes(self)
#     631 def _get_new_axes(self) -> list[Index]:
#     632     ndim = self._get_result_dim()
# --> 633     return [
#     634         self._get_concat_axis if i == self.bm_axis else self._get_comb_axis(i)
#     635         for i in range(ndim)
#     636     ]
#
# File ~\anaconda3\lib\site-packages\pandas\core\reshape\concat.py:634, in <listcomp>(.0)
#     631 def _get_new_axes(self) -> list[Index]:
#     632     ndim = self._get_result_dim()
#     633     return [
# --> 634         self._get_concat_axis if i == self.bm_axis else self._get_comb_axis(i)
#     635         for i in range(ndim)
#     636     ]
#
# File ~\anaconda3\lib\site-packages\pandas\_libs\properties.pyx:36, in pandas._libs.properties.CachedProperty.__get__()
#
# File ~\anaconda3\lib\site-packages\pandas\core\reshape\concat.py:693, in _Concatenator._get_concat_axis(self)
#     691     concat_axis = _concat_indexes(indexes)
#     692 else:
# --> 693     concat_axis = _make_concat_multiindex(
#     694         indexes, self.keys, self.levels, self.names
#     695     )
#     697 self._maybe_check_integrity(concat_axis)
#     699 return concat_axis
#
# File ~\anaconda3\lib\site-packages\pandas\core\reshape\concat.py:749, in _make_concat_multiindex(indexes, keys, levels, names)
#     746 to_concat = []
#     747 for key, index in zip(hlevel, indexes):
#     748     # Find matching codes, include matching nan values as equal.
# --> 749     mask = (isna(level) & isna(key)) | (level == key)
#     750     if not mask.any():
#     751         raise ValueError(f"Key {key} not in level {level}")
#
# File ~\anaconda3\lib\site-packages\pandas\core\ops\common.py:57, in _unpack_zerodim_and_defer.<locals>.new_method(self, other)
#      40 """
#      41 Boilerplate for pandas conventions in arithmetic and comparison methods.
#      42
#    (...)
#      53 method
#      54 """
#      55 is_cmp = name.strip("__") in {"eq", "ne", "lt", "le", "gt", "ge"}
# ---> 57 @wraps(method)
#      58 def new_method(self, other):
#      60     if is_cmp and isinstance(self, ABCIndex) and isinstance(other, ABCSeries):
#      61         # For comparison ops, Index does *not* defer to Series
#      62         pass
#
# KeyboardInterrupt:

# %%
idle_time_df = Phil.groupby('end_station').apply(lambda x: x['start_time'].shift(-1) - x['end_time']).reset_index()
print(idle_time_df)
idle_time_df.columns = ['end_station', 'index', 'idle_time']

# Berechnung des Durchschnitts der idle_time für jede Station
average_idle_time = idle_time_df.groupby('end_station')['idle_time'].mean().reset_index()

# Ausgabe der Ergebnisse
print(average_idle_time)
# Out:
#          end_station  level_1                 0
# 0               3004      579   0 days 01:35:00
# 1               3004      778 -1 days +21:54:00
# 2               3004      776 -1 days +22:29:00
# 3               3004      853   0 days 00:27:00
# 4               3004     1035   0 days 00:18:00
# ...              ...      ...               ...
# 1781469         3300  1780495 -1 days +23:57:00
# 1781470         3300  1780496 -1 days +23:40:00
# 1781471         3300  1780498 -1 days +23:41:00
# 1781472         3300  1780500   0 days 22:58:00
# 1781473         3300  1781398               NaT
#
# [1781474 rows x 3 columns]
#      end_station                 idle_time
# 0           3004 0 days 01:39:12.947950253
# 1           3005 0 days 02:07:19.907640638
# 2           3006 0 days 00:55:52.005603893
# 3           3007 0 days 00:23:20.510856606
# 4           3008 0 days 03:35:00.849557522
# 5           3009 0 days 00:44:48.468930172
# 6           3010 0 days 00:18:11.343408629
# 7           3011 0 days 02:38:39.536842105
# 8           3012 0 days 00:44:57.892364356
# 9           3013 0 days 01:32:49.392991239
# 10          3014 0 days 02:50:50.827338129
# 11          3015 0 days 01:42:10.765879385
# 12          3016 0 days 05:59:18.414985590
# 13          3017 0 days 03:08:23.628318584
# 14          3018 0 days 00:42:06.991060178
# 15          3019 0 days 03:07:29.982089552
# 16          3020 0 days 00:58:37.443943168
# 17          3021 0 days 00:45:36.464259142
# 18          3022 0 days 00:33:51.509971509
# 19          3024 0 days 02:19:41.903103229
# 20          3025 0 days 01:16:02.054006968
# 21          3026 0 days 00:46:51.877127701
# 22          3028 0 days 00:27:37.384832542
# 23          3029 0 days 00:44:01.678763755
# 24          3030 0 days 00:56:23.659499183
# 25          3031 0 days 01:54:26.313253012
# 26          3032 0 days 00:22:35.936449740
# 27          3033 0 days 00:53:13.693716450
# 28          3034 0 days 00:58:50.111095485
# 29          3035 0 days 01:15:52.797233797
# 30          3037 0 days 00:45:03.082595870
# 31          3038 0 days 01:30:58.221120475
# 32          3039 0 days 01:49:46.289926289
# 33          3040 0 days 01:10:22.325695180
# 34          3041 0 days 01:27:40.193013741
# 35          3043 0 days 01:12:56.093722981
# 36          3045 0 days 00:24:32.238491273
# 37          3046 0 days 00:28:58.627784156
# 38          3047 0 days 00:55:22.348754448
# 39          3049 0 days 01:00:18.256263662
# 40          3050 0 days 01:00:59.846188645
# 41          3051 0 days 01:20:54.895065229
# 42          3052 0 days 00:26:31.170760007
# 43          3053 0 days 01:22:02.182667055
# 44          3054 0 days 00:25:04.511384639
# 45          3055 0 days 00:55:32.461799660
# 46          3056 0 days 01:39:51.443749262
# 47          3057 0 days 00:15:21.087227569
# 48          3058 0 days 00:59:44.338864118
# 49          3059 0 days 01:04:36.822225690
# 50          3060 0 days 02:21:24.159492523
# 51          3061 0 days 00:49:20.855575868
# 52          3062 0 days 01:56:32.115528882
# 53          3063 0 days 00:47:43.299887193
# 54          3064 0 days 01:04:18.017991004
# 55          3065 0 days 04:06:30.371869466
# 56          3066 0 days 00:37:25.224383667
# 57          3067 0 days 06:31:48.387096774
# 58          3068 0 days 01:16:58.835316217
# 59          3069 0 days 01:22:49.462610179
# 60          3070 0 days 03:09:37.192068896
# 61          3071 0 days 02:14:42.355535950
# 62          3072 0 days 02:01:48.793963077
# 63          3073 0 days 01:35:48.831951770
# 64          3074 0 days 01:30:47.342964824
# 65          3075 0 days 01:14:25.592367736
# 66          3077 0 days 02:53:13.796262367
# 67          3078 0 days 00:49:03.992697053
# 68          3086 0 days 01:57:43.309118236
# 69          3088 0 days 01:22:22.515660733
# 70          3093 0 days 12:12:53.403141361
# 71          3096 0 days 19:05:28.958333333
# 72          3097 0 days 02:22:41.426036457
# 73          3098 0 days 01:19:49.125496876
# 74          3099 0 days 02:09:05.192953020
# 75          3100 0 days 00:46:23.845668894
# 76          3101 0 days 00:29:18.482521981
# 77          3102 0 days 00:30:05.998851894
# 78          3104 0 days 04:33:46.884507042
# 79          3106 0 days 06:53:48.494953927
# 80          3107 0 days 05:31:02.781044621
# 81          3108 0 days 00:29:45.188566297
# 82          3110 0 days 02:19:56.192435511
# 83          3111 0 days 05:38:24.176146788
# 84          3112 0 days 03:38:32.288430326
# 85          3113 0 days 09:53:29.068776628
# 86          3114 0 days 00:57:53.320054065
# 87          3115 0 days 04:49:23.055311676
# 88          3116 0 days 01:14:08.980875032
# 89          3117 0 days 09:38:56.942446043
# 90          3118 0 days 03:09:56.050386021
# 91          3119 0 days 06:46:14.063662670
# 92          3120 0 days 01:54:44.837978397
# 93          3121 0 days 01:23:20.461148259
# 94          3123 0 days 05:54:21.473684210
# 95          3124 0 days 01:32:30.573291366
# 96          3125 0 days 00:55:45.065152021
# 97          3150 0 days 02:07:24.176155851
# 98          3152 0 days 03:49:55.271856287
# 99          3153 0 days 03:45:10.664403491
# 100         3154 0 days 00:38:36.097061533
# 101         3155 0 days 01:12:03.306849544
# 102         3156 0 days 01:10:19.983392842
# 103         3157 0 days 01:28:14.498233949
# 104         3158 0 days 01:18:34.854461891
# 105         3159 0 days 01:23:06.909745241
# 106         3160 0 days 01:06:59.321785801
# 107         3161 0 days 01:02:52.292393320
# 108         3162 0 days 01:37:22.355722729
# 109         3163 0 days 00:42:21.489784849
# 110         3164 0 days 01:22:06.279798651
# 111         3165 0 days 01:45:20.812365204
# 112         3166 0 days 02:04:08.256728778
# 113         3167 0 days 00:20:51.217196665
# 114         3168 0 days 00:24:21.605861700
# 115         3169 0 days 01:12:29.784695201
# 116         3170 0 days 01:44:00.965767399
# 117         3181 0 days 11:26:19.406896551
# 118         3182 0 days 00:56:54.277813231
# 119         3183 0 days 10:47:36.201550387
# 120         3184 0 days 04:26:40.934730056
# 121         3185 0 days 00:30:44.103424178
# 122         3186 0 days 05:37:23.098995695
# 123         3187 0 days 02:03:50.342245989
# 124         3188 0 days 03:25:29.883481836
# 125         3190 0 days 00:18:34.847365746
# 126         3192 0 days 01:59:17.548990933
# 127         3196 0 days 14:12:55.171232876
# 128         3197    0 days 02:03:03.441459
# 129         3200 0 days 05:02:58.402203856
# 130         3201 0 days 01:07:08.531976744
# 131         3202 0 days 00:13:33.006948156
# 132         3203 0 days 00:54:39.522590554
# 133         3204 0 days 01:49:05.734724991
# 134         3205 0 days 01:27:30.014835327
# 135         3206 0 days 00:41:01.736382227
# 136         3207 0 days 00:44:14.889604415
# 137         3208 0 days 00:23:49.416114945
# 138         3209 0 days 02:16:52.223255813
# 139         3210 0 days 02:03:18.111177525
# 140         3211 0 days 03:20:45.224812656
# 141         3212 0 days 00:02:56.910004786
# 142         3213 0 days 01:46:48.447037701
# 143         3214 0 days 04:06:04.638255698
# 144         3226 0 days 09:09:37.763157894
# 145         3233 0 days 02:39:28.393632416
# 146         3234 0 days 01:44:39.281160992
# 147         3235 0 days 01:47:47.452734882
# 148         3236 0 days 01:51:02.603440260
# 149         3237 0 days 03:51:57.749769443
# 150         3238 0 days 00:41:19.137685580
# 151         3240 0 days 22:26:50.172413793
# 152         3241 0 days 04:16:07.166077738
# 153         3243 0 days 13:39:32.524590163
# 154         3244 0 days 00:40:27.576906868
# 155         3245 0 days 01:34:09.720138488
# 156         3246 0 days 03:49:47.335570469
# 157         3247 0 days 11:33:50.150943396
# 158         3248 0 days 01:56:16.445217391
# 159         3249 0 days 01:40:44.921215979
# 160         3250 0 days 03:49:50.049001130
# 161         3251 0 days 06:48:11.884406983
# 162         3252 0 days 02:47:59.154488517
# 163         3253 0 days 05:11:49.220338983
# 164         3254 0 days 04:09:19.192323070
# 165         3255 0 days 00:50:11.353322528
# 166         3256 0 days 00:51:50.883078441
# 167         3257 0 days 03:23:33.798008534
# 168         3258 0 days 06:21:20.208877284
# 169         3259 0 days 03:26:58.484398216
# 170         3261 0 days 01:32:59.333982473
# 171         3263 0 days 05:50:50.997526793
# 172         3264 0 days 01:08:11.381132075
# 173         3265 0 days 02:47:12.528089887
# 174         3266 0 days 02:44:00.806517311
# 175         3267 0 days 04:32:46.818774445
# 176         3271 0 days 10:12:16.582466567
# 177         3272 0 days 09:54:30.355029585
# 178         3273 0 days 01:19:02.482607103
# 179         3275 0 days 03:09:29.329305135
# 180         3276 0 days 04:05:42.533807829
# 181         3277 0 days 13:55:17.003257328
# 182         3278 0 days 13:19:27.572815533
# 183         3279 0 days 04:07:49.367875647
# 184         3280 0 days 15:06:46.384615384
# 185         3281 0 days 12:40:17.913669064
# 186         3282 1 days 05:03:18.688524590
# 187         3284 1 days 13:19:09.230769230
# 188         3285    0 days 08:57:17.250000
# 189         3286 0 days 02:44:53.947368421
# 190         3287 0 days 08:02:34.594594594
# 191         3291 0 days 12:19:56.504854368
# 192         3294 0 days 01:19:25.637755102
# 193         3295 0 days 00:35:12.917647058
# 194         3296 0 days 00:26:48.471216164
# 195         3298 1 days 01:06:01.463414634
# 196         3299 0 days 03:32:17.260273972
# 197         3300           0 days 09:28:11

# %%
idle_time_df = Phil.groupby(["end_station","trip_id", "end_time", "start_time"]).size()

print(idle_time_df)

idle_times = []

# Sortieren Sie den DataFrame nach end_time, um sicherzustellen, dass die Zeiten in aufsteigender Reihenfolge sind
idle_time_df = idle_time_df.sort_values("end_time")

# Iterieren Sie über die Gruppen im DataFrame
for (end_station, trip_id, end_time, start_time), count in idle_time_df.iteritems():
    # Suchen Sie die nächste start_time für die aktuelle end_time
    next_start_time = idle_time_df.loc[(end_station, trip_id), "start_time"].min()
    
    # Berechnen Sie die Zeitdifferenz zwischen end_time und next_start_time
    idle_time = next_start_time - end_time
    
    # Fügen Sie die Zeitdifferenz zur Liste idle_times hinzu
    idle_times.append(idle_time)

# Geben Sie die Liste idle_times aus
print(idle_times)
# Out:
# end_station  trip_id    end_time             start_time
# 3004         365254837  2021-01-02 12:04:00  2021-01-02 11:51:00    1
#              365259496  2021-01-02 15:03:00  2021-01-02 14:14:00    1
#              365260934  2021-01-02 15:45:00  2021-01-02 13:39:00    1
#              365260936  2021-01-02 15:45:00  2021-01-02 13:39:00    1
#              365261393  2021-01-02 16:11:00  2021-01-02 15:30:00    1
#                                                                    ..
# 3300         579268887  2022-12-30 20:23:00  2022-12-30 20:04:00    1
#              579268889  2022-12-30 20:23:00  2022-12-30 20:03:00    1
#              579268891  2022-12-30 20:23:00  2022-12-30 20:02:00    1
#              579268892  2022-12-30 20:05:00  2022-12-30 20:01:00    1
#              579482379  2022-12-31 19:52:00  2022-12-31 19:21:00    1
# Length: 1679150, dtype: int64
# C:\Users\Jen\AppData\Local\Temp\ipykernel_11472\3144999558.py:8: FutureWarning:
#
# In a future version of pandas all arguments of Series.sort_values will be keyword-only.
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\lib\site-packages\pandas\core\generic.py:554, in NDFrame._get_axis_number(cls, axis)
#     553 try:
# --> 554     return cls._AXIS_TO_AXIS_NUMBER[axis]
#     555 except KeyError:
#
# KeyError: 'end_time'
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# Cell In[186], line 8
#       5 idle_times = []
#       7 # Sortieren Sie den DataFrame nach end_time, um sicherzustellen, dass die Zeiten in aufsteigender Reihenfolge sind
# ----> 8 idle_time_df = idle_time_df.sort_values("end_time")
#      10 # Iterieren Sie über die Gruppen im DataFrame
#      11 for (end_station, trip_id, end_time, start_time), count in idle_time_df.iteritems():
#      12     # Suchen Sie die nächste start_time für die aktuelle end_time
#
# File ~\anaconda3\lib\site-packages\pandas\util\_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# File ~\anaconda3\lib\site-packages\pandas\core\series.py:3744, in Series.sort_values(self, axis, ascending, inplace, kind, na_position, ignore_index, key)
#    3742 inplace = validate_bool_kwarg(inplace, "inplace")
#    3743 # Validate the axis parameter
# -> 3744 self._get_axis_number(axis)
#    3746 # GH 5856/5853
#    3747 if inplace and self._is_cached:
#
# File ~\anaconda3\lib\site-packages\pandas\core\generic.py:556, in NDFrame._get_axis_number(cls, axis)
#     554     return cls._AXIS_TO_AXIS_NUMBER[axis]
#     555 except KeyError:
# --> 556     raise ValueError(f"No axis named {axis} for object type {cls.__name__}")
#
# ValueError: No axis named end_time for object type Series

# %%
# Konvertieren Sie die Series idle_time_df in ein DataFrame
idle_time_df = idle_time_df.reset_index()

# Sortieren Sie den DataFrame nach end_time, um sicherzustellen, dass die Zeiten in aufsteigender Reihenfolge sind
idle_time_df = idle_time_df.sort_values("end_time")

# Leeren DataFrame erstellen, um die Ergebnisse zu speichern
result_df = pd.DataFrame(columns=["end_station", "trip_id", "end_time", "start_time", "idle_time"])

# Iterieren Sie über die Gruppen im DataFrame
for index, row in idle_time_df.iterrows():
    current_end_station = row["end_station"]
    current_trip_id = row["trip_id"]
    current_end_time = row["end_time"]
    current_start_time = row["start_time"]

    # Suchen Sie die nächste start_time für die aktuelle end_time
    next_start_time = idle_time_df[(idle_time_df["end_station"] == current_end_station) & (idle_time_df["trip_id"] == current_trip_id) & (idle_time_df["start_time"] > current_end_time)]["start_time"].min()

    # Berechnen Sie die Zeitdifferenz zwischen end_time und next_start_time
    idle_time = next_start_time - current_end_time

    # Fügen Sie die Ergebnisse zum result_df hinzu
    result_df = result_df.append({"end_station": current_end_station, "trip_id": current_trip_id, "end_time": current_end_time, "start_time": current_start_time, "idle_time": idle_time}, ignore_index=True)

# Geben Sie das result_df aus
print(result_df)
# Out:
# C:\Users\Jen\AppData\Local\Temp\ipykernel_11472\796650309.py:24: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Jen\AppData\Local\Temp\ipykernel_11472\796650309.py:24: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Jen\AppData\Local\Temp\ipykernel_11472\796650309.py:24: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Jen\AppData\Local\Temp\ipykernel_11472\796650309.py:24: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Jen\AppData\Local\Temp\ipykernel_11472\796650309.py:24: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Jen\AppData\Local\Temp\ipykernel_11472\796650309.py:24: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Jen\AppData\Local\Temp\ipykernel_11472\796650309.py:24: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Jen\AppData\Local\Temp\ipykernel_11472\796650309.py:24: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Jen\AppData\Local\Temp\ipykernel_11472\796650309.py:24: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Jen\AppData\Local\Temp\ipykernel_11472\796650309.py:24: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Jen\AppData\Local\Temp\ipykernel_11472\796650309.py:24: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Jen\AppData\Local\Temp\ipykernel_11472\796650309.py:24: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Jen\AppData\Local\Temp\ipykernel_11472\796650309.py:24: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Jen\AppData\Local\Temp\ipykernel_11472\796650309.py:24: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Jen\AppData\Local\Temp\ipykernel_11472\796650309.py:24: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Jen\AppData\Local\Temp\ipykernel_11472\796650309.py:24: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Jen\AppData\Local\Temp\ipykernel_11472\796650309.py:24: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Jen\AppData\Local\Temp\ipykernel_11472\796650309.py:24: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Jen\AppData\Local\Temp\ipykernel_11472\796650309.py:24: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Jen\AppData\Local\Temp\ipykernel_11472\796650309.py:24: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Jen\AppData\Local\Temp\ipykernel_11472\796650309.py:24: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Jen\AppData\Local\Temp\ipykernel_11472\796650309.py:24: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Jen\AppData\Local\Temp\ipykernel_11472\796650309.py:24: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Jen\AppData\Local\Temp\ipykernel_11472\796650309.py:24: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Jen\AppData\Local\Temp\ipykernel_11472\796650309.py:24: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Jen\AppData\Local\Temp\ipykernel_11472\796650309.py:24: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Jen\AppData\Local\Temp\ipykernel_11472\796650309.py:24: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Jen\AppData\Local\Temp\ipykernel_11472\796650309.py:24: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Jen\AppData\Local\Temp\ipykernel_11472\796650309.py:24: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Jen\AppData\Local\Temp\ipykernel_11472\796650309.py:24: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Jen\AppData\Local\Temp\ipykernel_11472\796650309.py:24: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Jen\AppData\Local\Temp\ipykernel_11472\796650309.py:24: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Jen\AppData\Local\Temp\ipykernel_11472\796650309.py:24: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Jen\AppData\Local\Temp\ipykernel_11472\796650309.py:24: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Jen\AppData\Local\Temp\ipykernel_11472\796650309.py:24: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Jen\AppData\Local\Temp\ipykernel_11472\796650309.py:24: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Jen\AppData\Local\Temp\ipykernel_11472\796650309.py:24: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Jen\AppData\Local\Temp\ipykernel_11472\796650309.py:24: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Jen\AppData\Local\Temp\ipykernel_11472\796650309.py:24: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Jen\AppData\Local\Temp\ipykernel_11472\796650309.py:24: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Jen\AppData\Local\Temp\ipykernel_11472\796650309.py:24: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Jen\AppData\Local\Temp\ipykernel_11472\796650309.py:24: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Jen\AppData\Local\Temp\ipykernel_11472\796650309.py:24: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Jen\AppData\Local\Temp\ipykernel_11472\796650309.py:24: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Jen\AppData\Local\Temp\ipykernel_11472\796650309.py:24: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Jen\AppData\Local\Temp\ipykernel_11472\796650309.py:24: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Jen\AppData\Local\Temp\ipykernel_11472\796650309.py:24: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Jen\AppData\Local\Temp\ipykernel_11472\796650309.py:24: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Jen\AppData\Local\Temp\ipykernel_11472\796650309.py:24: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Jen\AppData\Local\Temp\ipykernel_11472\796650309.py:24: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Jen\AppData\Local\Temp\ipykernel_11472\796650309.py:24: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# C:\Users\Jen\AppData\Local\Temp\ipykernel_11472\796650309.py:24: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Jen\AppData\Local\Temp\ipykernel_11472\796650309.py:24: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Jen\AppData\Local\Temp\ipykernel_11472\796650309.py:24: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Jen\AppData\Local\Temp\ipykernel_11472\796650309.py:24: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Jen\AppData\Local\Temp\ipykernel_11472\796650309.py:24: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Jen\AppData\Local\Temp\ipykernel_11472\796650309.py:24: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Jen\AppData\Local\Temp\ipykernel_11472\796650309.py:24: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Jen\AppData\Local\Temp\ipykernel_11472\796650309.py:24: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Jen\AppData\Local\Temp\ipykernel_11472\796650309.py:24: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Jen\AppData\Local\Temp\ipykernel_11472\796650309.py:24: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Jen\AppData\Local\Temp\ipykernel_11472\796650309.py:24: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Jen\AppData\Local\Temp\ipykernel_11472\796650309.py:24: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Jen\AppData\Local\Temp\ipykernel_11472\796650309.py:24: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Jen\AppData\Local\Temp\ipykernel_11472\796650309.py:24: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Jen\AppData\Local\Temp\ipykernel_11472\796650309.py:24: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Jen\AppData\Local\Temp\ipykernel_11472\796650309.py:24: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Jen\AppData\Local\Temp\ipykernel_11472\796650309.py:24: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Jen\AppData\Local\Temp\ipykernel_11472\796650309.py:24: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Jen\AppData\Local\Temp\ipykernel_11472\796650309.py:24: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Jen\AppData\Local\Temp\ipykernel_11472\796650309.py:24: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Jen\AppData\Local\Temp\ipykernel_11472\796650309.py:24: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Jen\AppData\Local\Temp\ipykernel_11472\796650309.py:24: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Jen\AppData\Local\Temp\ipykernel_11472\796650309.py:24: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Jen\AppData\Local\Temp\ipykernel_11472\796650309.py:24: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Jen\AppData\Local\Temp\ipykernel_11472\796650309.py:24: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Jen\AppData\Local\Temp\ipykernel_11472\796650309.py:24: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Jen\AppData\Local\Temp\ipykernel_11472\796650309.py:24: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Jen\AppData\Local\Temp\ipykernel_11472\796650309.py:24: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Jen\AppData\Local\Temp\ipykernel_11472\796650309.py:24: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Jen\AppData\Local\Temp\ipykernel_11472\796650309.py:24: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Jen\AppData\Local\Temp\ipykernel_11472\796650309.py:24: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Jen\AppData\Local\Temp\ipykernel_11472\796650309.py:24: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Jen\AppData\Local\Temp\ipykernel_11472\796650309.py:24: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Jen\AppData\Local\Temp\ipykernel_11472\796650309.py:24: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Jen\AppData\Local\Temp\ipykernel_11472\796650309.py:24: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Jen\AppData\Local\Temp\ipykernel_11472\796650309.py:24: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Jen\AppData\Local\Temp\ipykernel_11472\796650309.py:24: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Jen\AppData\Local\Temp\ipykernel_11472\796650309.py:24: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Jen\AppData\Local\Temp\ipykernel_11472\796650309.py:24: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Jen\AppData\Local\Temp\ipykernel_11472\796650309.py:24: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Jen\AppData\Local\Temp\ipykernel_11472\796650309.py:24: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Jen\AppData\Local\Temp\ipykernel_11472\796650309.py:24: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Jen\AppData\Local\Temp\ipykernel_11472\796650309.py:24: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Jen\AppData\Local\Temp\ipykernel_11472\796650309.py:24: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Jen\AppData\Local\Temp\ipykernel_11472\796650309.py:24: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Jen\AppData\Local\Temp\ipykernel_11472\796650309.py:24: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Jen\AppData\Local\Temp\ipykernel_11472\796650309.py:24: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Jen\AppData\Local\Temp\ipykernel_11472\796650309.py:24: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Jen\AppData\Local\Temp\ipykernel_11472\796650309.py:24: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Jen\AppData\Local\Temp\ipykernel_11472\796650309.py:24: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Jen\AppData\Local\Temp\ipykernel_11472\796650309.py:24: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Jen\AppData\Local\Temp\ipykernel_11472\796650309.py:24: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Jen\AppData\Local\Temp\ipykernel_11472\796650309.py:24: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Jen\AppData\Local\Temp\ipykernel_11472\796650309.py:24: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# C:\Users\Jen\AppData\Local\Temp\ipykernel_11472\796650309.py:24: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Jen\AppData\Local\Temp\ipykernel_11472\796650309.py:24: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Jen\AppData\Local\Temp\ipykernel_11472\796650309.py:24: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Jen\AppData\Local\Temp\ipykernel_11472\796650309.py:24: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Jen\AppData\Local\Temp\ipykernel_11472\796650309.py:24: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Jen\AppData\Local\Temp\ipykernel_11472\796650309.py:24: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Jen\AppData\Local\Temp\ipykernel_11472\796650309.py:24: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Jen\AppData\Local\Temp\ipykernel_11472\796650309.py:24: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Jen\AppData\Local\Temp\ipykernel_11472\796650309.py:24: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Jen\AppData\Local\Temp\ipykernel_11472\796650309.py:24: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Jen\AppData\Local\Temp\ipykernel_11472\796650309.py:24: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Jen\AppData\Local\Temp\ipykernel_11472\796650309.py:24: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Jen\AppData\Local\Temp\ipykernel_11472\796650309.py:24: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Jen\AppData\Local\Temp\ipykernel_11472\796650309.py:24: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Jen\AppData\Local\Temp\ipykernel_11472\796650309.py:24: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Jen\AppData\Local\Temp\ipykernel_11472\796650309.py:24: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Jen\AppData\Local\Temp\ipykernel_11472\796650309.py:24: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Jen\AppData\Local\Temp\ipykernel_11472\796650309.py:24: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Jen\AppData\Local\Temp\ipykernel_11472\796650309.py:24: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Jen\AppData\Local\Temp\ipykernel_11472\796650309.py:24: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Jen\AppData\Local\Temp\ipykernel_11472\796650309.py:24: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Jen\AppData\Local\Temp\ipykernel_11472\796650309.py:24: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Jen\AppData\Local\Temp\ipykernel_11472\796650309.py:24: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Jen\AppData\Local\Temp\ipykernel_11472\796650309.py:24: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Jen\AppData\Local\Temp\ipykernel_11472\796650309.py:24: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Jen\AppData\Local\Temp\ipykernel_11472\796650309.py:24: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Jen\AppData\Local\Temp\ipykernel_11472\796650309.py:24: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Jen\AppData\Local\Temp\ipykernel_11472\796650309.py:24: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Jen\AppData\Local\Temp\ipykernel_11472\796650309.py:24: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Jen\AppData\Local\Temp\ipykernel_11472\796650309.py:24: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Jen\AppData\Local\Temp\ipykernel_11472\796650309.py:24: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Jen\AppData\Local\Temp\ipykernel_11472\796650309.py:24: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Jen\AppData\Local\Temp\ipykernel_11472\796650309.py:24: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Jen\AppData\Local\Temp\ipykernel_11472\796650309.py:24: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Jen\AppData\Local\Temp\ipykernel_11472\796650309.py:24: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Jen\AppData\Local\Temp\ipykernel_11472\796650309.py:24: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Jen\AppData\Local\Temp\ipykernel_11472\796650309.py:24: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Jen\AppData\Local\Temp\ipykernel_11472\796650309.py:24: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Jen\AppData\Local\Temp\ipykernel_11472\796650309.py:24: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Jen\AppData\Local\Temp\ipykernel_11472\796650309.py:24: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Jen\AppData\Local\Temp\ipykernel_11472\796650309.py:24: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Jen\AppData\Local\Temp\ipykernel_11472\796650309.py:24: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Jen\AppData\Local\Temp\ipykernel_11472\796650309.py:24: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Jen\AppData\Local\Temp\ipykernel_11472\796650309.py:24: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Jen\AppData\Local\Temp\ipykernel_11472\796650309.py:24: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Jen\AppData\Local\Temp\ipykernel_11472\796650309.py:24: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Jen\AppData\Local\Temp\ipykernel_11472\796650309.py:24: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Jen\AppData\Local\Temp\ipykernel_11472\796650309.py:24: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Jen\AppData\Local\Temp\ipykernel_11472\796650309.py:24: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Jen\AppData\Local\Temp\ipykernel_11472\796650309.py:24: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Jen\AppData\Local\Temp\ipykernel_11472\796650309.py:24: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Jen\AppData\Local\Temp\ipykernel_11472\796650309.py:24: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Jen\AppData\Local\Temp\ipykernel_11472\796650309.py:24: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Jen\AppData\Local\Temp\ipykernel_11472\796650309.py:24: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# C:\Users\Jen\AppData\Local\Temp\ipykernel_11472\796650309.py:24: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Jen\AppData\Local\Temp\ipykernel_11472\796650309.py:24: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Jen\AppData\Local\Temp\ipykernel_11472\796650309.py:24: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Jen\AppData\Local\Temp\ipykernel_11472\796650309.py:24: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Jen\AppData\Local\Temp\ipykernel_11472\796650309.py:24: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Jen\AppData\Local\Temp\ipykernel_11472\796650309.py:24: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Jen\AppData\Local\Temp\ipykernel_11472\796650309.py:24: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Jen\AppData\Local\Temp\ipykernel_11472\796650309.py:24: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Jen\AppData\Local\Temp\ipykernel_11472\796650309.py:24: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Jen\AppData\Local\Temp\ipykernel_11472\796650309.py:24: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Jen\AppData\Local\Temp\ipykernel_11472\796650309.py:24: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Jen\AppData\Local\Temp\ipykernel_11472\796650309.py:24: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Jen\AppData\Local\Temp\ipykernel_11472\796650309.py:24: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Jen\AppData\Local\Temp\ipykernel_11472\796650309.py:24: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Jen\AppData\Local\Temp\ipykernel_11472\796650309.py:24: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Jen\AppData\Local\Temp\ipykernel_11472\796650309.py:24: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Jen\AppData\Local\Temp\ipykernel_11472\796650309.py:24: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Jen\AppData\Local\Temp\ipykernel_11472\796650309.py:24: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Jen\AppData\Local\Temp\ipykernel_11472\796650309.py:24: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Jen\AppData\Local\Temp\ipykernel_11472\796650309.py:24: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Jen\AppData\Local\Temp\ipykernel_11472\796650309.py:24: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Jen\AppData\Local\Temp\ipykernel_11472\796650309.py:24: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Jen\AppData\Local\Temp\ipykernel_11472\796650309.py:24: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Jen\AppData\Local\Temp\ipykernel_11472\796650309.py:24: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Jen\AppData\Local\Temp\ipykernel_11472\796650309.py:24: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Jen\AppData\Local\Temp\ipykernel_11472\796650309.py:24: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Jen\AppData\Local\Temp\ipykernel_11472\796650309.py:24: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Jen\AppData\Local\Temp\ipykernel_11472\796650309.py:24: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Jen\AppData\Local\Temp\ipykernel_11472\796650309.py:24: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Jen\AppData\Local\Temp\ipykernel_11472\796650309.py:24: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Jen\AppData\Local\Temp\ipykernel_11472\796650309.py:24: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Jen\AppData\Local\Temp\ipykernel_11472\796650309.py:24: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Jen\AppData\Local\Temp\ipykernel_11472\796650309.py:24: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Jen\AppData\Local\Temp\ipykernel_11472\796650309.py:24: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Jen\AppData\Local\Temp\ipykernel_11472\796650309.py:24: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Jen\AppData\Local\Temp\ipykernel_11472\796650309.py:24: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Jen\AppData\Local\Temp\ipykernel_11472\796650309.py:24: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Jen\AppData\Local\Temp\ipykernel_11472\796650309.py:24: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Jen\AppData\Local\Temp\ipykernel_11472\796650309.py:24: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Jen\AppData\Local\Temp\ipykernel_11472\796650309.py:24: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Jen\AppData\Local\Temp\ipykernel_11472\796650309.py:24: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Jen\AppData\Local\Temp\ipykernel_11472\796650309.py:24: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Jen\AppData\Local\Temp\ipykernel_11472\796650309.py:24: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Jen\AppData\Local\Temp\ipykernel_11472\796650309.py:24: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Jen\AppData\Local\Temp\ipykernel_11472\796650309.py:24: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Jen\AppData\Local\Temp\ipykernel_11472\796650309.py:24: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Jen\AppData\Local\Temp\ipykernel_11472\796650309.py:24: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Jen\AppData\Local\Temp\ipykernel_11472\796650309.py:24: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Jen\AppData\Local\Temp\ipykernel_11472\796650309.py:24: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Jen\AppData\Local\Temp\ipykernel_11472\796650309.py:24: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Jen\AppData\Local\Temp\ipykernel_11472\796650309.py:24: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Jen\AppData\Local\Temp\ipykernel_11472\796650309.py:24: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# C:\Users\Jen\AppData\Local\Temp\ipykernel_11472\796650309.py:24: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Jen\AppData\Local\Temp\ipykernel_11472\796650309.py:24: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Jen\AppData\Local\Temp\ipykernel_11472\796650309.py:24: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Jen\AppData\Local\Temp\ipykernel_11472\796650309.py:24: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Jen\AppData\Local\Temp\ipykernel_11472\796650309.py:24: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Jen\AppData\Local\Temp\ipykernel_11472\796650309.py:24: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Jen\AppData\Local\Temp\ipykernel_11472\796650309.py:24: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Jen\AppData\Local\Temp\ipykernel_11472\796650309.py:24: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Jen\AppData\Local\Temp\ipykernel_11472\796650309.py:24: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Jen\AppData\Local\Temp\ipykernel_11472\796650309.py:24: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Jen\AppData\Local\Temp\ipykernel_11472\796650309.py:24: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Jen\AppData\Local\Temp\ipykernel_11472\796650309.py:24: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Jen\AppData\Local\Temp\ipykernel_11472\796650309.py:24: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Jen\AppData\Local\Temp\ipykernel_11472\796650309.py:24: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Jen\AppData\Local\Temp\ipykernel_11472\796650309.py:24: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Jen\AppData\Local\Temp\ipykernel_11472\796650309.py:24: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Jen\AppData\Local\Temp\ipykernel_11472\796650309.py:24: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Jen\AppData\Local\Temp\ipykernel_11472\796650309.py:24: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Jen\AppData\Local\Temp\ipykernel_11472\796650309.py:24: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Jen\AppData\Local\Temp\ipykernel_11472\796650309.py:24: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Jen\AppData\Local\Temp\ipykernel_11472\796650309.py:24: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Jen\AppData\Local\Temp\ipykernel_11472\796650309.py:24: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Jen\AppData\Local\Temp\ipykernel_11472\796650309.py:24: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Jen\AppData\Local\Temp\ipykernel_11472\796650309.py:24: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Jen\AppData\Local\Temp\ipykernel_11472\796650309.py:24: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Jen\AppData\Local\Temp\ipykernel_11472\796650309.py:24: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Jen\AppData\Local\Temp\ipykernel_11472\796650309.py:24: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Jen\AppData\Local\Temp\ipykernel_11472\796650309.py:24: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Jen\AppData\Local\Temp\ipykernel_11472\796650309.py:24: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# ...
#
# C:\Users\Jen\AppData\Local\Temp\ipykernel_11472\796650309.py:24: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Jen\AppData\Local\Temp\ipykernel_11472\796650309.py:24: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Jen\AppData\Local\Temp\ipykernel_11472\796650309.py:24: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Jen\AppData\Local\Temp\ipykernel_11472\796650309.py:24: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Jen\AppData\Local\Temp\ipykernel_11472\796650309.py:24: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Jen\AppData\Local\Temp\ipykernel_11472\796650309.py:24: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Jen\AppData\Local\Temp\ipykernel_11472\796650309.py:24: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Jen\AppData\Local\Temp\ipykernel_11472\796650309.py:24: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Jen\AppData\Local\Temp\ipykernel_11472\796650309.py:24: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Jen\AppData\Local\Temp\ipykernel_11472\796650309.py:24: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Jen\AppData\Local\Temp\ipykernel_11472\796650309.py:24: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Jen\AppData\Local\Temp\ipykernel_11472\796650309.py:24: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Jen\AppData\Local\Temp\ipykernel_11472\796650309.py:24: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Jen\AppData\Local\Temp\ipykernel_11472\796650309.py:24: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Jen\AppData\Local\Temp\ipykernel_11472\796650309.py:24: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Jen\AppData\Local\Temp\ipykernel_11472\796650309.py:24: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Jen\AppData\Local\Temp\ipykernel_11472\796650309.py:24: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Jen\AppData\Local\Temp\ipykernel_11472\796650309.py:24: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Jen\AppData\Local\Temp\ipykernel_11472\796650309.py:24: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Jen\AppData\Local\Temp\ipykernel_11472\796650309.py:24: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Jen\AppData\Local\Temp\ipykernel_11472\796650309.py:24: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Jen\AppData\Local\Temp\ipykernel_11472\796650309.py:24: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Jen\AppData\Local\Temp\ipykernel_11472\796650309.py:24: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Jen\AppData\Local\Temp\ipykernel_11472\796650309.py:24: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Jen\AppData\Local\Temp\ipykernel_11472\796650309.py:24: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Jen\AppData\Local\Temp\ipykernel_11472\796650309.py:24: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Jen\AppData\Local\Temp\ipykernel_11472\796650309.py:24: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Jen\AppData\Local\Temp\ipykernel_11472\796650309.py:24: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Jen\AppData\Local\Temp\ipykernel_11472\796650309.py:24: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Jen\AppData\Local\Temp\ipykernel_11472\796650309.py:24: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Jen\AppData\Local\Temp\ipykernel_11472\796650309.py:24: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Jen\AppData\Local\Temp\ipykernel_11472\796650309.py:24: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Jen\AppData\Local\Temp\ipykernel_11472\796650309.py:24: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Jen\AppData\Local\Temp\ipykernel_11472\796650309.py:24: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Jen\AppData\Local\Temp\ipykernel_11472\796650309.py:24: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Jen\AppData\Local\Temp\ipykernel_11472\796650309.py:24: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Jen\AppData\Local\Temp\ipykernel_11472\796650309.py:24: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Jen\AppData\Local\Temp\ipykernel_11472\796650309.py:24: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Jen\AppData\Local\Temp\ipykernel_11472\796650309.py:24: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Jen\AppData\Local\Temp\ipykernel_11472\796650309.py:24: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Jen\AppData\Local\Temp\ipykernel_11472\796650309.py:24: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Jen\AppData\Local\Temp\ipykernel_11472\796650309.py:24: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Jen\AppData\Local\Temp\ipykernel_11472\796650309.py:24: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Jen\AppData\Local\Temp\ipykernel_11472\796650309.py:24: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Jen\AppData\Local\Temp\ipykernel_11472\796650309.py:24: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Jen\AppData\Local\Temp\ipykernel_11472\796650309.py:24: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Jen\AppData\Local\Temp\ipykernel_11472\796650309.py:24: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Jen\AppData\Local\Temp\ipykernel_11472\796650309.py:24: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Jen\AppData\Local\Temp\ipykernel_11472\796650309.py:24: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# C:\Users\Jen\AppData\Local\Temp\ipykernel_11472\796650309.py:24: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Jen\AppData\Local\Temp\ipykernel_11472\796650309.py:24: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Jen\AppData\Local\Temp\ipykernel_11472\796650309.py:24: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Jen\AppData\Local\Temp\ipykernel_11472\796650309.py:24: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Jen\AppData\Local\Temp\ipykernel_11472\796650309.py:24: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Jen\AppData\Local\Temp\ipykernel_11472\796650309.py:24: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Jen\AppData\Local\Temp\ipykernel_11472\796650309.py:24: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Jen\AppData\Local\Temp\ipykernel_11472\796650309.py:24: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Jen\AppData\Local\Temp\ipykernel_11472\796650309.py:24: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Jen\AppData\Local\Temp\ipykernel_11472\796650309.py:24: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Jen\AppData\Local\Temp\ipykernel_11472\796650309.py:24: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Jen\AppData\Local\Temp\ipykernel_11472\796650309.py:24: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Jen\AppData\Local\Temp\ipykernel_11472\796650309.py:24: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Jen\AppData\Local\Temp\ipykernel_11472\796650309.py:24: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Jen\AppData\Local\Temp\ipykernel_11472\796650309.py:24: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Jen\AppData\Local\Temp\ipykernel_11472\796650309.py:24: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Jen\AppData\Local\Temp\ipykernel_11472\796650309.py:24: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Jen\AppData\Local\Temp\ipykernel_11472\796650309.py:24: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Jen\AppData\Local\Temp\ipykernel_11472\796650309.py:24: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Jen\AppData\Local\Temp\ipykernel_11472\796650309.py:24: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[187], line 18
#      15 current_start_time = row["start_time"]
#      17 # Suchen Sie die nächste start_time für die aktuelle end_time
# ---> 18 next_start_time = idle_time_df[(idle_time_df["end_station"] == current_end_station) & (idle_time_df["trip_id"] == current_trip_id) & (idle_time_df["start_time"] > current_end_time)]["start_time"].min()
#      20 # Berechnen Sie die Zeitdifferenz zwischen end_time und next_start_time
#      21 idle_time = next_start_time - current_end_time
#
# File ~\anaconda3\lib\site-packages\pandas\core\ops\common.py:72, in _unpack_zerodim_and_defer.<locals>.new_method(self, other)
#      68             return NotImplemented
#      70 other = item_from_zerodim(other)
# ---> 72 return method(self, other)
#
# File ~\anaconda3\lib\site-packages\pandas\core\arraylike.py:72, in OpsMixin.__and__(self, other)
#      70 @unpack_zerodim_and_defer("__and__")
#      71 def __and__(self, other):
# ---> 72     return self._logical_method(other, operator.and_)
#
# File ~\anaconda3\lib\site-packages\pandas\core\series.py:6254, in Series._logical_method(self, other, op)
#    6251 lvalues = self._values
#    6252 rvalues = extract_array(other, extract_numpy=True, extract_range=True)
# -> 6254 res_values = ops.logical_op(lvalues, rvalues, op)
#    6255 return self._construct_result(res_values, name=res_name)
#
# File ~\anaconda3\lib\site-packages\pandas\core\ops\array_ops.py:385, in logical_op(left, right, op)
#     383 if isinstance(rvalues, np.ndarray):
#     384     is_other_int_dtype = is_integer_dtype(rvalues.dtype)
# --> 385     rvalues = rvalues if is_other_int_dtype else fill_bool(rvalues, lvalues)
#     387 else:
#     388     # i.e. scalar
#     389     is_other_int_dtype = lib.is_integer(rvalues)
#
# File ~\anaconda3\lib\site-packages\pandas\core\ops\array_ops.py:364, in logical_op.<locals>.fill_bool(x, left)
#     361         x[mask] = False
#     363 if left is None or is_bool_dtype(left.dtype):
# --> 364     x = x.astype(bool)
#     365 return x
#
# KeyboardInterrupt:

# %%
# Konvertieren Sie die Series idle_time_df in ein DataFrame
idle_time_df = idle_time_df.reset_index()

# Sortieren Sie den DataFrame nach end_time, um sicherzustellen, dass die Zeiten in aufsteigender Reihenfolge sind
idle_time_df = idle_time_df.sort_values("end_time")

# DataFrame erstellen, um die Ergebnisse zu speichern
result_df = pd.DataFrame(columns=["end_station", "trip_id", "end_time", "start_time", "idle_time"])

# Iterieren Sie über die Gruppen im DataFrame
for index, row in idle_time_df.iterrows():
    current_end_station = row["end_station"]
    current_trip_id = row["trip_id"]
    current_end_time = row["end_time"]
    current_start_time = row["start_time"]

    # Suchen Sie die nächste start_time für die aktuelle end_time
    next_start_time = idle_time_df[(idle_time_df["end_station"] == current_end_station) & (idle_time_df["trip_id"] == current_trip_id) & (idle_time_df["start_time"] > current_end_time)]["start_time"].min()

    # Berechnen Sie die Zeitdifferenz zwischen end_time und next_start_time
    idle_time = next_start_time - current_end_time

    # Fügen Sie die Ergebnisse zu result_df hinzu
    result_df = pd.concat([result_df, pd.DataFrame([[current_end_station, current_trip_id, current_end_time, current_start_time, idle_time]], columns=result_df.columns)], ignore_index=True)

# Geben Sie das result_df aus
print(result_df)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[188], line 24
#      21     idle_time = next_start_time - current_end_time
#      23     # Fügen Sie die Ergebnisse zu result_df hinzu
# ---> 24     result_df = pd.concat([result_df, pd.DataFrame([[current_end_station, current_trip_id, current_end_time, current_start_time, idle_time]], columns=result_df.columns)], ignore_index=True)
#      26 # Geben Sie das result_df aus
#      27 print(result_df)
#
# File ~\anaconda3\lib\site-packages\pandas\util\_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# File ~\anaconda3\lib\site-packages\pandas\core\reshape\concat.py:381, in concat(objs, axis, join, ignore_index, keys, levels, names, verify_integrity, sort, copy)
#     159 """
#     160 Concatenate pandas objects along a particular axis.
#     161
#    (...)
#     366 1   3   4
#     367 """
#     368 op = _Concatenator(
#     369     objs,
#     370     axis=axis,
#    (...)
#     378     sort=sort,
#     379 )
# --> 381 return op.get_result()
#
# File ~\anaconda3\lib\site-packages\pandas\core\reshape\concat.py:616, in _Concatenator.get_result(self)
#     612             indexers[ax] = obj_labels.get_indexer(new_labels)
#     614     mgrs_indexers.append((obj._mgr, indexers))
# --> 616 new_data = concatenate_managers(
#     617     mgrs_indexers, self.new_axes, concat_axis=self.bm_axis, copy=self.copy
#     618 )
#     619 if not self.copy:
#     620     new_data._consolidate_inplace()
#
# File ~\anaconda3\lib\site-packages\pandas\core\internals\concat.py:223, in concatenate_managers(mgrs_indexers, axes, concat_axis, copy)
#     217 vals = [ju.block.values for ju in join_units]
#     219 if not blk.is_extension:
#     220     # _is_uniform_join_units ensures a single dtype, so
#     221     #  we can use np.concatenate, which is more performant
#     222     #  than concat_compat
# --> 223     values = np.concatenate(vals, axis=1)
#     224 else:
#     225     # TODO(EA2D): special-casing not needed with 2D EAs
#     226     values = concat_compat(vals, axis=1)
#
# KeyboardInterrupt:
