# %%
import numpy as np
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns
from datetime import datetime #for working with times objects
from datetime import timedelta #for working with times objects
import math
from math import radians, sin, cos, sqrt, atan2
import random
import glob

# %%
Phil = pd.read_csv('cleaned_Phil.csv', low_memory=False)
POI = pd.read_csv('POI_PA_Cleaned.csv', low_memory=False)

# %%
POI.head()
POI.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4222 entries, 0 to 4221
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   id        4222 non-null   int64
#  1   lat       4222 non-null   float64
#  2   lon       4222 non-null   float64
#  3   operator  412 non-null    object
#  4   amenity   3882 non-null   object
#  5   atm       53 non-null     object
#  6   tourism   310 non-null    object
# dtypes: float64(2), int64(1), object(4)
# memory usage: 231.0+ KB

# %%
# unique start station coordinations; start stations = end stations
unique_coordinates = Phil[["start_coordinates", "start_station"]].drop_duplicates().values.tolist()

# %%
#Haversine formula for distance between two points on a sphere 

def haversine_formula(lat1, lon1, lat2, lon2):
    R = 6371.0 # earth radius
    
    lat1 = radians(lat1)  #degree into radians
    lon1 = radians(lon1)
    lat2 = radians(lat2)
    lon2 = radians(lon2)
    
    phi_lat = lat2 - lat1
    phi_lon = lon2 - lon1
    
    a = sin(phi_lat/2)**2 + cos(lat1) * cos(lat2) * sin(phi_lon/2)**2
    c = 2 * atan2(sqrt(a), sqrt(1-a))
    
    radius = R * c
    
    return radius

# %%
#counter for POI for each station

def count_POI(station, POI_data):
    
    lat1, lon1 = [float(x) for x in station[0].split(",")]
    poi_count = 0
    
    for index, row in POI_data.iterrows():
        lat2, lon2 = row['lat'], row['lon']
        distance = haversine_formula(lat1, lon1, lat2, lon2)
        if distance <= 0.2:  # radius of 200 meter 
            poi_count += 1
    return poi_count

# %%
POI_counts = []

for station in unique_coordinates:
    count = count_POI(station, POI)
    POI_counts.append({'Station': station[1], 'POI_Count': count})

# %%
sorted_POI_counts = sorted(POI_counts, key=lambda x: x["Station"])
sorted_POI_counts
# Out:
# [{'Station': 3004, 'POI_Count': 43},
#  {'Station': 3005, 'POI_Count': 48},
#  {'Station': 3006, 'POI_Count': 23},
#  {'Station': 3007, 'POI_Count': 9},
#  {'Station': 3008, 'POI_Count': 9},
#  {'Station': 3009, 'POI_Count': 22},
#  {'Station': 3010, 'POI_Count': 31},
#  {'Station': 3011, 'POI_Count': 5},
#  {'Station': 3012, 'POI_Count': 20},
#  {'Station': 3013, 'POI_Count': 4},
#  {'Station': 3014, 'POI_Count': 10},
#  {'Station': 3015, 'POI_Count': 17},
#  {'Station': 3016, 'POI_Count': 1},
#  {'Station': 3017, 'POI_Count': 0},
#  {'Station': 3018, 'POI_Count': 64},
#  {'Station': 3019, 'POI_Count': 7},
#  {'Station': 3020, 'POI_Count': 7},
#  {'Station': 3021, 'POI_Count': 53},
#  {'Station': 3022, 'POI_Count': 35},
#  {'Station': 3024, 'POI_Count': 43},
#  {'Station': 3025, 'POI_Count': 8},
#  {'Station': 3026, 'POI_Count': 16},
#  {'Station': 3028, 'POI_Count': 26},
#  {'Station': 3029, 'POI_Count': 44},
#  {'Station': 3030, 'POI_Count': 15},
#  {'Station': 3031, 'POI_Count': 37},
#  {'Station': 3032, 'POI_Count': 31},
#  {'Station': 3033, 'POI_Count': 28},
#  {'Station': 3034, 'POI_Count': 5},
#  {'Station': 3035, 'POI_Count': 11},
#  {'Station': 3037, 'POI_Count': 36},
#  {'Station': 3038, 'POI_Count': 17},
#  {'Station': 3039, 'POI_Count': 7},
#  {'Station': 3040, 'POI_Count': 22},
#  {'Station': 3041, 'POI_Count': 9},
#  {'Station': 3043, 'POI_Count': 0},
#  {'Station': 3045, 'POI_Count': 41},
#  {'Station': 3046, 'POI_Count': 58},
#  {'Station': 3047, 'POI_Count': 26},
#  {'Station': 3049, 'POI_Count': 12},
#  {'Station': 3050, 'POI_Count': 24},
#  {'Station': 3051, 'POI_Count': 12},
#  {'Station': 3052, 'POI_Count': 32},
#  {'Station': 3053, 'POI_Count': 3},
#  {'Station': 3054, 'POI_Count': 24},
#  {'Station': 3055, 'POI_Count': 18},
#  {'Station': 3056, 'POI_Count': 16},
#  {'Station': 3057, 'POI_Count': 14},
#  {'Station': 3058, 'POI_Count': 14},
#  {'Station': 3059, 'POI_Count': 13},
#  {'Station': 3060, 'POI_Count': 24},
#  {'Station': 3061, 'POI_Count': 35},
#  {'Station': 3062, 'POI_Count': 24},
#  {'Station': 3063, 'POI_Count': 14},
#  {'Station': 3064, 'POI_Count': 1},
#  {'Station': 3065, 'POI_Count': 10},
#  {'Station': 3066, 'POI_Count': 17},
#  {'Station': 3067, 'POI_Count': 5},
#  {'Station': 3068, 'POI_Count': 2},
#  {'Station': 3069, 'POI_Count': 3},
#  {'Station': 3070, 'POI_Count': 7},
#  {'Station': 3071, 'POI_Count': 0},
#  {'Station': 3072, 'POI_Count': 1},
#  {'Station': 3073, 'POI_Count': 3},
#  {'Station': 3074, 'POI_Count': 22},
#  {'Station': 3075, 'POI_Count': 7},
#  {'Station': 3077, 'POI_Count': 3},
#  {'Station': 3078, 'POI_Count': 61},
#  {'Station': 3086, 'POI_Count': 6},
#  {'Station': 3088, 'POI_Count': 5},
#  {'Station': 3093, 'POI_Count': 2},
#  {'Station': 3096, 'POI_Count': 10},
#  {'Station': 3097, 'POI_Count': 1},
#  {'Station': 3098, 'POI_Count': 9},
#  {'Station': 3099, 'POI_Count': 3},
#  {'Station': 3100, 'POI_Count': 7},
#  {'Station': 3101, 'POI_Count': 13},
#  {'Station': 3102, 'POI_Count': 12},
#  {'Station': 3104, 'POI_Count': 1},
#  {'Station': 3106, 'POI_Count': 3},
#  {'Station': 3107, 'POI_Count': 0},
#  {'Station': 3108, 'POI_Count': 56},
#  {'Station': 3110, 'POI_Count': 6},
#  {'Station': 3111, 'POI_Count': 3},
#  {'Station': 3112, 'POI_Count': 13},
#  {'Station': 3113, 'POI_Count': 7},
#  {'Station': 3114, 'POI_Count': 8},
#  {'Station': 3115, 'POI_Count': 3},
#  {'Station': 3116, 'POI_Count': 17},
#  {'Station': 3117, 'POI_Count': 12},
#  {'Station': 3118, 'POI_Count': 4},
#  {'Station': 3119, 'POI_Count': 14},
#  {'Station': 3120, 'POI_Count': 2},
#  {'Station': 3121, 'POI_Count': 29},
#  {'Station': 3123, 'POI_Count': 8},
#  {'Station': 3124, 'POI_Count': 31},
#  {'Station': 3125, 'POI_Count': 18},
#  {'Station': 3150, 'POI_Count': 6},
#  {'Station': 3152, 'POI_Count': 6},
#  {'Station': 3153, 'POI_Count': 2},
#  {'Station': 3154, 'POI_Count': 8},
#  {'Station': 3155, 'POI_Count': 8},
#  {'Station': 3156, 'POI_Count': 54},
#  {'Station': 3157, 'POI_Count': 5},
#  {'Station': 3158, 'POI_Count': 9},
#  {'Station': 3159, 'POI_Count': 41},
#  {'Station': 3160, 'POI_Count': 6},
#  {'Station': 3161, 'POI_Count': 36},
#  {'Station': 3162, 'POI_Count': 20},
#  {'Station': 3163, 'POI_Count': 20},
#  {'Station': 3164, 'POI_Count': 16},
#  {'Station': 3165, 'POI_Count': 7},
#  {'Station': 3166, 'POI_Count': 10},
#  {'Station': 3167, 'POI_Count': 58},
#  {'Station': 3168, 'POI_Count': 63},
#  {'Station': 3169, 'POI_Count': 7},
#  {'Station': 3170, 'POI_Count': 11},
#  {'Station': 3181, 'POI_Count': 5},
#  {'Station': 3182, 'POI_Count': 98},
#  {'Station': 3183, 'POI_Count': 4},
#  {'Station': 3184, 'POI_Count': 4},
#  {'Station': 3185, 'POI_Count': 52},
#  {'Station': 3186, 'POI_Count': 24},
#  {'Station': 3187, 'POI_Count': 18},
#  {'Station': 3188, 'POI_Count': 1},
#  {'Station': 3190, 'POI_Count': 87},
#  {'Station': 3192, 'POI_Count': 21},
#  {'Station': 3196, 'POI_Count': 0},
#  {'Station': 3197, 'POI_Count': 2},
#  {'Station': 3200, 'POI_Count': 7},
#  {'Station': 3201, 'POI_Count': 25},
#  {'Station': 3202, 'POI_Count': 100},
#  {'Station': 3203, 'POI_Count': 4},
#  {'Station': 3204, 'POI_Count': 8},
#  {'Station': 3205, 'POI_Count': 55},
#  {'Station': 3206, 'POI_Count': 85},
#  {'Station': 3207, 'POI_Count': 54},
#  {'Station': 3208, 'POI_Count': 34},
#  {'Station': 3209, 'POI_Count': 39},
#  {'Station': 3210, 'POI_Count': 17},
#  {'Station': 3211, 'POI_Count': 1},
#  {'Station': 3212, 'POI_Count': 9},
#  {'Station': 3213, 'POI_Count': 4},
#  {'Station': 3214, 'POI_Count': 32},
#  {'Station': 3226, 'POI_Count': 9},
#  {'Station': 3233, 'POI_Count': 0},
#  {'Station': 3234, 'POI_Count': 39},
#  {'Station': 3235, 'POI_Count': 16},
#  {'Station': 3236, 'POI_Count': 12},
#  {'Station': 3237, 'POI_Count': 4},
#  {'Station': 3238, 'POI_Count': 6},
#  {'Station': 3240, 'POI_Count': 1},
#  {'Station': 3241, 'POI_Count': 4},
#  {'Station': 3243, 'POI_Count': 1},
#  {'Station': 3244, 'POI_Count': 4},
#  {'Station': 3245, 'POI_Count': 32},
#  {'Station': 3246, 'POI_Count': 29},
#  {'Station': 3247, 'POI_Count': 2},
#  {'Station': 3248, 'POI_Count': 19},
#  {'Station': 3249, 'POI_Count': 19},
#  {'Station': 3250, 'POI_Count': 0},
#  {'Station': 3251, 'POI_Count': 5},
#  {'Station': 3252, 'POI_Count': 4},
#  {'Station': 3253, 'POI_Count': 2},
#  {'Station': 3254, 'POI_Count': 6},
#  {'Station': 3255, 'POI_Count': 54},
#  {'Station': 3256, 'POI_Count': 44},
#  {'Station': 3257, 'POI_Count': 6},
#  {'Station': 3258, 'POI_Count': 6},
#  {'Station': 3259, 'POI_Count': 2},
#  {'Station': 3261, 'POI_Count': 21},
#  {'Station': 3263, 'POI_Count': 8},
#  {'Station': 3264, 'POI_Count': 6},
#  {'Station': 3265, 'POI_Count': 5},
#  {'Station': 3266, 'POI_Count': 0},
#  {'Station': 3267, 'POI_Count': 0},
#  {'Station': 3271, 'POI_Count': 3},
#  {'Station': 3272, 'POI_Count': 2},
#  {'Station': 3273, 'POI_Count': 7},
#  {'Station': 3275, 'POI_Count': 1},
#  {'Station': 3276, 'POI_Count': 3},
#  {'Station': 3277, 'POI_Count': 2},
#  {'Station': 3278, 'POI_Count': 1},
#  {'Station': 3279, 'POI_Count': 13},
#  {'Station': 3280, 'POI_Count': 4},
#  {'Station': 3281, 'POI_Count': 0},
#  {'Station': 3282, 'POI_Count': 1},
#  {'Station': 3284, 'POI_Count': 2},
#  {'Station': 3285, 'POI_Count': 4},
#  {'Station': 3286, 'POI_Count': 4},
#  {'Station': 3287, 'POI_Count': 0},
#  {'Station': 3291, 'POI_Count': 2},
#  {'Station': 3294, 'POI_Count': 85},
#  {'Station': 3295, 'POI_Count': 58},
#  {'Station': 3296, 'POI_Count': 100},
#  {'Station': 3298, 'POI_Count': 27},
#  {'Station': 3299, 'POI_Count': 20},
#  {'Station': 3300, 'POI_Count': 24}]

# %%
Counted_POI = pd.DataFrame(sorted_POI_counts)
Counted_POI.to_csv("Counted_POI.csv", index = False)
